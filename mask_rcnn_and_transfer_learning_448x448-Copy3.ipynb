# %% [markdown]
# **Mask-RCNN Starter Model for the RSNA Pneumonia Detection Challenge with transfer learning **
#
# Using pre-trained COCO weights trained on http://cocodataset.org as in https://github.com/matterport/Mask_RCNN/tree/master/samples/balloon
#
# This is a modified version of the starter model. I have made some minor changes to the Mask_RCNN in a fork but nothing that should cause errors. I have also increased the input image size to 448x448 and greatly increased the data augmentation.

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import keras
import glob
# Out:
# Using TensorFlow backend.

# %%
# enter your Kaggle credentionals here
os.environ['KAGGLE_USERNAME']="skooch"
os.environ['KAGGLE_KEY']="42f8a02ee92cc773d1dbe66565673ad3"

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
DATA_DIR = '/home/eric/pneumonia'

# Directory to save logs and trained model
ROOT_DIR = '/home/eric/pneumonia/working'

# %% [markdown]
# ### Install Matterport's Mask-RCNN model from github.
# See the [Matterport's implementation of Mask-RCNN](https://github.com/matterport/Mask_RCNN).

# %%
# !git clone https://www.github.com/escuccim/Mask_RCNN.git
os.chdir('Mask_RCNN')

# %%
# Import Mask RCNN
sys.path.append(os.path.join(ROOT_DIR, 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_1_test_images')

# %%
# !wget --quiet https://github.com/matterport/Mask_RCNN/releases/download/v2.0/mask_rcnn_coco.h5
# !ls -lh mask_rcnn_coco.h5

COCO_WEIGHTS_PATH = "mask_rcnn_coco.h5"

# %% [markdown]
# ### Some setup functions and classes for Mask-RCNN
#
# - dicom_fps is a list of the dicom image path and filenames
# - image_annotions is a dictionary of the annotations keyed by the filenames
# - parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia448'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 10
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 448
    IMAGE_MAX_DIM = 448
    RPN_ANCHOR_SCALES = (56, 112, 224, 448)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 4
    DETECTION_MAX_INSTANCES = 5
    DETECTION_MIN_CONFIDENCE = 0.7
    DETECTION_NMS_THRESHOLD = 0.1
    
    # make each epoch a full epoch instead of shorter ones
    STEPS_PER_EPOCH = 23684 // IMAGES_PER_GPU
    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     10
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        5
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.1
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 10
# IMAGE_MAX_DIM                  448
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  448
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [448 448   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'mrcnn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'rpn_class_loss': 1.0, 'mrcnn_mask_loss': 1.0, 'rpn_bbox_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               4
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia448
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (56, 112, 224, 448)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                2368
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
        
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ### Examine the annotation data, parse the dataset, and view dicom fields

# %%
# training dataset
anns = pd.read_csv(os.path.join(DATA_DIR, 'stage_1_train_labels.csv'))
anns.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# ### Split the data into training and validation datasets

# %%
# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
image_fps_list = list(image_fps)
random.seed(72)
random.shuffle(image_fps_list)

val_size = 1500
image_fps_val = image_fps_list[:val_size]
image_fps_train = image_fps_list[val_size:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 24184 1500

# %% [markdown]
# ### Create and prepare the training dataset using the DetectorDataset class.

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# one dataset containing all images - we'll train on this for an epoch or two at the end
dataset_all = DetectorDataset(image_fps_list, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_all.prepare()

# %% [markdown]
# ### Display a random image with bounding boxes

# %%
# Load and display random sample and their bounding boxes

class_ids = [0]
while class_ids[0] == 0:  ## look for a mask
    image_id = random.choice(dataset_train.image_ids)
    image_fp = dataset_train.image_reference(image_id)
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
    
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# /home/eric/pneumonia/stage_1_train_images/b44b65e1-7382-4aa6-8d87-fe6d7b4f1a17.dcm
# [1 1]

# %% [markdown]
# ### Image Augmentation. Try finetuning some variables to custom values

# %%
sometimes = lambda aug: iaa.Sometimes(0.5, aug)

# Image augmentation (heavy and random)
augmentation = iaa.Sequential([
    # flip left/right 50% of time
    iaa.Fliplr(0.5),
    iaa.Sequential([
        iaa.OneOf([ ## geometric transform
            iaa.Affine(
                scale={"x": (0.85, 1.15), "y": (0.8, 1.2)},
                translate_percent={"x": (-0.05, 0.05), "y": (-0.08, 0.08)},
                rotate=(-2.5, 2.5),
                shear=(-1.5, 1.5),
            ),
            iaa.PiecewiseAffine(scale=(0.005, 0.075)),
            iaa.Noop(),
        ]),
        iaa.OneOf([
            iaa.Crop(px=(0, 50)),
            iaa.Pad(px=(0, 50)),
            iaa.Noop(),
        ]),
    ], True),
    iaa.OneOf([ ## brightness or contrast
        iaa.Multiply((0.85, 1.15)),
        iaa.ContrastNormalization((0.75, 1.25)),
        iaa.Add((-20, 20)),
        iaa.Noop(),
    ]),
    iaa.OneOf([ ## blur or sharpen
        iaa.GaussianBlur(sigma=(0.0, 0.4)),
        iaa.Sharpen(alpha=(0.0, 0.4)),
        iaa.Noop(),
    ]),
])

# test on the same image as above
imggrid = augmentation.draw_grid(image[:, :, 0], cols=5, rows=2)
plt.figure(figsize=(30, 12))
_ = plt.imshow(imggrid[:, :, 0], cmap='gray')

# %%
# Less augmentation to speed up training
augmentation2 = iaa.Sequential([
    # flip left/right 50% of time
    iaa.Fliplr(0.5),
    
    # crop or pad the image
    iaa.OneOf([
        iaa.CropAndPad(px=(-35, 35)),
        iaa.OneOf([ ## geometric transform
                iaa.Affine(
                    scale={"x": (0.95, 1.05), "y": (0.95, 1.08)},
                    translate_percent={"x": (-0.02, 0.02), "y": (-0.04, 0.04)},
                    rotate=(-2, 2),
                    shear=(-1, 1),
                ),
                iaa.PiecewiseAffine(scale=(0.001, 0.025)),
                iaa.Noop(),
            ]),
        ]),
    # blur or sharpen
    iaa.OneOf([
        iaa.GaussianBlur(sigma=(0.0, 0.1)),
        iaa.Sharpen(alpha=(0.0, 0.1)),
    ]),
], True)

# test on the same image as above
imggrid = augmentation2.draw_grid(image[:, :, 0], cols=5, rows=2)
plt.figure(figsize=(30, 12))
_ = plt.imshow(imggrid[:, :, 0], cmap='gray')

# %% [markdown]
# ### Now it's time to train the model. Note that training even a basic model can take a few hours.
#
# Note: the following model is for demonstration purpose only. We have limited the training to one epoch, and have set nominal values for the Detector Configuration to reduce run-time.
#
# - dataset_train and dataset_val are derived from DetectorDataset
# - DetectorDataset loads images from image filenames and  masks from the annotation data
# - model is Mask-RCNN

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

# try to load the latest checkpoint, if there is a problem initialize with the coco weights instead
try:    
    # find the most recent checkpoint
    checkpoint = model.find_last()
#     checkpoint = "/home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0020.h5"
    print("Loading weights from:", checkpoint)

    # load the previous weights
    model.load_weights(checkpoint)
    
    # get the current epoch from the path
    current_epoch = int(checkpoint.split("_")[-1].split(".")[0])
    print("Epoch:", current_epoch)
    # set the current epoch 
    model.epoch = current_epoch
except:
    # Exclude the last layers because they require a matching
    # number of classes
    print("Error loading weights, initializing with COCO")
    model.load_weights(COCO_WEIGHTS_PATH, by_name=True, exclude=[
    "mrcnn_class_logits", "mrcnn_bbox_fc",
    "mrcnn_bbox", "mrcnn_mask"])
    
LEARNING_RATE = 0.004

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
# Out:
# Loading weights from: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0034.h5
# Epoch: 34

# %%
# %%time
## train heads with higher lr and no augmentation to speedup the learning
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE * 2,
            epochs=6,
            layers='heads',
            augmentation=None)  ## no need to augment yet
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 5. LR=0.008
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 6/6
# 750/750 [==============================] - 2701s 4s/step - loss: 1.2730 - rpn_class_loss: 0.0322 - rpn_bbox_loss: 0.2690 - mrcnn_class_loss: 0.2907 - mrcnn_bbox_loss: 0.3392 - mrcnn_mask_loss: 0.3419 - val_loss: 1.2943 - val_rpn_class_loss: 0.0388 - val_rpn_bbox_loss: 0.2778 - val_mrcnn_class_loss: 0.2533 - val_mrcnn_bbox_loss: 0.3612 - val_mrcnn_mask_loss: 0.3633
#
# Epoch 00006: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0006.h5
# CPU times: user 19min 32s, sys: 4min 26s, total: 23min 59s
# Wall time: 47min 45s

# %%
# %%time
# train heads with augmentation and lower lr for 2 more epochs
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE,
            epochs=8,
            layers='heads',
            augmentation=augmentation)
# Out:
# Starting at epoch 6. LR=0.004
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 7/8
# 750/750 [==============================] - 5050s 7s/step - loss: 1.3322 - rpn_class_loss: 0.0340 - rpn_bbox_loss: 0.2613 - mrcnn_class_loss: 0.3035 - mrcnn_bbox_loss: 0.3641 - mrcnn_mask_loss: 0.3692 - val_loss: 1.2911 - val_rpn_class_loss: 0.0289 - val_rpn_bbox_loss: 0.2612 - val_mrcnn_class_loss: 0.2802 - val_mrcnn_bbox_loss: 0.3630 - val_mrcnn_mask_loss: 0.3577
#
# Epoch 00007: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0007.h5
# Epoch 8/8
#  66/750 [=>............................] - ETA: 1:08:51 - loss: 1.3221 - rpn_class_loss: 0.0316 - rpn_bbox_loss: 0.2614 - mrcnn_class_loss: 0.2916 - mrcnn_bbox_loss: 0.3690 - mrcnn_mask_loss: 0.3684

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE,
            epochs=10,
            layers='5+',
            augmentation=None)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 9. LR=0.004
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 10/10
# 1312/1312 [==============================] - 4284s 3s/step - loss: 0.8310 - rpn_class_loss: 0.0124 - rpn_bbox_loss: 0.1561 - mrcnn_class_loss: 0.1702 - mrcnn_bbox_loss: 0.1984 - mrcnn_mask_loss: 0.2940 - val_loss: 1.0639 - val_rpn_class_loss: 0.0177 - val_rpn_bbox_loss: 0.2098 - val_mrcnn_class_loss: 0.2198 - val_mrcnn_bbox_loss: 0.2685 - val_mrcnn_mask_loss: 0.3481
#
# Epoch 00010: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0010.h5
# CPU times: user 31min 26s, sys: 7min 14s, total: 38min 40s
# Wall time: 1h 14min 28s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/2,
            epochs=14,
            layers='5+',
            augmentation=augmentation)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 11. LR=0.002
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 12/14
# 1480/1480 [==============================] - 7182s 5s/step - loss: 1.1827 - rpn_class_loss: 0.0233 - rpn_bbox_loss: 0.2276 - mrcnn_class_loss: 0.2563 - mrcnn_bbox_loss: 0.3177 - mrcnn_mask_loss: 0.3577 - val_loss: 0.9302 - val_rpn_class_loss: 0.0132 - val_rpn_bbox_loss: 0.1529 - val_mrcnn_class_loss: 0.2210 - val_mrcnn_bbox_loss: 0.2358 - val_mrcnn_mask_loss: 0.3073
#
# Epoch 00012: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0012.h5
# Epoch 13/14
# 1480/1480 [==============================] - 6583s 4s/step - loss: 1.1592 - rpn_class_loss: 0.0214 - rpn_bbox_loss: 0.2193 - mrcnn_class_loss: 0.2526 - mrcnn_bbox_loss: 0.3104 - mrcnn_mask_loss: 0.3555 - val_loss: 0.9433 - val_rpn_class_loss: 0.0139 - val_rpn_bbox_loss: 0.1524 - val_mrcnn_class_loss: 0.2206 - val_mrcnn_bbox_loss: 0.2463 - val_mrcnn_mask_loss: 0.3100
#
# Epoch 00013: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0013.h5
# Epoch 14/14
# 1480/1480 [==============================] - 6682s 5s/step - loss: 1.1211 - rpn_class_loss: 0.0200 - rpn_bbox_loss: 0.2130 - mrcnn_class_loss: 0.2387 - mrcnn_bbox_loss: 0.2991 - mrcnn_mask_loss: 0.3503 - val_loss: 0.9428 - val_rpn_class_loss: 0.0143 - val_rpn_bbox_loss: 0.1611 - val_mrcnn_class_loss: 0.2161 - val_mrcnn_bbox_loss: 0.2414 - val_mrcnn_mask_loss: 0.3099
#
# Epoch 00014: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0014.h5
# CPU times: user 1h 48min 7s, sys: 24min 54s, total: 2h 13min 1s
# Wall time: 5h 43min 42s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/3,
            epochs=16,
            layers='4+',
            augmentation=None)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 14. LR=0.0013333333333333333
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 15/16
# 1480/1480 [==============================] - 4688s 3s/step - loss: 0.5555 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.0994 - mrcnn_class_loss: 0.0994 - mrcnn_bbox_loss: 0.1156 - mrcnn_mask_loss: 0.2348 - val_loss: 0.6803 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.1174 - val_mrcnn_class_loss: 0.1224 - val_mrcnn_bbox_loss: 0.1501 - val_mrcnn_mask_loss: 0.2834
#
# Epoch 00015: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0015.h5
# Epoch 16/16
# 1480/1480 [==============================] - 4324s 3s/step - loss: 0.3304 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0577 - mrcnn_class_loss: 0.0491 - mrcnn_bbox_loss: 0.0527 - mrcnn_mask_loss: 0.1677 - val_loss: 0.7773 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.1465 - val_mrcnn_class_loss: 0.1225 - val_mrcnn_bbox_loss: 0.1631 - val_mrcnn_mask_loss: 0.3360
#
# Epoch 00016: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0016.h5
# CPU times: user 1h 33min 10s, sys: 17min 35s, total: 1h 50min 45s
# Wall time: 2h 31min 40s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/3,
            epochs=20,
            layers='4+',
            augmentation=augmentation)
# Out:
# Starting at epoch 16. LR=0.0013333333333333333
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 17/20
# 1480/1480 [==============================] - 7393s 5s/step - loss: 1.0810 - rpn_class_loss: 0.0189 - rpn_bbox_loss: 0.2072 - mrcnn_class_loss: 0.2241 - mrcnn_bbox_loss: 0.2839 - mrcnn_mask_loss: 0.3470 - val_loss: 0.8461 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.1373 - val_mrcnn_class_loss: 0.1837 - val_mrcnn_bbox_loss: 0.2168 - val_mrcnn_mask_loss: 0.2972
#
# Epoch 00017: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0017.h5
# Epoch 18/20
# 1480/1480 [==============================] - 6940s 5s/step - loss: 1.0292 - rpn_class_loss: 0.0172 - rpn_bbox_loss: 0.1927 - mrcnn_class_loss: 0.2110 - mrcnn_bbox_loss: 0.2701 - mrcnn_mask_loss: 0.3382 - val_loss: 0.8363 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.1516 - val_mrcnn_class_loss: 0.1590 - val_mrcnn_bbox_loss: 0.2165 - val_mrcnn_mask_loss: 0.2987
#
# Epoch 00018: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0018.h5
# Epoch 19/20
# 1480/1480 [==============================] - 6830s 5s/step - loss: 0.9841 - rpn_class_loss: 0.0155 - rpn_bbox_loss: 0.1843 - mrcnn_class_loss: 0.1972 - mrcnn_bbox_loss: 0.2557 - mrcnn_mask_loss: 0.3315 - val_loss: 0.8684 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.1681 - val_mrcnn_class_loss: 0.1565 - val_mrcnn_bbox_loss: 0.2249 - val_mrcnn_mask_loss: 0.3070
#
# Epoch 00019: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0019.h5
# Epoch 20/20
# 1480/1480 [==============================] - 6974s 5s/step - loss: 0.9408 - rpn_class_loss: 0.0144 - rpn_bbox_loss: 0.1771 - mrcnn_class_loss: 0.1824 - mrcnn_bbox_loss: 0.2421 - mrcnn_mask_loss: 0.3248 - val_loss: 0.8546 - val_rpn_class_loss: 0.0095 - val_rpn_bbox_loss: 0.1608 - val_mrcnn_class_loss: 0.1474 - val_mrcnn_bbox_loss: 0.2264 - val_mrcnn_mask_loss: 0.3104
#
# Epoch 00020: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0020.h5
# CPU times: user 2h 38min 14s, sys: 32min 12s, total: 3h 10min 27s
# Wall time: 7h 49min 45s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/5,
            epochs=23,
            layers='all',
            augmentation=augmentation2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 22. LR=0.0008
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 23/23
# 1691/1691 [==============================] - 6262s 4s/step - loss: 0.7153 - rpn_class_loss: 0.0084 - rpn_bbox_loss: 0.1326 - mrcnn_class_loss: 0.1259 - mrcnn_bbox_loss: 0.1705 - mrcnn_mask_loss: 0.2778 - val_loss: 0.5002 - val_rpn_class_loss: 0.0054 - val_rpn_bbox_loss: 0.0897 - val_mrcnn_class_loss: 0.0878 - val_mrcnn_bbox_loss: 0.0980 - val_mrcnn_mask_loss: 0.2193
#
# Epoch 00023: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0023.h5
# CPU times: user 52min 33s, sys: 10min 32s, total: 1h 3min 5s
# Wall time: 1h 45min 49s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/6,
            epochs=25,
            layers='all',
            augmentation=augmentation)
# Out:
# Starting at epoch 23. LR=0.0006666666666666666
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 24/25
# 1691/1691 [==============================] - 7591s 4s/step - loss: 0.8029 - rpn_class_loss: 0.0107 - rpn_bbox_loss: 0.1504 - mrcnn_class_loss: 0.1488 - mrcnn_bbox_loss: 0.1935 - mrcnn_mask_loss: 0.2994 - val_loss: 0.5560 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.0960 - val_mrcnn_class_loss: 0.1094 - val_mrcnn_bbox_loss: 0.1123 - val_mrcnn_mask_loss: 0.2325
#
# Epoch 00024: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0024.h5
# Epoch 25/25
# 1691/1691 [==============================] - 7199s 4s/step - loss: 0.7734 - rpn_class_loss: 0.0100 - rpn_bbox_loss: 0.1447 - mrcnn_class_loss: 0.1405 - mrcnn_bbox_loss: 0.1843 - mrcnn_mask_loss: 0.2938 - val_loss: 0.5486 - val_rpn_class_loss: 0.0063 - val_rpn_bbox_loss: 0.0955 - val_mrcnn_class_loss: 0.0963 - val_mrcnn_bbox_loss: 0.1186 - val_mrcnn_mask_loss: 0.2318
#
# Epoch 00025: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0025.h5
# CPU times: user 1h 42min 34s, sys: 19min, total: 2h 1min 34s
# Wall time: 4h 7min 19s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/8,
            epochs=29,
            layers='all',
            augmentation=augmentation)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 26. LR=0.0005
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 27/29
# 1691/1691 [==============================] - 7494s 4s/step - loss: 0.7205 - rpn_class_loss: 0.0090 - rpn_bbox_loss: 0.1356 - mrcnn_class_loss: 0.1274 - mrcnn_bbox_loss: 0.1658 - mrcnn_mask_loss: 0.2826 - val_loss: 0.4501 - val_rpn_class_loss: 0.0046 - val_rpn_bbox_loss: 0.0740 - val_mrcnn_class_loss: 0.0794 - val_mrcnn_bbox_loss: 0.0873 - val_mrcnn_mask_loss: 0.2048
#
# Epoch 00027: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0027.h5
# Epoch 28/29
# 1691/1691 [==============================] - 6947s 4s/step - loss: 0.7070 - rpn_class_loss: 0.0086 - rpn_bbox_loss: 0.1325 - mrcnn_class_loss: 0.1255 - mrcnn_bbox_loss: 0.1609 - mrcnn_mask_loss: 0.2795 - val_loss: 0.4477 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.0791 - val_mrcnn_class_loss: 0.0742 - val_mrcnn_bbox_loss: 0.0852 - val_mrcnn_mask_loss: 0.2052
#
# Epoch 00028: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0028.h5
# Epoch 29/29
# 1691/1691 [==============================] - 7104s 4s/step - loss: 0.6842 - rpn_class_loss: 0.0082 - rpn_bbox_loss: 0.1266 - mrcnn_class_loss: 0.1209 - mrcnn_bbox_loss: 0.1543 - mrcnn_mask_loss: 0.2742 - val_loss: 0.4674 - val_rpn_class_loss: 0.0044 - val_rpn_bbox_loss: 0.0784 - val_mrcnn_class_loss: 0.0813 - val_mrcnn_bbox_loss: 0.0911 - val_mrcnn_mask_loss: 0.2124
#
# Epoch 00029: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0029.h5
# CPU times: user 2h 34min 52s, sys: 30min 37s, total: 3h 5min 29s
# Wall time: 6h 2min 18s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/12,
            epochs=31,
            layers='all',
            augmentation=augmentation)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 29. LR=0.0003333333333333333
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 30/31
# 2368/2368 [==============================] - 7521s 3s/step - loss: 0.6874 - rpn_class_loss: 0.0082 - rpn_bbox_loss: 0.1302 - mrcnn_class_loss: 0.1205 - mrcnn_bbox_loss: 0.1546 - mrcnn_mask_loss: 0.2739 - val_loss: 0.3920 - val_rpn_class_loss: 0.0036 - val_rpn_bbox_loss: 0.0668 - val_mrcnn_class_loss: 0.0667 - val_mrcnn_bbox_loss: 0.0667 - val_mrcnn_mask_loss: 0.1882
#
# Epoch 00030: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0030.h5
# Epoch 31/31
# 2368/2368 [==============================] - 7061s 3s/step - loss: 0.6712 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.1269 - mrcnn_class_loss: 0.1173 - mrcnn_bbox_loss: 0.1488 - mrcnn_mask_loss: 0.2702 - val_loss: 0.4218 - val_rpn_class_loss: 0.0042 - val_rpn_bbox_loss: 0.0728 - val_mrcnn_class_loss: 0.0713 - val_mrcnn_bbox_loss: 0.0754 - val_mrcnn_mask_loss: 0.1980
#
# Epoch 00031: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0031.h5
# CPU times: user 1h 46min 21s, sys: 17min 18s, total: 2h 3min 39s
# Wall time: 4h 6min

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/16,
            epochs=34,
            layers='all',
            augmentation=augmentation)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 31. LR=0.00025
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 32/34
# 2368/2368 [==============================] - 7194s 3s/step - loss: 0.7224 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 0.1374 - mrcnn_class_loss: 0.1313 - mrcnn_bbox_loss: 0.1623 - mrcnn_mask_loss: 0.2816 - val_loss: 0.3985 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.0671 - val_mrcnn_class_loss: 0.0690 - val_mrcnn_bbox_loss: 0.0667 - val_mrcnn_mask_loss: 0.1917
#
# Epoch 00032: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0032.h5
# Epoch 33/34
# 2368/2368 [==============================] - 6896s 3s/step - loss: 0.7104 - rpn_class_loss: 0.0094 - rpn_bbox_loss: 0.1354 - mrcnn_class_loss: 0.1295 - mrcnn_bbox_loss: 0.1580 - mrcnn_mask_loss: 0.2782 - val_loss: 0.3964 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.0669 - val_mrcnn_class_loss: 0.0712 - val_mrcnn_bbox_loss: 0.0641 - val_mrcnn_mask_loss: 0.1900
#
# Epoch 00033: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0033.h5
# Epoch 34/34
# 2368/2368 [==============================] - 6927s 3s/step - loss: 0.7000 - rpn_class_loss: 0.0091 - rpn_bbox_loss: 0.1331 - mrcnn_class_loss: 0.1272 - mrcnn_bbox_loss: 0.1549 - mrcnn_mask_loss: 0.2757 - val_loss: 0.4120 - val_rpn_class_loss: 0.0048 - val_rpn_bbox_loss: 0.0741 - val_mrcnn_class_loss: 0.0690 - val_mrcnn_bbox_loss: 0.0702 - val_mrcnn_mask_loss: 0.1939
#
# Epoch 00034: saving model to /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0034.h5
# CPU times: user 2h 32min 24s, sys: 25min 26s, total: 2h 57min 51s
# Wall time: 5h 53min 5s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/20,
            epochs=35,
            layers='all',
            augmentation=augmentation2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 34. LR=0.0002
#
# Checkpoint Path: /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_{epoch:04d}.h5
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# Epoch 35/35
# Process Process-5:
# Process Process-9:
# Process Process-14:
# Process Process-8:
# Process Process-4:
# Process Process-13:
# Process Process-3:
# Process Process-15:
# Traceback (most recent call last):
# Process Process-2:
# Process Process-6:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process Process-16:
# Process Process-7:
# Process Process-17:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process Process-11:
# Traceback (most recent call last):
# Process Process-12:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1227, in load_image_gt
#     image = det.augment_image(image)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 323, in augment_image
#     return self.augment_images([image], hooks=hooks)[0]
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1227, in load_image_gt
#     image = det.augment_image(image)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
# Traceback (most recent call last):
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1195, in load_image_gt
#     mode=config.IMAGE_RESIZE_MODE)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1195, in load_image_gt
#     mode=config.IMAGE_RESIZE_MODE)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1227, in load_image_gt
#     image = det.augment_image(image)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 457, in resize_image
#     order=1, mode="constant", preserve_range=True)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 323, in augment_image
#     return self.augment_images([image], hooks=hooks)[0]
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1514, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 457, in resize_image
#     order=1, mode="constant", preserve_range=True)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1195, in load_image_gt
#     mode=config.IMAGE_RESIZE_MODE)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1195, in load_image_gt
#     mode=config.IMAGE_RESIZE_MODE)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 323, in augment_image
#     return self.augment_images([image], hooks=hooks)[0]
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1187, in load_image_gt
#     image = dataset.load_image(image_id)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 457, in resize_image
#     order=1, mode="constant", preserve_range=True)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1196, in load_image_gt
#     mask = utils.resize_mask(mask, scale, padding, crop)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1195, in load_image_gt
#     mode=config.IMAGE_RESIZE_MODE)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "<ipython-input-11-bedc163eb8cd>", line 25, in load_image
#     image = ds.pixel_array
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1514, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 457, in resize_image
#     order=1, mode="constant", preserve_range=True)
#   File "/home/eric/.local/lib/python3.5/site-packages/pydicom/dataset.py", line 901, in pixel_array
#     self.convert_pixel_data()
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 800, in warp
#     image = convert_to_float(image, preserve_range)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1187, in load_image_gt
#     image = dataset.load_image(image_id)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 852, in warp
#     order=order, mode=mode, cval=cval))
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 457, in resize_image
#     order=1, mode="constant", preserve_range=True)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 517, in resize_mask
#     mask = scipy.ndimage.zoom(mask, zoom=[scale, scale, 1], order=0)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1195, in load_image_gt
#     mode=config.IMAGE_RESIZE_MODE)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1195, in load_image_gt
#     mode=config.IMAGE_RESIZE_MODE)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/pydicom/dataset.py", line 815, in convert_pixel_data
#     arr = handler.get_pixeldata(self)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1195, in load_image_gt
#     mode=config.IMAGE_RESIZE_MODE)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 457, in resize_image
#     order=1, mode="constant", preserve_range=True)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1187, in load_image_gt
#     image = dataset.load_image(image_id)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1762, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 800, in warp
#     image = convert_to_float(image, preserve_range)
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 501, in resize_image
#     return image.astype(image_dtype), window, scale, padding, crop
#   File "skimage/transform/_warps_cy.pyx", line 90, in skimage.transform._warps_cy._warp_fast
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/_shared/utils.py", line 241, in convert_to_float
#     image = image.astype(np.double)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/eric/.local/lib/python3.5/site-packages/scipy/ndimage/interpolation.py", line 595, in zoom
#     _nd_image.zoom_shift(filtered, zoom, None, output, order, mode, cval)
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 852, in warp
#     order=order, mode=mode, cval=cval))
#   File "/home/eric/.local/lib/python3.5/site-packages/pydicom/pixel_data_handlers/pillow_handler.py", line 200, in get_pixeldata
#     UncompressedPixelData.extend(decompressed_image.tobytes())
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/_shared/utils.py", line 241, in convert_to_float
#     image = image.astype(np.double)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1762, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 852, in warp
#     order=order, mode=mode, cval=cval))
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/core/numeric.py", line 590, in ascontiguousarray
#     return array(a, dtype, copy=False, order='C', ndmin=1)
#   File "skimage/transform/_warps_cy.pyx", line 131, in skimage.transform._warps_cy._warp_fast
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/utils.py", line 457, in resize_image
#     order=1, mode="constant", preserve_range=True)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1514, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 165, in resize
#     tform.estimate(src_corners, dst_corners)
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/core/numeric.py", line 433, in asarray
#     def asarray(a, dtype=None, order=None):
#   File "/home/eric/.local/lib/python3.5/site-packages/PIL/Image.py", line 735, in tobytes
#     self.load()
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "<ipython-input-11-bedc163eb8cd>", line 25, in load_image
#     image = ds.pixel_array
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_geometric.py", line 688, in estimate
#     H = np.dot(np.linalg.inv(dst_matrix), np.dot(H, src_matrix))
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "<ipython-input-11-bedc163eb8cd>", line 28, in load_image
#     image = np.stack((image,) * 3, -1)
#   File "skimage/transform/_warps_cy.pyx", line 131, in skimage.transform._warps_cy._warp_fast
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1762, in _augment_images
#     hooks=hooks
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1762, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/core/numeric.py", line 433, in asarray
#     def asarray(a, dtype=None, order=None):
#   File "/home/eric/.local/lib/python3.5/site-packages/PIL/ImageFile.py", line 239, in load
#     n, err_code = decoder.decode(b)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1762, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/linalg/linalg.py", line 532, in inv
#     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#   File "/home/eric/.local/lib/python3.5/site-packages/pydicom/dataset.py", line 901, in pixel_array
#     self.convert_pixel_data()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 853, in warp
#     warped = np.dstack(dims)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/core/shape_base.py", line 360, in stack
#     return _nx.concatenate(expanded_arrays, axis=axis, out=out)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
# Process Process-18:
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/geometric.py", line 1469, in _augment_images
#     transformer = self._get_transformer(h, w, nb_rows_samples[i], nb_cols_samples[i], rs_image)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1762, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/geometric.py", line 1480, in _augment_images
#     output_shape=images[i].shape
#   File "/home/eric/.local/lib/python3.5/site-packages/pydicom/dataset.py", line 815, in convert_pixel_data
#     arr = handler.get_pixeldata(self)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/geometric.py", line 1620, in _get_transformer
#     matrix.estimate(points_src[:, ::-1], points_dest[:, ::-1])
# Traceback (most recent call last):
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/lib/shape_base.py", line 646, in dstack
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/pydicom/pixel_data_handlers/pillow_handler.py", line 200, in get_pixeldata
#     UncompressedPixelData.extend(decompressed_image.tobytes())
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_geometric.py", line 866, in estimate
#     affine.estimate(dst[tri, :], src[tri, :])
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 887, in warp
#     coords = warp_coords(coord_map, output_shape)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 600, in warp_coords
#     tf_coords = coord_map(tf_coords)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_geometric.py", line 688, in estimate
#     H = np.dot(np.linalg.inv(dst_matrix), np.dot(H, src_matrix))
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/geometric.py", line 1469, in _augment_images
#     transformer = self._get_transformer(h, w, nb_rows_samples[i], nb_cols_samples[i], rs_image)
#   File "/home/eric/.local/lib/python3.5/site-packages/PIL/Image.py", line 735, in tobytes
#     self.load()
#   File "/home/eric/.local/lib/python3.5/site-packages/PIL/ImageFile.py", line 239, in load
#     n, err_code = decoder.decode(b)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/geometric.py", line 1620, in _get_transformer
#     matrix.estimate(points_src[:, ::-1], points_dest[:, ::-1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 878, in coord_map
#     return inverse_map(*args, **map_args)
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/linalg/linalg.py", line 532, in inv
#     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#   File "/home/eric/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 677, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_geometric.py", line 866, in estimate
#     affine.estimate(dst[tri, :], src[tri, :])
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1677, in data_generator
#     use_mini_mask=config.USE_MINI_MASK)
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_geometric.py", line 902, in __call__
#     out[index_mask, :] = affine(coords[index_mask, :])
# KeyboardInterrupt
#   File "/home/eric/pneumonia/Mask_RCNN/mrcnn/model.py", line 1227, in load_image_gt
#     image = det.augment_image(image)
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 323, in augment_image
#     return self.augment_images([image], hooks=hooks)[0]
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1514, in _augment_images
#     hooks=hooks
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_geometric.py", line 679, in estimate
#     _, _, V = np.linalg.svd(A)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/linalg/linalg.py", line 1543, in svd
#     _assertRankAtLeast2(a)
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1762, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/numpy/linalg/linalg.py", line 201, in _assertRankAtLeast2
#     for a in arrays:
# KeyboardInterrupt
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 1762, in _augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/meta.py", line 431, in augment_images
#     hooks=hooks
#   File "/home/eric/.local/lib/python3.5/site-packages/imgaug/augmenters/geometric.py", line 1480, in _augment_images
#     output_shape=images[i].shape
#   File "/home/eric/.local/lib/python3.5/site-packages/skimage/transform/_warps.py", line 894, in warp
#     mode=ndi_mode, order=order, cval=cval)
#   File "/home/eric/.local/lib/python3.5/site-packages/scipy/ndimage/interpolation.py", line 328, in map_coordinates
#     output, order, mode, cval, None, None)
# KeyboardInterrupt

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/20,
            epochs=38,
            layers='all',
            augmentation=augmentation)

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/24,
            epochs=40,
            layers='all',
            augmentation=augmentation2)

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/24,
            epochs=43,
            layers='all',
            augmentation=augmentation)

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else:
        checkpoint = os.path.join(dir_name, checkpoints[-1])
        fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0034.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    DETECTION_MIN_CONFIDENCE = 0.6
    
inference_config = InferenceConfig()

# Recreate the model in inference mode
model_inf = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# model_path = "/content/working/pneumonia/mask_rcnn_pneumonia_0018.h5"

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model_inf.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  /home/eric/pneumonia/working/pneumonia448/mask_rcnn_pneumonia448_0034.h5

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# ### How does the predicted box compared to the expected value? Let's use the validation dataset to check.
#
# Note that we trained only one epoch for **demonstration purposes ONLY**. You might be able to improve performance running more epochs.

# %%
# calculate IOU where there can be multiple overlapping truths and predictions
def calc_iou_better(y_true, y_pred, image_size=1024):
    label_array = np.zeros((image_size, image_size))
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    for truth in y_true:
        x,y,x1,y1 = truth[:4].astype(int)  
        label_array[y:y1, x:x1] = 1
                
    pred_array = np.zeros((image_size, image_size))
    for pred in y_pred:
        x,y,x1,y1 = pred[:4].astype(int)

        # update the pixels
        pred_array[y:y1, x:x1] = 1
                
    true_area = np.sum(label_array)
    pred_area = np.sum(pred_array)
    
    intersect_area = np.sum((pred_array == 1) & (label_array == 1))
    
    union = true_area + pred_area - intersect_area
    
    iou = intersect_area / (union + 1e-6)
    
    return iou

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))
iou_scores = []

for i in range(6):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model_inf.detect([original_image])
    r = results[0]
    
    if len(r['rois']) or len(gt_bbox):
        iou = calc_iou_better(gt_bbox, r['rois'], 384)
        iou_scores.append(iou)
    
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
    
print("Mean IOU:", np.mean(iou_scores))
# Out:
# (448, 448, 3)
#
# *** No instances to display ***
#
# (448, 448, 3)
# (448, 448, 3)
# (448, 448, 3)
#
# *** No instances to display ***
#
# (448, 448, 3)
#
# *** No instances to display ***
#
# (448, 448, 3)
#
# *** No instances to display ***
#
# Mean IOU: 0.2628661236056922

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %% [markdown]
# ### Final steps - Create the submission file

# %%
# Make predictions on test images, write out sample submission
def predict(image_fps, filepath='submission.csv', min_conf=0.95):
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    #resize_factor = ORIG_SIZE
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps):
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1)
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model_inf.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0:
                pass
            else:
                num_instances = len(r['rois'])

                for i in range(num_instances):
                    if r['scores'][i] > min_conf:
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1
                        height = r['rois'][i][2] - y1
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
submission_fp = os.path.join(ROOT_DIR, 'submission.csv')
predict(test_image_fps, filepath=submission_fp)
print(submission_fp)
# Out:
# 100%|██████████| 1000/1000 [03:39<00:00,  4.56it/s]
# /home/eric/pneumonia/working/submission.csv

# %%
# !kaggle competitions submit -c rsna-pneumonia-detection-challenge -f {submission_fp} -m "mask-rcnn GCP 448x448 34 epochs"
# Out:
# Successfully submitted to RSNA Pneumonia Detection Challenge

# %%
del(model_inf)

# %%
# show a few test image detection example
def visualize2(): 
    image_id = random.choice(test_image_fps)
    ds = pydicom.read_file(image_id)
    
    # original image 
    image = ds.pixel_array
    
    # assume square image 
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    
    # If grayscale. Convert to RGB for consistency.
    if len(image.shape) != 3 or image.shape[2] != 3:
        image = np.stack((image,) * 3, -1) 
    resized_image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.IMAGE_MIN_DIM,
        min_scale=config.IMAGE_MIN_SCALE,
        max_dim=config.IMAGE_MAX_DIM,
        mode=config.IMAGE_RESIZE_MODE)

    patient_id = os.path.splitext(os.path.basename(image_id))[0]
    print(patient_id)

    results = model.detect([resized_image])
    r = results[0]
    for bbox in r['rois']: 
        print(bbox)
        x1 = int(bbox[1] * resize_factor)
        y1 = int(bbox[0] * resize_factor)
        x2 = int(bbox[3] * resize_factor)
        y2 = int(bbox[2]  * resize_factor)
        cv2.rectangle(image, (x1,y1), (x2,y2), (77, 255, 9), 3, 1)
        width = x2 - x1 
        height = y2 - y1 
        print("x {} y {} h {} w {}".format(x1, y1, width, height))
    plt.figure() 
    plt.imshow(image, cmap=plt.cm.gist_gray)

visualize2()
visualize2()
visualize2()
visualize2()
