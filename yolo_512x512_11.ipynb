# %% [markdown]
# ## Approach
#
# * This is a simplied version of YOLO. We take our 512x512 input, divide it into a 4x4 grid, each cell outputs five values:
#     * The confidence that there is pneumonia present
#     * The x, y, w, and h of the bounding box
#     * We have removed the entire classification section, using the confidence to indicate whether there is an ROI in the cell instead.
# * A sigmoid is applied to the output of the network to result in values between 0 and 1
# * The x and y coordinates are offsets from the upper left corner of each cell, the w and h are percentage of the total width.
# * The loss function is based on YOLO with some differences:
#     * The weights of the components have been updated
#     * The "objectness" loss of YOLO tries to make the confidence match the actual IOU. Since our model only outputs one box per cell, this effectively drives the confidence down towards the IOU rather than driving the IOU up.
#     * We replaced this component of the loss by calculating the IOU for cells with ground truth, subtracting that from 1 and using that as the loss. Since we want to maximize the IOU, why not just do it directly?
#
# ## Network
#
# * The network consists of a number of residual blocks with convolutions and downsampling blocks with max pooling.
# * The network outputs a 4x4x5 array as described above.
# * We are using an Adam optimizer with gradient clipping to avoid exploding gradients.
#
# ## Predictions
# * To generate our predictions we loop through each cell of the output
# * We unnormalize the output to get the actual values
# * If the confidence is greater than 0.5 and the box has width and height we append it to the list of candidates.
# * We apply non-max suppression to remove duplicates.
# * The remaining boxes are concatenated onto the output string.
#
# **Change Log:**
# * v3 - changing output to 8x8 grid from 16x16; changed model to downsample one more time; adjusted network accordingly.
# * v4 - changed output to 4x4 grid, no image has more than 3 ROIs so this may work better?
#     * Using center point of ROI to predict instead of upper left corner.
# * v5 - We only calculate MSE loss for boxes with a confidence over 0.5 or actual truth since we don't care about predictions for boxes that are not ROIs. This will prevent the network from being constrained by outputting 0s for boxes that don't exist.
# * v6 - centering input data so maybe bboxes can be output more accurately? Also centering the image
# * v6.2 - labels have ROI centered in center of cell by default instead of mean location.
# * v8 - using custom loss function based on YOLO loss. Set default height and width to 1 px because 0 sent the gradients to -inf which screwed everything up.

# %%
# install dependencies not included by Colab
# use pip3 to ensure compatibility w/ Google Deep Learning Images 
# !pip3 install -q pydicom 
# !pip3 install -q imgaug 
# !pip3 install -q kaggle
# !pip3 install -q tqdm

# %%
import os
import csv
import random
import pydicom
import numpy as np
import pickle
import pandas as pd
from skimage import measure
from skimage.transform import resize
import datetime
import math

import tensorflow as tf
from tensorflow import keras

from matplotlib import pyplot as plt
import matplotlib.patches as patches

# %%
from google.colab import auth
from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build

auth.authenticate_user()

drive_service = build('drive', 'v3')

def save_file_to_drive(name, path):
    file_metadata = {
      'name': name,
      'mimeType': 'application/octet-stream'
     }

    media = MediaFileUpload(path, 
                    mimetype='application/octet-stream',
                    resumable=True)

    created = drive_service.files().create(body=file_metadata,
                                   media_body=media,
                                   fields='id').execute()

    print('File ID: {}'.format(created.get('id')))

    return created

# %%
# Malisiewicz et al.
def non_max_suppression_fast(boxes, overlapThresh=0.3):
    # if there are no boxes, return an empty list
    if len(boxes) == 0:
        return []
 
    # if the bounding boxes integers, convert them to floats --
    # this is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")
 
    # initialize the list of picked indexes	
    pick = []
 
    # grab the coordinates of the bounding boxes
    x1 = boxes[:,0]
    y1 = boxes[:,1]
    w = boxes[:,2]
    h = boxes[:,3]
 
    x2 = x1 + w
    y2 = y1 + h

    # compute the area of the bounding boxes and sort the bounding
    # boxes by the bottom-right y-coordinate of the bounding box
    area = (w + 1) * (h + 1)
    idxs = np.argsort(y2)
 
    # keep looping while some indexes still remain in the indexes
    # list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the
        # index value to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)
 
        # find the largest (x, y) coordinates for the start of
        # the bounding box and the smallest (x, y) coordinates
        # for the end of the bounding box
        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.minimum(x2[i], x2[idxs[:last]])
        yy2 = np.minimum(y2[i], y2[idxs[:last]])
 
        # compute the width and height of the bounding box
        w = np.maximum(0, xx2 - xx1 + 1)
        h = np.maximum(0, yy2 - yy1 + 1)
 
        # compute the ratio of overlap
        overlap = (w * h) / area[idxs[:last]]
 
        # delete all indexes from the index list that have
        idxs = np.delete(idxs, np.concatenate(([last],
            np.where(overlap > overlapThresh)[0])))
 
    # return only the bounding boxes that were picked using the
    # integer data type
    return boxes[pick].astype("int")

# get actual x and y values from sigmoid output and what cell they are in
def unnorm(val, idx, cell_size=256):
    x = (val * cell_size) + (cell_size * idx)
    return x

# sigmoid in numpy, with limit to avoid nans                             
def sigmoid(x):
    # to avoid NaNs set a lower floor on x values
    y = np.maximum(x, -700)
    return 1 / (1 + np.exp(-y))

# %%
# enter your Kaggle credentionals here
os.environ['KAGGLE_USERNAME']="skooch"
os.environ['KAGGLE_KEY']="42f8a02ee92cc773d1dbe66565673ad3"

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# If you are unable to download the competition dataset, check to see if you have 
# accepted the user agreement on the competition website. 
if not os.path.exists("./stage_1_detailed_class_info.csv.zip"):
    # !kaggle competitions download -c rsna-pneumonia-detection-challenge
# Out:
# Downloading GCP%20Credits%20Request%20Link%20-%20RSNA.txt to /content
#   0% 0.00/55.0 [00:00<?, ?B/s]
# 100% 55.0/55.0 [00:00<00:00, 41.3kB/s]
# Downloading stage_1_detailed_class_info.csv.zip to /content
#   0% 0.00/561k [00:00<?, ?B/s]
# 100% 561k/561k [00:00<00:00, 66.1MB/s]
# Downloading stage_1_sample_submission.csv to /content
#   0% 0.00/51.8k [00:00<?, ?B/s]
# 100% 51.8k/51.8k [00:00<00:00, 39.0MB/s]
# Downloading stage_1_train_labels.csv.zip to /content
#   0% 0.00/634k [00:00<?, ?B/s]
# 100% 634k/634k [00:00<00:00, 85.1MB/s]
# Downloading stage_1_test_images.zip to /content
#  86% 109M/126M [00:00<00:00, 148MB/s]
# 100% 126M/126M [00:00<00:00, 183MB/s]
# Downloading stage_1_train_images.zip to /content
# 100% 3.16G/3.17G [00:23<00:00, 94.5MB/s]
# 100% 3.17G/3.17G [00:23<00:00, 146MB/s]

# %%
# unzipping takes a few minutes
if not os.path.exists("./stage_1_train_labels.csv"):
    print("Unzipping...")
    # !unzip -q -o stage_1_test_images.zip -d stage_1_test_images
    # !unzip -q -o stage_1_train_images.zip -d stage_1_train_images
    # !unzip -q -o stage_1_train_labels.csv.zip
# Out:
# Unzipping...

# %% [markdown]
# # Load pneumonia locations
#
# Table contains [filename : pneumonia location] pairs per row.
# * If a filename contains multiple pneumonia, the table contains multiple rows with the same filename but different pneumonia locations.
# * If a filename contains no pneumonia it contains a single row with an empty pneumonia location.
#
# The code below loads the table and transforms it into a dictionary.
# * The dictionary uses the filename as key and a list of pneumonia locations in that filename as value.
# * If a filename is not present in the dictionary it means that it contains no pneumonia.

# %%
ROOT_DIR = "./"

train_dicom_dir = os.path.join(ROOT_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(ROOT_DIR, 'stage_1_test_images')
print("Train dir:", train_dicom_dir)
# Out:
# Train dir: ./stage_1_train_images

# %%
# !gsutil cp gs://{bucket_name}/yolo_labels_centered_4x4_6.p ./yolo_labels_centered_4x4_6.p
# Out:
# Copying gs://pneumonia/yolo_labels_centered_4x4_6.p...
# - [1 files][ 17.5 MiB/ 17.5 MiB]
# Operation completed over 1 objects/17.5 MiB.

# %%
with open('yolo_labels_centered_4x4_6.p', 'rb') as handle:
    pneumonia_locations = pickle.load(handle)

# %% [markdown]
# # Load filenames

# %%
random.seed(72)

# load and shuffle filenames
folder = './stage_1_train_images'
filenames = os.listdir(folder)
random.shuffle(filenames)
# split into train and validation filenames
n_valid_samples = int(len(filenames) * 0.1)
train_filenames = filenames[n_valid_samples:]
valid_filenames = filenames[:n_valid_samples]
print('n train samples', len(train_filenames))
print('n valid samples', len(valid_filenames))
n_train_samples = len(filenames) - n_valid_samples
# Out:
# n train samples 23116
# n valid samples 2568

# %%
# create a list of images with ROIs so we can make sure there is at least one in each batch
positive_images = []

for filename in pneumonia_locations:
    label = pneumonia_locations[filename][...,0]
    if np.max(label) > 1e-6:
        if filename + ".dcm" in train_filenames:
            positive_images.append(filename + ".dcm")

# %% [markdown]
#  # Data generator
#
# The dataset is too large to fit into memory, so we need to create a generator that loads data on the fly.
#
# * The generator takes in some filenames, batch_size and other parameters.
#
# * The generator outputs a random batch of numpy images and numpy masks.

# %%
BATCH_SIZE = 16
IMAGE_SIZE = 512
CHECKPOINT_PATH = "yolo10_2_512.h5"

# %%
# !gsutil cp gs://{bucket_name}/{CHECKPOINT_PATH} ./{CHECKPOINT_PATH}
# Out:
# Copying gs://pneumonia/yolo10_2_512.h5...
# | [1 files][ 71.5 MiB/ 71.5 MiB]
# Operation completed over 1 objects/71.5 MiB.

# %%
# means to center data
mu_x = 391.456158
mu_y = 363.1358768
mu_w = 220.8453815
mu_h = 334.1743641
mu_center_x = 501.8788487
mu_center_y = 530.2230589

# %%
class generator(keras.utils.Sequence):
    
    def __init__(self, folder, filenames, pneumonia_locations=None, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=False, predict=False):
        self.folder = folder
        self.filenames = filenames
        self.pneumonia_locations = pneumonia_locations
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.predict = predict
        self.on_epoch_end()
        
    def __load__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # get filename without extension
        filename = filename.split('.')[0]
        label = pneumonia_locations[filename].copy()
        
        # remove the confidence and bboxes because they will be flipped separately
        confs = label[:,:,0]
        boxes = label[:,:,1:]
        
        ## data augmentation may be complicated, let's do that later
        # if augment then horizontal flip half the time
        if self.augment and random.random() > 0.5:
            # flip the image
            img = np.fliplr(img)
            
            # update our x coords
            mask = confs != 0
            
            # flip
            boxes[mask, 0] = 1 - boxes[mask,0]
            
            # flip our boxes lr on axis 0
            boxes = np.flip(boxes, axis=0)         
            
            # flip the confidences lr as well
            confs = np.flip(confs, axis=0)
        
        # very small shifts to image - if these are bigger they will mess with the label alignment
        if self.augment:
            h_offset = np.random.randint(low=0, high=5)
            v_offset = np.random.randint(low=0, high=5)
            # crop the images
            img = img[v_offset:,h_offset:]
        
        # random contrast adjustment
#         if self.augment and random.random() > 0.5:
#             # generate a random contrast adjustment
#             contrast_factor = np.random.normal(loc=1.0, scale=0.10)
            
#             # put some limits on the contrast
#             contrast_factor = np.minimum(contrast_factor, 1.25)
#             contrast_factor = np.maximum(contrast_factor, 0.75)
            
#             # adjust the image
#             img = change_contrast(img, contrast_factor)
            
        # resize both image and mask
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        
        # scale and center the image
        img = (img - np.mean(img)) / np.max(img)
        
        boxes = np.concatenate([confs.reshape((4,4,1)), boxes], axis=2)
        
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        return img, boxes
    
    def __loadpredict__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # resize image
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        return img
        
    def __getitem__(self, index):
        # select batch
        filenames = self.filenames[index*self.batch_size:(index+1)*self.batch_size]
        # predict mode: return images and filenames
        if self.predict:
            # load files
            imgs = [self.__loadpredict__(filename) for filename in filenames]
            # create numpy batch
            imgs = np.array(imgs)
            return imgs, filenames
        # train mode: return images and masks
        else:
            # load files
            items = [self.__load__(filename) for filename in filenames]
            
            # unzip images and masks
            imgs, bboxes = zip(*items)
            
            # create numpy batch
            imgs = np.array(imgs)
            bboxes = np.array(bboxes)
            
            # make sure there is at least one positive image in the batch
            pos = np.max(bboxes[:,:,:,0])
            if pos < 1:
                # pick a random positive image
                filename = np.random.choice(positive_images)
                img, label = self.__load__(filename)
                
                # add the positive image to our batch
                imgs[-1] = img
                bboxes[-1] = label
                
            labels = bboxes
            return imgs, labels
        
    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.filenames)
        
    def __len__(self):
        if self.predict:
            # return everything
            return int(np.ceil(len(self.filenames) / self.batch_size))
        else:
            # return full batches only
            return int(len(self.filenames) / self.batch_size)

# %% [markdown]
# # Network

# %%
def create_downsample(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.MaxPool2D(2)(x)
    return x

def create_resblock(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0.1)(x)
    x_1 = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x_1)
    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.add([x, x_1])
    return x

def create_network(input_size, channels, n_blocks=2, depth=4):
    # input - 512x512x3
    inputs = keras.Input(shape=(input_size, input_size, 1))
    
    # 256x256x24
    x = keras.layers.Conv2D(channels, 3, strides=(2,2), padding='same', use_bias=False)(inputs)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    # 256x256x24 for residual connection
    x = keras.layers.Conv2D(channels, 1, padding='same', use_bias=False)(x)
    
    # residual blocks
    for d in range(depth):
        channels = channels * 2
        
        x = create_downsample(channels, x)
            
        for b in range(n_blocks):
            x = create_resblock(channels, x)
    
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    
    # dilated convolutions for context - 16x16x512
    x_2 = keras.layers.Conv2D(512, (3,3), padding='same', dilation_rate=(2,2), activation=None, name="dilated_conv_1")(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x_2)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    x = keras.layers.Conv2D(512, (3,3), padding='same', dilation_rate=(2,2), activation=None, name="dilated_conv_2")(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    x = keras.layers.Conv2D(512, (3,3), padding='same', activation=None, name="last_conv")(x)
    x = keras.layers.add([x, x_2])
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    # downsample to 4x4x512 with stride 4
    x = keras.layers.Conv2D(512, (4,4), padding='same', strides=(4,4), activation=None, name="downsample_1")(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    
#     # confidence branch
    c = keras.layers.Conv2D(384, (1,1), padding='same', activation=None, name="fc_1_c", kernel_regularizer=keras.regularizers.l2(l=0.01))(x)
    c = keras.layers.BatchNormalization(momentum=0.9)(c)
    c = keras.layers.LeakyReLU(0.1)(c)
    c = keras.layers.Dropout(0.10)(c)
    
#     c = keras.layers.Conv2D(256, (1,1), padding='same', activation=None, name="fc_2_c", kernel_regularizer=keras.regularizers.l2(l=0.01))(c)
#     c = keras.layers.BatchNormalization(momentum=0.9)(c)
#     c = keras.layers.LeakyReLU(0.1)(c)
#     c = keras.layers.Dropout(0.10)(c)
    
    confidence = keras.layers.Conv2D(1, (1,1), padding='same', activation=None, name="confidence_output")(c)
    
    # bounding box branch
    b = keras.layers.Conv2D(1024, (1,1), padding='same', activation=None, name="fc_1_b", kernel_regularizer=keras.regularizers.l2(l=0.01))(x)
    b = keras.layers.BatchNormalization(momentum=0.9)(b)
    b = keras.layers.LeakyReLU(0.01)(b)
    b = keras.layers.Dropout(0.10)(b)
    
    b = keras.layers.Conv2D(1024, (1,1), padding='same', activation=None, name="fc_2_b", kernel_regularizer=keras.regularizers.l2(l=0.001))(b)
    b = keras.layers.BatchNormalization(momentum=0.9)(b)
    b = keras.layers.LeakyReLU(0.01)(b)
#     b = keras.layers.Dropout(0.05)(b)
    
    boxes = keras.layers.Conv2D(4, (1,1), padding='same', activation="linear")(b)
    boxes = keras.layers.concatenate([confidence, boxes], name="bboxes_output")
    
    # return both outputs
    model = keras.Model(inputs=inputs, outputs=boxes)
    
    return model

# %% [markdown]
# # Train network

# %%
def binary_accuracy(y_true, y_pred):
    y_pred = tf.sigmoid(y_pred)
    y_true = tf.round(tf.reshape(y_true, [-1, 5]))
    y_pred = tf.round(tf.reshape(y_pred, [-1, 5]))
    
    acc = tf.reduce_mean(tf.cast(tf.equal(y_true[:,0], y_pred[:,0]), dtype=tf.float32))
    return acc
    
def overlap_iou(y_true, y_pred):
    """
    Args:
        bboxes1: shape (batch_size, 16, 16, 4)
            with x1, y1, x2, y2 point order.
        bboxes2: shape (batch_size, 16, 16, 4)
            with x1, y1, x2, y2 point order.
        p1 *-----
           |     |
           |_____* p2
    Returns:
        Tensor with shape (total_bboxes1, total_bboxes2)
        with the IoU (intersection over union) of bboxes1[i] and bboxes2[j]
        in [i, j].
    """
    y_pred = tf.sigmoid(y_pred)
    
    # flatten the data because it's easier that way
    bboxes1 = tf.reshape(y_true, (-1, 5))
    bboxes2 = tf.reshape(y_pred, (-1, 5))
    
    # split the components out
    true_boxes, x11, y11, w1, h1 = tf.split(bboxes1, 5, axis=1)
    pred_conf, x21, y21, w2, h2 = tf.split(bboxes2, 5, axis=1)
    
    # uncenter the data - make sure the numbers are positive
    x11 = x11 * 256
    x21 = x21 * 256
    y11 = y11 * 256
    y21 = y21 * 256
    
    w1 = w1 * 1024
    w2 = w2 * 1024
    h1 = h1 * 1024
    h2 = h2 * 1024
    
    # is there either a box predicted here or a box actually here?
    mask = (pred_conf >= 0.5) | (true_boxes == 1)
    
    # these labels are center points of the boxes so we need to calculate the corners
    x12 = x11 + (w1 / 2)
    y12 = y11 + (h1 / 2)
    x22 = x21 + (w2 / 2)
    y22 = y21 + (h2 / 2)
    
    x11 = x11 - (w1 / 2)
    y11 = y11 - (h1 / 2)
    x21 = x21 - (w2 / 2)
    y21 = y21 - (h2 / 2)

    # find the corners of the intersection area
    xI1 = tf.maximum(x11, x21)
    yI1 = tf.maximum(y11, y21)

    xI2 = tf.minimum(x12, x22)
    yI2 = tf.minimum(y12, y22)
    
    # get the intersection area, if the truth has no boxes it is 0
    inter_area = true_boxes * (xI2 - xI1 + 1) * (yI2 - yI1 + 1)

    # get the area of each box
    bboxes1_area = (w1 + 1) * (h1 + 1)
    bboxes2_area = (w2 + 1) * (h2 + 1)
    
    # union is area of both boxes - intersection
    union = (bboxes1_area + bboxes2_area) - inter_area + 1
    
    iou = tf.maximum(inter_area/union, 0)
    
    # apply the mask
    iou = tf.boolean_mask(iou, mask)
    
    # reduce the mean so we have mean iou for our inputs
    return tf.reduce_mean(iou)

def loss_fn(y_true, y_pred):
    # get the iou loss
    iou_loss = iou_loss_fn(y_true, y_pred)
    
    # get the xe loss
    xe_loss = binary_cross_entropy(y_true, y_pred)
    
    # get the box loss
    box_loss = adj_mse(y_true, y_pred)
    
    # add the losses and return them
    return (xe_loss + (box_loss * 3.0) + (iou_loss * 2.0))

# only apply mse to layers with high confidence that there is an ROI or if there actually is an ROI
def adj_mse(y_true, y_pred):
    # coefficients
    lam_coord = 5
    lam_noobj = 0.5
    
    y_pred = tf.sigmoid(y_pred)
        
    # flatten the inputs
    y_true = tf.reshape(y_true, (-1, 5))
    y_pred = tf.reshape(y_pred, (-1, 5))

    # separate the confidence from the boxes
    conf_true, x_true, y_true, w_true, h_true = tf.split(y_true, 5, axis=1)
    conf_pred, x_pred, y_pred, w_pred, h_pred = tf.split(y_pred, 5, axis=1)

    # center squared error
    center_se = tf.square(x_true - y_pred) + tf.square(y_true - y_pred)
    size_se =  tf.square(tf.sqrt(w_true) - tf.sqrt(w_pred)) + tf.square(tf.sqrt(h_true) - tf.sqrt(h_pred))
    
    box_se = center_se + size_se
    
    # only get loss for boxes which are actually positive
    mask = tf.cast(tf.equal(conf_true, 1), tf.float32) * 5.0
    
    box_se = tf.multiply(box_se, mask)
    
    loss = tf.reduce_sum(box_se)
    
    return loss
    
# use weight of 0.5 for negative cells, 19 for positive ones
def binary_cross_entropy(y_true, y_pred):
    conf_true = y_true[...,0]
    conf_pred = tf.sigmoid(y_pred[...,0])
    
    weight = 10.5
    weights = tf.multiply(y_true[...,0], weight) + 0.5
    
    xe = tf.multiply(tf.square(conf_true - conf_pred), weights)
    
    return tf.reduce_sum(xe)

def iou_loss_fn(y_true, y_pred):
    # apply sigmoid to predictions
    y_pred = tf.sigmoid(y_pred)
    
    # separate the x, y from the w, h and unnormalize them
    true_box_xy = y_true[...,1:3] * 256
    true_box_wh = y_true[...,3:] * 1024
    
    pred_box_xy = y_pred[...,1:3] * 256
    pred_box_wh = y_pred[...,3:] * 1024
    
    # get the corners of the boxes by subtracting or adding half of h, w
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half  
    
    # get the corners of the intersect area
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    # get the area of the boxes
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    # calculate the IOU
    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas + 1e-16)
    
    # only use the IOU from boxes which actually have ROIs
    mask = tf.equal(y_true[...,0], 1)
    use_iou = tf.boolean_mask(1 - iou_scores, mask)
    
    return tf.reduce_sum(use_iou)
    
# create network and compiler
model = create_network(input_size=IMAGE_SIZE, channels=24, n_blocks=1, depth=4)

optimizer = keras.optimizers.Adam(lr=0.002, beta_1=0.9, beta_2=0.999, decay=1e-8, clipnorm=3, clipvalue=1.5)

model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=[binary_accuracy, overlap_iou, adj_mse, binary_cross_entropy])

# cosine learning rate annealing
def exp_decay(x):
    lr0 = 0.002
    epochs_drop = 10
    drop = 0.75
    lrate = lr0 * math.pow(drop, math.floor((1+x)/epochs_drop))
    return lrate

learning_rate = tf.keras.callbacks.LearningRateScheduler(exp_decay)
checkpoint = keras.callbacks.ModelCheckpoint(CHECKPOINT_PATH, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=True, mode='auto', period=1)

# create train and validation generators
folder = './stage_1_train_images'
train_gen = generator(folder, train_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=True, predict=False)
valid_gen = generator(folder, valid_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=False, predict=False)

print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 24) 216         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 24) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 24) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 24) 5184        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 24) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 24) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 24) 5184        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 24) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 256, 256, 24) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 24) 576         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 24) 96          conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 256, 256, 24) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 24) 0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 24) 96          max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 128, 128, 24) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 48) 10368       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 48) 192         conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 128, 128, 48) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 48) 20736       leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 48) 192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 128, 128, 48) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 48) 20736       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 48) 192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 128, 128, 48) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 48) 20736       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 48) 0           conv2d_7[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 48) 192         add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 128, 128, 48) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 48)   0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 48)   192         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 64, 64, 48)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 96)   41472       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 96)   384         conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 64, 64, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 96)   82944       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 96)   384         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 64, 64, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 96)   82944       leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 96)   384         conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 64, 64, 96)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 96)   82944       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 96)   0           conv2d_11[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 96)   384         add_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 64, 64, 96)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 96)   0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 96)   384         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 32, 32, 96)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 192)  165888      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 192)  768         conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 32, 32, 192)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 192)  331776      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 192)  768         conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 32, 32, 192)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 192)  331776      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 192)  768         conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 32, 32, 192)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 192)  331776      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 192)  0           conv2d_15[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 192)  768         add_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 32, 32, 192)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 192)  0           leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 192)  768         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 16, 16, 192)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 384)  663552      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 384)  1536        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 16, 16, 384)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 384)  1327104     leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 384)  1536        conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 16, 16, 384)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 384)  1327104     leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 384)  1536        conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 16, 16, 384)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 384)  1327104     leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 384)  0           conv2d_19[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 384)  1536        add_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 16, 16, 384)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dilated_conv_1 (Conv2D)         (None, 16, 16, 512)  1769984     leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 512)  2048        dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 16, 16, 512)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# dilated_conv_2 (Conv2D)         (None, 16, 16, 512)  2359808     leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 512)  2048        dilated_conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 16, 16, 512)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# last_conv (Conv2D)              (None, 16, 16, 512)  2359808     leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 512)  0           last_conv[0][0]
#                                                                  dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 512)  2048        add_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 16, 16, 512)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# downsample_1 (Conv2D)           (None, 4, 4, 512)    4194816     leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 512)    2048        downsample_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 4, 4, 512)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# fc_1_b (Conv2D)                 (None, 4, 4, 1024)   525312      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 1024)   4096        fc_1_b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 4, 4, 1024)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# fc_1_c (Conv2D)                 (None, 4, 4, 384)    196992      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4, 4, 1024)   0           leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, 4, 384)    1536        fc_1_c[0][0]
# __________________________________________________________________________________________________
# fc_2_b (Conv2D)                 (None, 4, 4, 1024)   1049600     dropout_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 4, 4, 384)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 1024)   4096        fc_2_b[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4, 4, 384)    0           leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 4, 4, 1024)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# confidence_output (Conv2D)      (None, 4, 4, 1)      385         dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 4)      4100        leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# bboxes_output (Concatenate)     (None, 4, 4, 5)      0           confidence_output[0][0]
#                                                                  conv2d_20[0][0]
# ==================================================================================================
# Total params: 18,672,189
# Trainable params: 18,656,557
# Non-trainable params: 15,632
# __________________________________________________________________________________________________
# None

# %%
model.load_weights(CHECKPOINT_PATH)

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=10, shuffle=True, verbose=1, initial_epoch=0)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1443/1444 [============================>.] - ETA: 0s - loss: 71.7237 - binary_accuracy: 0.8750 - overlap_iou: nan - adj_mse: 7.4334 - binary_cross_entropy: 35.3179
# Epoch 00001: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1337s 926ms/step - loss: 71.7171 - binary_accuracy: 0.8750 - overlap_iou: nan - adj_mse: 7.4336 - binary_cross_entropy: 35.3112 - val_loss: 55.2281 - val_binary_accuracy: 0.9028 - val_overlap_iou: 0.0334 - val_adj_mse: 5.6872 - val_binary_cross_entropy: 27.8131
# Epoch 2/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 54.0938 - binary_accuracy: 0.8567 - overlap_iou: 0.0349 - adj_mse: 5.8492 - binary_cross_entropy: 26.7009
# Epoch 00002: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1302s 902ms/step - loss: 54.0841 - binary_accuracy: 0.8566 - overlap_iou: 0.0349 - adj_mse: 5.8476 - binary_cross_entropy: 26.6976 - val_loss: 51.3526 - val_binary_accuracy: 0.8497 - val_overlap_iou: 0.0340 - val_adj_mse: 5.3582 - val_binary_cross_entropy: 26.2639
# Epoch 3/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 48.9334 - binary_accuracy: 0.8669 - overlap_iou: nan - adj_mse: 5.5125 - binary_cross_entropy: 23.7113
# Epoch 00003: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1288s 892ms/step - loss: 48.9458 - binary_accuracy: 0.8670 - overlap_iou: nan - adj_mse: 5.5158 - binary_cross_entropy: 23.7115 - val_loss: 49.4323 - val_binary_accuracy: 0.8937 - val_overlap_iou: 0.0436 - val_adj_mse: 5.3997 - val_binary_cross_entropy: 24.9619
# Epoch 4/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 47.9853 - binary_accuracy: 0.8726 - overlap_iou: nan - adj_mse: 5.5013 - binary_cross_entropy: 23.1679
# Epoch 00004: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1275s 883ms/step - loss: 47.9618 - binary_accuracy: 0.8726 - overlap_iou: nan - adj_mse: 5.4978 - binary_cross_entropy: 23.1586 - val_loss: 46.8889 - val_binary_accuracy: 0.8986 - val_overlap_iou: 0.0499 - val_adj_mse: 5.2951 - val_binary_cross_entropy: 22.8499
# Epoch 5/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 47.1984 - binary_accuracy: 0.8824 - overlap_iou: 0.0458 - adj_mse: 5.4684 - binary_cross_entropy: 22.6278
# Epoch 00005: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1276s 883ms/step - loss: 47.1929 - binary_accuracy: 0.8824 - overlap_iou: 0.0458 - adj_mse: 5.4687 - binary_cross_entropy: 22.6215 - val_loss: 44.7022 - val_binary_accuracy: 0.8782 - val_overlap_iou: 0.0432 - val_adj_mse: 5.2445 - val_binary_cross_entropy: 20.9637
# Epoch 6/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 46.5568 - binary_accuracy: 0.8821 - overlap_iou: 0.0464 - adj_mse: 5.4542 - binary_cross_entropy: 21.9585
# Epoch 00006: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1280s 887ms/step - loss: 46.5416 - binary_accuracy: 0.8821 - overlap_iou: 0.0464 - adj_mse: 5.4529 - binary_cross_entropy: 21.9494 - val_loss: 45.3030 - val_binary_accuracy: 0.8977 - val_overlap_iou: 0.0501 - val_adj_mse: 5.1728 - val_binary_cross_entropy: 21.6531
# Epoch 7/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 45.1405 - binary_accuracy: 0.8864 - overlap_iou: 0.0499 - adj_mse: 5.1953 - binary_cross_entropy: 21.5047
# Epoch 00007: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1273s 882ms/step - loss: 45.1487 - binary_accuracy: 0.8864 - overlap_iou: 0.0499 - adj_mse: 5.1968 - binary_cross_entropy: 21.5078 - val_loss: 44.4893 - val_binary_accuracy: 0.8582 - val_overlap_iou: 0.0387 - val_adj_mse: 5.2239 - val_binary_cross_entropy: 20.6815
# Epoch 8/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 43.0637 - binary_accuracy: 0.8900 - overlap_iou: 0.0545 - adj_mse: 4.8097 - binary_cross_entropy: 20.9666
# Epoch 00008: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1285s 890ms/step - loss: 43.0624 - binary_accuracy: 0.8900 - overlap_iou: 0.0545 - adj_mse: 4.8096 - binary_cross_entropy: 20.9660 - val_loss: 41.1101 - val_binary_accuracy: 0.8905 - val_overlap_iou: 0.0566 - val_adj_mse: 4.5969 - val_binary_cross_entropy: 19.9810
# Epoch 9/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 41.4221 - binary_accuracy: 0.9000 - overlap_iou: 0.0618 - adj_mse: 4.5850 - binary_cross_entropy: 20.2353
# Epoch 00009: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1290s 893ms/step - loss: 41.4142 - binary_accuracy: 0.9000 - overlap_iou: 0.0618 - adj_mse: 4.5842 - binary_cross_entropy: 20.2305 - val_loss: 39.8881 - val_binary_accuracy: 0.9300 - val_overlap_iou: 0.0793 - val_adj_mse: 4.2497 - val_binary_cross_entropy: 19.9716
# Epoch 10/10
# 1443/1444 [============================>.] - ETA: 0s - loss: 39.3094 - binary_accuracy: 0.9026 - overlap_iou: 0.0676 - adj_mse: 4.3247 - binary_cross_entropy: 19.2621
# Epoch 00010: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1285s 890ms/step - loss: 39.2929 - binary_accuracy: 0.9026 - overlap_iou: 0.0676 - adj_mse: 4.3220 - binary_cross_entropy: 19.2571 - val_loss: 38.5430 - val_binary_accuracy: 0.8737 - val_overlap_iou: 0.0543 - val_adj_mse: 4.3683 - val_binary_cross_entropy: 18.4709

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=25, shuffle=True, verbose=1, initial_epoch=17)
# Out:
# Epoch 18/25
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1443/1444 [============================>.] - ETA: 0s - loss: 29.9484 - binary_accuracy: 0.9348 - overlap_iou: 0.1180 - adj_mse: 3.5961 - binary_cross_entropy: 13.2333
# Epoch 00018: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1348s 934ms/step - loss: 29.9510 - binary_accuracy: 0.9348 - overlap_iou: 0.1181 - adj_mse: 3.5969 - binary_cross_entropy: 13.2320 - val_loss: 32.2246 - val_binary_accuracy: 0.9228 - val_overlap_iou: 0.0985 - val_adj_mse: 3.8147 - val_binary_cross_entropy: 14.9229
# Epoch 19/25
# 1443/1444 [============================>.] - ETA: 0s - loss: 29.8982 - binary_accuracy: 0.9366 - overlap_iou: 0.1214 - adj_mse: 3.5765 - binary_cross_entropy: 13.2417
# Epoch 00019: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1284s 889ms/step - loss: 29.8990 - binary_accuracy: 0.9366 - overlap_iou: 0.1214 - adj_mse: 3.5767 - binary_cross_entropy: 13.2386 - val_loss: 43.4737 - val_binary_accuracy: 0.9719 - val_overlap_iou: nan - val_adj_mse: 3.9172 - val_binary_cross_entropy: 25.7500
# Epoch 20/25
# 1443/1444 [============================>.] - ETA: 0s - loss: 28.7012 - binary_accuracy: 0.9417 - overlap_iou: 0.1312 - adj_mse: 3.5039 - binary_cross_entropy: 12.3399
# Epoch 00020: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1266s 877ms/step - loss: 28.6994 - binary_accuracy: 0.9417 - overlap_iou: 0.1311 - adj_mse: 3.5025 - binary_cross_entropy: 12.3442 - val_loss: 41.5253 - val_binary_accuracy: 0.9660 - val_overlap_iou: 0.1711 - val_adj_mse: 3.8030 - val_binary_cross_entropy: 24.2361
# Epoch 21/25
# 1443/1444 [============================>.] - ETA: 0s - loss: 28.3333 - binary_accuracy: 0.9426 - overlap_iou: 0.1332 - adj_mse: 3.4534 - binary_cross_entropy: 12.1430
# Epoch 00021: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1263s 875ms/step - loss: 28.3287 - binary_accuracy: 0.9425 - overlap_iou: 0.1332 - adj_mse: 3.4517 - binary_cross_entropy: 12.1453 - val_loss: 55.3810 - val_binary_accuracy: 0.5656 - val_overlap_iou: 0.0224 - val_adj_mse: 4.3191 - val_binary_cross_entropy: 36.5324
# Epoch 22/25
# 1443/1444 [============================>.] - ETA: 0s - loss: 28.2071 - binary_accuracy: 0.9439 - overlap_iou: 0.1365 - adj_mse: 3.4560 - binary_cross_entropy: 12.0428
# Epoch 00022: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1303s 902ms/step - loss: 28.2201 - binary_accuracy: 0.9439 - overlap_iou: 0.1365 - adj_mse: 3.4575 - binary_cross_entropy: 12.0465 - val_loss: 53.2203 - val_binary_accuracy: 0.9792 - val_overlap_iou: nan - val_adj_mse: 3.7736 - val_binary_cross_entropy: 36.1930
# Epoch 23/25
# 1443/1444 [============================>.] - ETA: 0s - loss: 27.8954 - binary_accuracy: 0.9452 - overlap_iou: 0.1390 - adj_mse: 3.4891 - binary_cross_entropy: 11.6250
# Epoch 00023: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1309s 907ms/step - loss: 27.8877 - binary_accuracy: 0.9452 - overlap_iou: 0.1390 - adj_mse: 3.4880 - binary_cross_entropy: 11.6212 - val_loss: 36.2086 - val_binary_accuracy: 0.9553 - val_overlap_iou: 0.1427 - val_adj_mse: 3.9806 - val_binary_cross_entropy: 18.4861
# Epoch 24/25
# 1443/1444 [============================>.] - ETA: 0s - loss: 28.0826 - binary_accuracy: 0.9460 - overlap_iou: 0.1395 - adj_mse: 3.4837 - binary_cross_entropy: 11.7936
# Epoch 00024: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1299s 900ms/step - loss: 28.0941 - binary_accuracy: 0.9460 - overlap_iou: 0.1395 - adj_mse: 3.4849 - binary_cross_entropy: 11.7991 - val_loss: 33.1908 - val_binary_accuracy: 0.9280 - val_overlap_iou: 0.1036 - val_adj_mse: 3.8362 - val_binary_cross_entropy: 15.9469
# Epoch 25/25
# 1443/1444 [============================>.] - ETA: 0s - loss: 27.8124 - binary_accuracy: 0.9469 - overlap_iou: 0.1408 - adj_mse: 3.4618 - binary_cross_entropy: 11.6193
# Epoch 00025: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1291s 894ms/step - loss: 27.8144 - binary_accuracy: 0.9469 - overlap_iou: 0.1408 - adj_mse: 3.4634 - binary_cross_entropy: 11.6153 - val_loss: 34.0948 - val_binary_accuracy: 0.9417 - val_overlap_iou: 0.1189 - val_adj_mse: 3.8832 - val_binary_cross_entropy: 16.5454

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=30, shuffle=True, verbose=1, initial_epoch=25)
# Out:
# Epoch 26/30
# 1443/1444 [============================>.] - ETA: 0s - loss: 27.5387 - binary_accuracy: 0.9480 - overlap_iou: 0.1434 - adj_mse: 3.4361 - binary_cross_entropy: 11.4140
# Epoch 00026: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1287s 891ms/step - loss: 27.5412 - binary_accuracy: 0.9480 - overlap_iou: 0.1434 - adj_mse: 3.4373 - binary_cross_entropy: 11.4113 - val_loss: 83693.8734 - val_binary_accuracy: 0.9109 - val_overlap_iou: 0.0826 - val_adj_mse: 27890.7790 - val_binary_cross_entropy: 15.4235
# Epoch 27/30
# 1443/1444 [============================>.] - ETA: 0s - loss: 27.4513 - binary_accuracy: 0.9485 - overlap_iou: 0.1455 - adj_mse: 3.4650 - binary_cross_entropy: 11.2815
# Epoch 00027: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1283s 888ms/step - loss: 27.4501 - binary_accuracy: 0.9485 - overlap_iou: 0.1455 - adj_mse: 3.4652 - binary_cross_entropy: 11.2781 - val_loss: 83684.6298 - val_binary_accuracy: 0.9590 - val_overlap_iou: 0.1518 - val_adj_mse: 27886.5880 - val_binary_cross_entropy: 19.0554
# Epoch 28/30
# 1443/1444 [============================>.] - ETA: 0s - loss: 27.1897 - binary_accuracy: 0.9481 - overlap_iou: 0.1464 - adj_mse: 3.3982 - binary_cross_entropy: 11.2448
# Epoch 00028: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1289s 892ms/step - loss: 27.1869 - binary_accuracy: 0.9481 - overlap_iou: 0.1464 - adj_mse: 3.3972 - binary_cross_entropy: 11.2460 - val_loss: 83697.5785 - val_binary_accuracy: 0.8262 - val_overlap_iou: 0.0502 - val_adj_mse: 27890.2906 - val_binary_cross_entropy: 20.8682
# Epoch 29/30
# 1443/1444 [============================>.] - ETA: 0s - loss: 27.5398 - binary_accuracy: 0.9486 - overlap_iou: 0.1465 - adj_mse: 3.4297 - binary_cross_entropy: 11.4845
# Epoch 00029: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1296s 898ms/step - loss: 27.5292 - binary_accuracy: 0.9486 - overlap_iou: 0.1466 - adj_mse: 3.4283 - binary_cross_entropy: 11.4798 - val_loss: 83699.6987 - val_binary_accuracy: 0.9707 - val_overlap_iou: 0.1938 - val_adj_mse: 27889.4632 - val_binary_cross_entropy: 25.5232
# Epoch 30/30
# 1443/1444 [============================>.] - ETA: 0s - loss: 26.1235 - binary_accuracy: 0.9524 - overlap_iou: 0.1574 - adj_mse: 3.3626 - binary_cross_entropy: 10.3713
# Epoch 00030: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1280s 886ms/step - loss: 26.1287 - binary_accuracy: 0.9524 - overlap_iou: 0.1574 - adj_mse: 3.3629 - binary_cross_entropy: 10.3755 - val_loss: 83744.9451 - val_binary_accuracy: 0.9780 - val_overlap_iou: nan - val_adj_mse: 27900.3026 - val_binary_cross_entropy: 38.0197

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=35, shuffle=True, verbose=1, initial_epoch=30)
# Out:
# Epoch 31/35
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1443/1444 [============================>.] - ETA: 0s - loss: 26.8531 - binary_accuracy: 0.9535 - overlap_iou: 0.1595 - adj_mse: 3.4015 - binary_cross_entropy: 10.9520
# Epoch 00031: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1331s 922ms/step - loss: 26.8509 - binary_accuracy: 0.9535 - overlap_iou: 0.1595 - adj_mse: 3.4025 - binary_cross_entropy: 10.9474 - val_loss: 41.3364 - val_binary_accuracy: 0.9633 - val_overlap_iou: 0.1621 - val_adj_mse: 3.9584 - val_binary_cross_entropy: 23.4875
# Epoch 32/35
# 1443/1444 [============================>.] - ETA: 0s - loss: 27.0273 - binary_accuracy: 0.9526 - overlap_iou: 0.1568 - adj_mse: 3.4290 - binary_cross_entropy: 11.0462
# Epoch 00032: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1281s 887ms/step - loss: 27.0223 - binary_accuracy: 0.9526 - overlap_iou: 0.1568 - adj_mse: 3.4286 - binary_cross_entropy: 11.0424 - val_loss: 36.0206 - val_binary_accuracy: 0.9030 - val_overlap_iou: 0.0829 - val_adj_mse: 4.2768 - val_binary_cross_entropy: 17.3386
# Epoch 33/35
# 1443/1444 [============================>.] - ETA: 0s - loss: 27.0236 - binary_accuracy: 0.9524 - overlap_iou: 0.1570 - adj_mse: 3.4017 - binary_cross_entropy: 11.1266
# Epoch 00033: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1289s 892ms/step - loss: 27.0517 - binary_accuracy: 0.9524 - overlap_iou: 0.1570 - adj_mse: 3.4037 - binary_cross_entropy: 11.1461 - val_loss: 60.1548 - val_binary_accuracy: 0.9777 - val_overlap_iou: nan - val_adj_mse: 4.1515 - val_binary_cross_entropy: 41.1860
# Epoch 34/35
# 1443/1444 [============================>.] - ETA: 0s - loss: 30.0028 - binary_accuracy: 0.9531 - overlap_iou: 0.1557 - adj_mse: 3.4780 - binary_cross_entropy: 13.7725
# Epoch 00034: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1303s 903ms/step - loss: 29.9975 - binary_accuracy: 0.9531 - overlap_iou: 0.1558 - adj_mse: 3.4766 - binary_cross_entropy: 13.7730 - val_loss: 53.2044 - val_binary_accuracy: 0.9722 - val_overlap_iou: nan - val_adj_mse: 3.9657 - val_binary_cross_entropy: 35.4299
# Epoch 35/35
# 1443/1444 [============================>.] - ETA: 0s - loss: 31.4199 - binary_accuracy: 0.9515 - overlap_iou: 0.1533 - adj_mse: 3.5042 - binary_cross_entropy: 15.0858
# Epoch 00035: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1305s 904ms/step - loss: 31.4523 - binary_accuracy: 0.9515 - overlap_iou: 0.1532 - adj_mse: 3.5062 - binary_cross_entropy: 15.1095 - val_loss: 42.5646 - val_binary_accuracy: 0.9550 - val_overlap_iou: 0.1414 - val_adj_mse: 3.9103 - val_binary_cross_entropy: 24.9522

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=40, shuffle=True, verbose=1, initial_epoch=35)
# Out:
# Epoch 36/40
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1443/1444 [============================>.] - ETA: 0s - loss: 32.3526 - binary_accuracy: 0.9487 - overlap_iou: 0.1431 - adj_mse: 3.5787 - binary_cross_entropy: 15.7455
# Epoch 00036: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1369s 948ms/step - loss: 32.3751 - binary_accuracy: 0.9487 - overlap_iou: 0.1431 - adj_mse: 3.5800 - binary_cross_entropy: 15.7631 - val_loss: 189648.6999 - val_binary_accuracy: 0.9547 - val_overlap_iou: 0.1363 - val_adj_mse: 63206.0435 - val_binary_cross_entropy: 24.3771
# Epoch 37/40
# 1443/1444 [============================>.] - ETA: 0s - loss: 33.0716 - binary_accuracy: 0.9481 - overlap_iou: 0.1414 - adj_mse: 3.6404 - binary_cross_entropy: 16.2396
# Epoch 00037: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1292s 895ms/step - loss: 33.0665 - binary_accuracy: 0.9481 - overlap_iou: 0.1414 - adj_mse: 3.6412 - binary_cross_entropy: 16.2317 - val_loss: 189684.5152 - val_binary_accuracy: 0.9413 - val_overlap_iou: 0.1158 - val_adj_mse: 63219.0228 - val_binary_cross_entropy: 21.5439
# Epoch 38/40
# 1443/1444 [============================>.] - ETA: 0s - loss: 33.3754 - binary_accuracy: 0.9486 - overlap_iou: 0.1418 - adj_mse: 3.5875 - binary_cross_entropy: 16.7109
# Epoch 00038: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1301s 901ms/step - loss: 33.3633 - binary_accuracy: 0.9486 - overlap_iou: 0.1417 - adj_mse: 3.5867 - binary_cross_entropy: 16.7035 - val_loss: 189679.4423 - val_binary_accuracy: 0.9385 - val_overlap_iou: 0.1136 - val_adj_mse: 63217.1751 - val_binary_cross_entropy: 22.1268
# Epoch 39/40
# 1443/1444 [============================>.] - ETA: 0s - loss: 33.5854 - binary_accuracy: 0.9474 - overlap_iou: 0.1398 - adj_mse: 3.5764 - binary_cross_entropy: 16.9502
# Epoch 00039: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1306s 904ms/step - loss: 33.6015 - binary_accuracy: 0.9474 - overlap_iou: 0.1400 - adj_mse: 3.5769 - binary_cross_entropy: 16.9628 - val_loss: 189748.7624 - val_binary_accuracy: 0.9602 - val_overlap_iou: 0.1293 - val_adj_mse: 63237.5779 - val_binary_cross_entropy: 29.7709
# Epoch 40/40
# 1443/1444 [============================>.] - ETA: 0s - loss: 32.6834 - binary_accuracy: 0.9516 - overlap_iou: 0.1474 - adj_mse: 3.5383 - binary_cross_entropy: 16.1871
# Epoch 00040: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1300s 900ms/step - loss: 32.6831 - binary_accuracy: 0.9516 - overlap_iou: 0.1474 - adj_mse: 3.5376 - binary_cross_entropy: 16.1897 - val_loss: 189677.8243 - val_binary_accuracy: 0.9418 - val_overlap_iou: 0.1140 - val_adj_mse: 63216.5567 - val_binary_cross_entropy: 22.1464

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=50, shuffle=True, verbose=1, initial_epoch=40)
# Out:
# Epoch 41/50
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1443/1444 [============================>.] - ETA: 0s - loss: 30.8849 - binary_accuracy: 0.9543 - overlap_iou: 0.1584 - adj_mse: 3.5052 - binary_cross_entropy: 14.5364
# Epoch 00041: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1335s 925ms/step - loss: 30.8919 - binary_accuracy: 0.9543 - overlap_iou: 0.1585 - adj_mse: 3.5063 - binary_cross_entropy: 14.5387 - val_loss: 40.9855 - val_binary_accuracy: 0.9518 - val_overlap_iou: 0.1356 - val_adj_mse: 3.8574 - val_binary_cross_entropy: 23.4728
# Epoch 42/50
# 1443/1444 [============================>.] - ETA: 0s - loss: 31.6534 - binary_accuracy: 0.9522 - overlap_iou: 0.1537 - adj_mse: 3.5468 - binary_cross_entropy: 15.1621
# Epoch 00042: saving model to yolo10_2_512.h5
# 1444/1444 [==============================] - 1282s 888ms/step - loss: 31.6609 - binary_accuracy: 0.9522 - overlap_iou: 0.1537 - adj_mse: 3.5473 - binary_cross_entropy: 15.1652 - val_loss: 47.5945 - val_binary_accuracy: 0.9656 - val_overlap_iou: 0.1510 - val_adj_mse: 3.9723 - val_binary_cross_entropy: 29.3175
# Epoch 43/50
#  581/1444 [===========>..................] - ETA: 11:37 - loss: 30.8578 - binary_accuracy: 0.9510 - overlap_iou: 0.1494 - adj_mse: 3.4356 - binary_cross_entropy: 14.7766
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-94226f5d1b71> in <module>()
# ----> 1 history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=50, shuffle=True, verbose=1, initial_epoch=40)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1777         use_multiprocessing=use_multiprocessing,
#    1778         shuffle=shuffle,
# -> 1779         initial_epoch=initial_epoch)
#    1780
#    1781   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     202
#     203         outs = model.train_on_batch(
# --> 204             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     205
#     206         if not isinstance(outs, list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1550
#    1551       self._make_train_function()
# -> 1552       outputs = self.train_function(ins)
#    1553
#    1554     if len(outputs) == 1:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    2912       self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    2913
# -> 2914     fetched = self._callable_fn(*array_vals)
#    2915     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2916     return fetched[:len(self.outputs)]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %% [markdown]
# ## Sample Predictions

# %%
THRESHOLD = 0.5
OVERLAP = 0.3
# look at some sample predictions
samples = np.random.choice(valid_filenames, size=10, replace=False)

coords = np.arange(0, 1024, 256)
overall_ious = []

for filename in samples:
    # load the image
    img = pydicom.dcmread(os.path.join(train_dicom_dir, filename)).pixel_array
    
    filename = filename.split('.')[0]
    
    f, ax = plt.subplots(figsize=(6, 6))
    plt.imshow(img)
    
    # initialize our lists
    ious = []
    truths = []
    boxes = []
    
    # draw the truth boxes
    if filename in pneumonia_locations:
        locs = pneumonia_locations[filename]
        for i in range(4):
            for j in range(4):
                pixel_data = locs[i,j,:]
                if pixel_data[0] > 0.5:
                    x, y, w, h = pixel_data[1:]
                    
                    # unnormalize the data
                    w = w * 1024
                    h = h * 1024
                    
                    x = unnorm(x, j, 256)
                    y = unnorm(y, i, 256)
                    
                    # get the corners
                    x = x - (w // 2)
                    y = y - (h // 2)
                    
                    x = int(x)
                    y = int(y)
                    w = int(w)
                    h = int(h)
                    locs[i,j,:] = [1, x, y, w, h]
                    print("Truth:", i, j, x, y, w, h)
                    truths.append([x, y, w, h])
                    
                    rect = patches.Rectangle((x,y),w,h,linewidth=1,edgecolor='b',facecolor='none')
                    ax.add_patch(rect)
                    
    # predict the image
    img = resize(img, (IMAGE_SIZE, IMAGE_SIZE), mode='reflect')
    yhat = model.predict(img.reshape(1, IMAGE_SIZE, IMAGE_SIZE, 1))
    yhat = sigmoid(yhat)
    conf = np.squeeze(yhat)[:,:,0]
    bboxes = np.squeeze(yhat)[:,:,1:]    
    pred_boxes = np.zeros_like(bboxes)
    
    # loop through our predictions
    for i in range(4):
        for j in range(4):
            conf_ = conf[i,j]
            # if we have a prediction
            if conf_ > THRESHOLD:
                x,y,w,h = bboxes[i,j,:]
                
                # unnormalize the data
                w = w * 1024
                h = h * 1024

                x = unnorm(x, j, 256)
                y = unnorm(y, i, 256)
                
                # convert to upper left corner from center
                x = np.maximum(x - (w // 2), 0)
                y = np.maximum(y - (h // 2), 0)
                
                x = int(x)
                y = int(y)
                w = int(w)
                h = int(h)
                
                pred_boxes[i,j,:] = [x, y, w, h]
                
                print("Pred:", i, j, "conf:", conf_, x, y, w, h)
                
                # if the boxes have width and height add them to our list
                if w > 30 and h > 30:
                    boxes.append([x,y,w,h])
                
    # do non-max suppression of our boxes
    nms_boxes = non_max_suppression_fast(np.array(boxes), OVERLAP)
    
    # plot our boxes
    for box in nms_boxes:
        x,y,w,h = box
        print(x, y, w, h)
        rect = patches.Rectangle((x,y), w, h, linewidth=1, edgecolor='r', facecolor='none')
        ax.add_patch(rect)
    
    ## calculate the IOU
    true_area = 0
    # get the area of the true boxes
    for true_box in truths:
        x, y, w, h = true_box
        area = w * h
        true_area += area
        
    pred_area = 0
    # get the area of the predictions
    for pred_box in nms_boxes:
        x, y, w, h = pred_box
        area = w * h
        pred_area += area
        
    overall_intersect_area = 0
    # get the IOU by checking all combinations of boxes
    for true_box in truths:
        x1_t, y1_t, w_t, h_t = true_box
        for pred_box in nms_boxes:
            x1_p, y1_p, w_p, h_p = pred_box
            
            # get the far corners
            x2_p, y2_p = x1_p + w_p, y1_p + h_p
            x2_t, y2_t = x1_t + w_t, y1_t + h_t
        
            # get corners of intersection
            x1_i = np.maximum(x1_p, x1_t)
            y1_i = np.maximum(y1_p, y1_t)
            x2_i = np.minimum(x2_p, x2_t)
            y2_i = np.minimum(y2_p, y2_t)

            # get area of intersect
            i_w, i_h = x2_i - x1_i, y2_i - y1_i
            
            # trap for negative numbers
            i_w = np.maximum(i_w, 0)
            i_h = np.maximum(i_h, 0)
            
            intersect_area = i_w * i_h
            overall_intersect_area += intersect_area
            
            
    for item in coords:
        plt.axvline(item, linewidth=0.5)
        plt.axhline(item, linewidth=0.5)
    
    print("True:", true_area, "Pred:", pred_area, "Intersect:", overall_intersect_area)
    union_area = true_area + pred_area - overall_intersect_area
    
    iou = overall_intersect_area / (union_area + 1e-6)
    print("IOU:", iou)
    
    if len(truths) or len(nms_boxes):
      overall_ious.append(iou)
      
    plt.show()
    
print("Overall Mean IOU:", np.mean(overall_ious))
# Out:
# Pred: 1 1 conf: 0.99656624 235 208 209 272
# Pred: 1 2 conf: 0.9829202 568 251 217 329
# Pred: 2 2 conf: 0.9995553 545 451 233 397
# 545 451 233 397
# 235 208 209 272
# True: 0 Pred: 149349 Intersect: 0
# IOU: 0.0
# Pred: 1 1 conf: 0.9984841 223 125 251 484
# Pred: 1 2 conf: 0.9998022 558 156 252 510
# Pred: 2 1 conf: 0.84842604 182 389 247 476
# Pred: 2 2 conf: 0.99986696 511 370 256 507
# 511 370 256 507
# 182 389 247 476
# True: 0 Pred: 247364 Intersect: 0
# IOU: 0.0
# Truth: 2 1 270 475 118 151
# Truth: 2 2 505 504 220 226
# Pred: 1 1 conf: 0.8925821 228 188 225 362
# Pred: 1 2 conf: 0.9979188 488 185 224 346
# Pred: 2 1 conf: 0.9918469 242 444 231 383
# Pred: 2 2 conf: 0.9998615 496 429 235 398
# 496 429 235 398
# 242 444 231 383
# 228 188 225 362
# 488 185 224 346
# True: 67538 Pred: 340957 Intersect: 81977
# IOU: 0.25106425985626807
# Truth: 1 2 512 288 253 445
# Truth: 2 0 98 506 280 212
# Pred: 2 1 conf: 0.7328408 236 473 207 273
# 236 473 207 273
# True: 171945 Pred: 56511 Intersect: 30104
# IOU: 0.15177058965802326
# Truth: 0 1 253 148 183 201
# Truth: 1 2 583 158 161 243
# Truth: 2 2 652 546 76 72
# Pred: 1 1 conf: 0.999984 201 62 265 539
# Pred: 1 2 conf: 0.9997985 482 67 267 554
# Pred: 2 1 conf: 0.9397558 167 361 253 477
# Pred: 2 2 conf: 0.5247158 528 372 256 499
# 528 372 256 499
# 167 361 253 477
# True: 81378 Pred: 248425 Intersect: 10141
# IOU: 0.031724133616032796
# Pred: 1 1 conf: 0.987715 254 60 269 575
# Pred: 1 2 conf: 0.94024 533 65 275 620
# Pred: 2 1 conf: 0.51549155 284 453 228 370
# Pred: 2 2 conf: 0.6408433 533 396 251 486
# Pred: 2 3 conf: 0.9744037 700 394 241 433
# 533 396 251 486
# 284 453 228 370
# 254 60 269 575
# True: 0 Pred: 361021 Intersect: 0
# IOU: 0.0
# Pred: 1 1 conf: 0.9969754 298 140 253 507
# Pred: 1 2 conf: 0.9998903 522 205 234 423
# Pred: 2 2 conf: 0.7509717 495 445 221 326
# 495 445 221 326
# 298 140 253 507
# True: 0 Pred: 200317 Intersect: 0
# IOU: 0.0
# Truth: 2 1 232 502 131 157
# Pred: 1 1 conf: 0.99993145 214 96 252 456
# Pred: 2 2 conf: 0.98140097 481 354 259 523
# 481 354 259 523
# 214 96 252 456
# True: 20567 Pred: 250369 Intersect: 6550
# IOU: 0.02477438290974267
# Pred: 1 2 conf: 0.9146063 569 261 217 339
# Pred: 2 1 conf: 0.9840806 298 440 228 352
# Pred: 2 2 conf: 0.961627 590 472 221 325
# 590 472 221 325
# 298 440 228 352
# True: 0 Pred: 152081 Intersect: 0
# IOU: 0.0
# Pred: 1 1 conf: 0.999186 250 220 214 308
# Pred: 1 2 conf: 0.95532745 517 234 208 281
# Pred: 2 1 conf: 0.9927194 236 484 211 294
# Pred: 2 2 conf: 0.99480516 514 476 222 351
# Pred: 2 3 conf: 0.51323366 791 483 221 358
# 791 483 221 358
# 514 476 222 351
# 236 484 211 294
# 250 220 214 308
# 517 234 208 281
# True: 0 Pred: 343434 Intersect: 0
# IOU: 0.0
# Overall Mean IOU: 0.04593333660400668

# %% [markdown]
# # Predict test images

# %%
THRESHOLD = 0.5

# load and shuffle filenames
folder = './stage_1_test_images'
test_filenames = os.listdir(folder)
print('n test samples:', len(test_filenames))

# create test generator with predict flag set to True
test_gen = generator(folder, test_filenames, None, batch_size=3, image_size=IMAGE_SIZE, shuffle=False, predict=True)

# create submission dictionary
submission_dict = {}
# loop through testset
for imgs, filenames in test_gen:
    
    # predict batch of images
    yhats = model.predict(imgs)
    
    # apply sigmoid
    yhats = sigmoid(yhats)
    
    # loop through batch
    for yhat, filename in zip(yhats, filenames):
        predictionString = ""
        boxes = []
        for i in range(4):
            for j in range(4):
                conf = yhat[i, j, 0]
                if conf > THRESHOLD:
                    x, y, w, h = yhat[i,j, 1:]
                    
                    # possible thresholds to keep our boxes within reasonable sizes?
                    if True: #w < 600 and h < 1000:
                        w = w * 1024
                        h = h * 1024

                        x = unnorm(x, j, 256)
                        y = unnorm(y, i, 256)

                        # convert to upper left corner from center
                        x = x - (w // 2)
                        y = y - (h // 2)
                        
                        if w > 20 and h > 20:
                            # make sure our boxes don't run off the edges of the images
                            w = np.minimum(w, 1024 - x)
                            h = np.minimum(h, 1024 - y)
                            boxes.append([x,y,w,h])

        # do our non-max suppression here
        boxes = non_max_suppression_fast(np.array(boxes), 0.3)
        
        # loop through our suppressed boxes and creat the prediction string
        for box in boxes:
            x,y,w,h = box
            
            x = int(x)
            y = int(y)
            w = int(w)
            h = int(h)
        
            # create the prediction string
            predictionString += str(0.9) + ' ' + str(x) + ' ' + str(y) + ' ' + str(w) + ' ' + str(h) + ' '
            
        # add filename and predictionString to dictionary
        filename = filename.split('.')[0]
        submission_dict[filename] = predictionString

    # stop if we've got them all
    if len(submission_dict) >= len(test_filenames):
        break
    
# save dictionary as csv file
sub = pd.DataFrame.from_dict(submission_dict,orient='index')
sub.index.names = ['patientId']
sub.columns = ['PredictionString']

now = datetime.datetime.now()
today = str(now)[:10]
submission_file = today + "_yolo_submission.csv" 
sub.to_csv(submission_file)
# Out:
# n test samples: 1000

# %%
# !kaggle competitions submit -c rsna-pneumonia-detection-challenge -f {submission_file} -m "YOLOv11 512x512 50 epochs"
# Out:
# Successfully submitted to RSNA Pneumonia Detection Challenge

# %%
save_file_to_drive("submission.csv", "submission.csv")
save_file_to_drive(CHECKPOINT_PATH, CHECKPOINT_PATH)

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# !gsutil cp ./{CHECKPOINT_PATH} gs://{bucket_name}/
# Out:
# Updated property [core/project].
# Copying file://./yolo10_2_512.h5 [Content-Type=application/octet-stream]...
# \
# Operation completed over 1 objects/71.5 MiB.
