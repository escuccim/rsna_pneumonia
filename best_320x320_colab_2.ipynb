# %% [markdown]
# # Approach
#
# * Firstly a convolutional neural network is used to segment the image, using the bounding boxes directly as a mask.
# * Secondly connected components is used to separate multiple areas of predicted pneumonia.
# * Finally a bounding box is simply drawn around every connected component.
#
# # Network
#
# * The network consists of a number of residual blocks with convolutions and downsampling blocks with max pooling.
# * At the end of the network a single upsampling layer converts the output to the same shape as the input.
#
# As the input to the network is 256 by 256 (instead of the original 1024 by 1024) and the network downsamples a number of times without any meaningful upsampling (the final upsampling is just to match in 256 by 256 mask) the final prediction is very crude. If the network downsamples 4 times the final bounding boxes can only change with at least 16 pixels.
#
# **Edit by EAS** - Change input image size to 320x320.

# %%
# install dependencies not included by Colab
# use pip3 to ensure compatibility w/ Google Deep Learning Images 
# !pip install -q pydicom 
# !pip install -q imgaug 
# !pip install -q kaggle
# !pip install -q tqdm 
# !pip install -q PyDrive

# %%
import os
import csv
import random
import pydicom
import numpy as np
import pandas as pd
from skimage import measure
from skimage.transform import resize

import tensorflow as tf
from tensorflow import keras

from matplotlib import pyplot as plt

# %%
from google.colab import auth
from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build

auth.authenticate_user()

drive_service = build('drive', 'v3')

def save_file_to_drive(name, path):
    file_metadata = {
      'name': name,
      'mimeType': 'application/octet-stream'
     }

    media = MediaFileUpload(path, 
                    mimetype='application/octet-stream',
                    resumable=True)

    created = drive_service.files().create(body=file_metadata,
                                   media_body=media,
                                   fields='id').execute()

    print('File ID: {}'.format(created.get('id')))

    return created

# %%
# enter your Kaggle credentionals here
os.environ['KAGGLE_USERNAME']="skooch"
os.environ['KAGGLE_KEY']="42f8a02ee92cc773d1dbe66565673ad3"

# %%
# If you are unable to download the competition dataset, check to see if you have 
# accepted the user agreement on the competition website. 
if not os.path.exists("./stage_1_detailed_class_info.csv.zip"):
    # !kaggle competitions download -c rsna-pneumonia-detection-challenge
# Out:
# Downloading GCP%20Credits%20Request%20Link%20-%20RSNA.txt to /content
#   0% 0.00/55.0 [00:00<?, ?B/s]
# 100% 55.0/55.0 [00:00<00:00, 37.3kB/s]
# Downloading stage_1_detailed_class_info.csv.zip to /content
#   0% 0.00/561k [00:00<?, ?B/s]
# 100% 561k/561k [00:00<00:00, 76.2MB/s]
# Downloading stage_1_sample_submission.csv to /content
#   0% 0.00/51.8k [00:00<?, ?B/s]
# 100% 51.8k/51.8k [00:00<00:00, 40.4MB/s]
# Downloading stage_1_train_labels.csv.zip to /content
#   0% 0.00/634k [00:00<?, ?B/s]
# 100% 634k/634k [00:00<00:00, 99.2MB/s]
# Downloading stage_1_test_images.zip to /content
#  89% 112M/126M [00:00<00:00, 122MB/s]
# 100% 126M/126M [00:00<00:00, 168MB/s]
# Downloading stage_1_train_images.zip to /content
#  99% 3.15G/3.17G [00:24<00:00, 139MB/s]
# 100% 3.17G/3.17G [00:24<00:00, 139MB/s]

# %%
# unzipping takes a few minutes
if not os.path.exists("./stage_1_train_labels.csv"):
    print("Unzipping...")
    # !unzip -q -o stage_1_test_images.zip -d stage_1_test_images
    # !unzip -q -o stage_1_train_images.zip -d stage_1_train_images
    # !unzip -q -o stage_1_train_labels.csv.zip
# Out:
# Unzipping...

# %% [markdown]
# # Load pneumonia locations
#
# Table contains [filename : pneumonia location] pairs per row.
# * If a filename contains multiple pneumonia, the table contains multiple rows with the same filename but different pneumonia locations.
# * If a filename contains no pneumonia it contains a single row with an empty pneumonia location.
#
# The code below loads the table and transforms it into a dictionary.
# * The dictionary uses the filename as key and a list of pneumonia locations in that filename as value.
# * If a filename is not present in the dictionary it means that it contains no pneumonia.

# %%
ROOT_DIR = "./"

train_dicom_dir = os.path.join(ROOT_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(ROOT_DIR, 'stage_1_test_images')
print("Train dir:", train_dicom_dir)
# Out:
# Train dir: ./stage_1_train_images

# %%
# empty dictionary
pneumonia_locations = {}
# load table
with open(os.path.join('./stage_1_train_labels.csv'), mode='r') as infile:
    # open reader
    reader = csv.reader(infile)
    # skip header
    next(reader, None)
    # loop through rows
    for rows in reader:
        # retrieve information
        filename = rows[0]
        location = rows[1:5]
        pneumonia = rows[5]
        # if row contains pneumonia add label to dictionary
        # which contains a list of pneumonia locations per filename
        if pneumonia == '1':
            # convert string to float to int
            location = [int(float(i)) for i in location]
            # save pneumonia location in dictionary
            if filename in pneumonia_locations:
                pneumonia_locations[filename].append(location)
            else:
                pneumonia_locations[filename] = [location]

# %% [markdown]
# # Load filenames

# %%
# load and shuffle filenames
random.seed(1977)
folder = './stage_1_train_images'
filenames = os.listdir(folder)
random.shuffle(filenames)
# split into train and validation filenames
n_valid_samples = 2560
train_filenames = filenames[n_valid_samples:]
valid_filenames = filenames[:n_valid_samples]
print('n train samples', len(train_filenames))
print('n valid samples', len(valid_filenames))
n_train_samples = len(filenames) - n_valid_samples
# Out:
# n train samples 23124
# n valid samples 2560

# %% [markdown]
#  # Data generator
#
# The dataset is too large to fit into memory, so we need to create a generator that loads data on the fly.
#
# * The generator takes in some filenames, batch_size and other parameters.
#
# * The generator outputs a random batch of numpy images and numpy masks.

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 320
CHECKPOINT_PATH = "model9_320.h5"

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# !gsutil cp gs://{bucket_name}/{CHECKPOINT_PATH} ./{CHECKPOINT_PATH}
# Out:
# Updated property [core/project].
# CommandException: No URLs matched: gs://pneumonia/model9_320.h5

# %%
class generator(keras.utils.Sequence):
    
    def __init__(self, folder, filenames, pneumonia_locations=None, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=False, predict=False):
        self.folder = folder
        self.filenames = filenames
        self.pneumonia_locations = pneumonia_locations
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.predict = predict
        self.on_epoch_end()
        
    def __load__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # create empty mask
        msk = np.zeros(img.shape)
        # get filename without extension
        filename = filename.split('.')[0]
        # if image contains pneumonia
        if filename in pneumonia_locations:
            # loop through pneumonia
            for location in pneumonia_locations[filename]:
                # add 1's at the location of the pneumonia
                x, y, w, h = location
                msk[y:y+h, x:x+w] = 1
        # if augment then horizontal flip half the time
        if self.augment and random.random() > 0.5:
            img = np.fliplr(img)
            msk = np.fliplr(msk)
            
        # small shifts to images
        if self.augment:
            h_offset = np.random.randint(low=0, high=15)
            v_offset = np.random.randint(low=0, high=15)
            # crop the images
            img = img[v_offset:,h_offset:]
            msk = msk[v_offset:,h_offset:]
            
        # resize both image and mask
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        msk = resize(msk, (self.image_size, self.image_size), mode='reflect') > 0.5
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        msk = np.expand_dims(msk, -1)
        return img, msk
    
    def __loadpredict__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # resize image
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        return img
        
    def __getitem__(self, index):
        # select batch
        filenames = self.filenames[index*self.batch_size:(index+1)*self.batch_size]
        # predict mode: return images and filenames
        if self.predict:
            # load files
            imgs = [self.__loadpredict__(filename) for filename in filenames]
            # create numpy batch
            imgs = np.array(imgs)
            return imgs, filenames
        # train mode: return images and masks
        else:
            # load files
            items = [self.__load__(filename) for filename in filenames]
            # unzip images and masks
            imgs, msks = zip(*items)
            # create numpy batch
            imgs = np.array(imgs)
            msks = np.array(msks)
            return imgs, msks
        
    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.filenames)
        
    def __len__(self):
        if self.predict:
            # return everything
            return int(np.ceil(len(self.filenames) / self.batch_size))
        else:
            # return full batches only
            return int(len(self.filenames) / self.batch_size)

# %% [markdown]
# # Network

# %%
def create_downsample(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 1, padding='same', use_bias=False)(x)
    x = keras.layers.MaxPool2D(2)(x)
    return x

def create_resblock(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    return keras.layers.add([x, inputs])

def create_network(input_size, channels, n_blocks=2, depth=4):
    # input
    inputs = keras.Input(shape=(input_size, input_size, 1))
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(inputs)
    # residual blocks
    for d in range(depth):
        channels = channels * 2
        x = create_downsample(channels, x)
        for b in range(n_blocks):
            x = create_resblock(channels, x)
    # output
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(1, 1, activation='sigmoid')(x)
    outputs = keras.layers.UpSampling2D(2**depth)(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # Train network

# %%
# define iou or jaccard loss function
def iou_loss(y_true, y_pred):
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true * y_pred)
    score = (intersection + 1.) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection + 1.)
    return 1 - score

# combine bce loss and iou loss
def iou_bce_loss(y_true, y_pred):
    return 0.5 * keras.losses.binary_crossentropy(y_true, y_pred) + 0.5 * iou_loss(y_true, y_pred)

# mean iou as a metric
def mean_iou(y_true, y_pred):
    y_pred = tf.round(y_pred)
    intersect = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    smooth = tf.ones(tf.shape(intersect))
    return tf.reduce_mean((intersect + smooth) / (union - intersect + smooth))

# mean iou with any image with no truth counted as 0
def adj_mean_iou(y_true, y_pred):
    y_pred = tf.round(y_pred)
    y_true_pos = tf.reduce_max(y_true, axis=[1, 2, 3])
    
    intersect = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    smooth = tf.ones(tf.shape(intersect))
    
    return tf.reduce_mean((y_true_pos * (intersect + smooth)) / (union - intersect + smooth))      
  
# create network and compiler
model = create_network(input_size=320, channels=32, n_blocks=2, depth=4)
model.compile(optimizer='adam',
              loss=iou_bce_loss,
              metrics=['accuracy', mean_iou, adj_mean_iou])

# cosine learning rate annealing
def cosine_annealing(x):
    lr = 0.002
    epochs = 40
    return lr*(np.cos(np.pi*x/epochs)+1.)/2
  
learning_rate = tf.keras.callbacks.LearningRateScheduler(cosine_annealing)
checkpoint = keras.callbacks.ModelCheckpoint(CHECKPOINT_PATH, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=True, mode='auto', period=1)

# create train and validation generators
folder = './stage_1_train_images'
train_gen = generator(folder, train_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=True, predict=False)
valid_gen = generator(folder, valid_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=False, predict=False)

print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 320, 320, 1)  0
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 320, 320, 32) 288         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 320, 320, 32) 128         conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 320, 320, 32) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 320, 320, 64) 2048        leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 160, 160, 64) 0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 160, 160, 64) 256         max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 160, 160, 64) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 160, 160, 64) 36864       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 160, 160, 64) 256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 160, 160, 64) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 160, 160, 64) 36864       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 160, 160, 64) 0           conv2d_47[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 160, 160, 64) 256         add_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 160, 160, 64) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 160, 160, 64) 36864       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 160, 160, 64) 256         conv2d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 160, 160, 64) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 160, 160, 64) 36864       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 160, 160, 64) 0           conv2d_49[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 160, 160, 64) 256         add_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 160, 160, 64) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 160, 160, 128 8192        leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 80, 80, 128)  0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 80, 80, 128)  512         max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 80, 80, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 80, 80, 128)  147456      leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 80, 80, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 80, 80, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 80, 80, 128)  147456      leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 80, 80, 128)  0           conv2d_52[0][0]
#                                                                  max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 80, 80, 128)  512         add_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 80, 80, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 80, 80, 128)  147456      leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 80, 80, 128)  512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 80, 80, 128)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 80, 80, 128)  147456      leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 80, 80, 128)  0           conv2d_54[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 80, 80, 128)  512         add_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 80, 80, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 80, 80, 256)  32768       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 40, 40, 256)  0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 40, 40, 256)  1024        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 40, 40, 256)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 40, 40, 256)  589824      leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 40, 40, 256)  1024        conv2d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 40, 40, 256)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 40, 40, 256)  589824      leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 40, 40, 256)  0           conv2d_57[0][0]
#                                                                  max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 40, 40, 256)  1024        add_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 40, 40, 256)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 40, 40, 256)  589824      leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 40, 40, 256)  1024        conv2d_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 40, 40, 256)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 40, 40, 256)  589824      leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 40, 40, 256)  0           conv2d_59[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 40, 40, 256)  1024        add_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 40, 40, 256)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 40, 40, 512)  131072      leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 20, 20, 512)  0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 20, 20, 512)  2048        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 20, 20, 512)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 20, 20, 512)  2359296     leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 20, 20, 512)  2048        conv2d_61[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 20, 20, 512)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 20, 20, 512)  2359296     leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 20, 20, 512)  0           conv2d_62[0][0]
#                                                                  max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 20, 20, 512)  2048        add_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 20, 20, 512)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 20, 20, 512)  2359296     leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 20, 20, 512)  2048        conv2d_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 20, 20, 512)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 20, 20, 512)  2359296     leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 20, 20, 512)  0           conv2d_64[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 20, 20, 512)  2048        add_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 20, 20, 512)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 20, 20, 1)    513         leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 320, 320, 1)  0           conv2d_65[0][0]
# ==================================================================================================
# Total params: 12,727,969
# Trainable params: 12,718,305
# Non-trainable params: 9,664
# __________________________________________________________________________________________________
# None

# %%
model.load_weights(CHECKPOINT_PATH)

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=15, shuffle=True)
# Out:
# Epoch 1/15
# 1444/1445 [============================>.] - ETA: 0s - loss: 0
# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=25, shuffle=True, initial_epoch=18)
# Out:
# Epoch 19/25
# 721/722 [============================>.] - ETA: 1s - loss: 0.3764 - acc: 0.9741 - mean_iou: 0.7368 - adj_mean_iou: 0.0761
# Epoch 00019: saving model to model9_320.h5
# 722/722 [==============================] - 1415s 2s/step - loss: 0.3763 - acc: 0.9741 - mean_iou: 0.7367 - adj_mean_iou: 0.0761 - val_loss: 0.3882 - val_acc: 0.9739 - val_mean_iou: 0.7371 - val_adj_mean_iou: 0.0714
# Epoch 20/25
# 721/722 [============================>.] - ETA: 1s - loss: 0.3763 - acc: 0.9742 - mean_iou: 0.7383 - adj_mean_iou: 0.0762
# Epoch 00020: saving model to model9_320.h5
# 722/722 [==============================] - 1388s 2s/step - loss: 0.3764 - acc: 0.9742 - mean_iou: 0.7382 - adj_mean_iou: 0.0761 - val_loss: 0.3852 - val_acc: 0.9735 - val_mean_iou: 0.7157 - val_adj_mean_iou: 0.0762
# Epoch 21/25
# 721/722 [============================>.] - ETA: 1s - loss: 0.3754 - acc: 0.9743 - mean_iou: 0.7372 - adj_mean_iou: 0.0773
# Epoch 00021: saving model to model9_320.h5
# 722/722 [==============================] - 1383s 2s/step - loss: 0.3755 - acc: 0.9743 - mean_iou: 0.7370 - adj_mean_iou: 0.0773 - val_loss: 0.3842 - val_acc: 0.9736 - val_mean_iou: 0.7258 - val_adj_mean_iou: 0.0765
# Epoch 22/25
# 721/722 [============================>.] - ETA: 1s - loss: 0.3719 - acc: 0.9746 - mean_iou: 0.7397 - adj_mean_iou: 0.0786
# Epoch 00022: saving model to model9_320.h5
# 722/722 [==============================] - 1393s 2s/step - loss: 0.3718 - acc: 0.9746 - mean_iou: 0.7398 - adj_mean_iou: 0.0785 - val_loss: 0.3839 - val_acc: 0.9737 - val_mean_iou: 0.7244 - val_adj_mean_iou: 0.0758
# Epoch 23/25
# 721/722 [============================>.] - ETA: 1s - loss: 0.3716 - acc: 0.9747 - mean_iou: 0.7420 - adj_mean_iou: 0.0784
# Epoch 00023: saving model to model9_320.h5
# 722/722 [==============================] - 1399s 2s/step - loss: 0.3716 - acc: 0.9747 - mean_iou: 0.7420 - adj_mean_iou: 0.0784 - val_loss: 0.3826 - val_acc: 0.9727 - val_mean_iou: 0.7191 - val_adj_mean_iou: 0.0800
# Epoch 24/25
# 721/722 [============================>.] - ETA: 1s - loss: 0.3701 - acc: 0.9749 - mean_iou: 0.7435 - adj_mean_iou: 0.0788
# Epoch 00024: saving model to model9_320.h5
# 722/722 [==============================] - 1396s 2s/step - loss: 0.3700 - acc: 0.9749 - mean_iou: 0.7436 - adj_mean_iou: 0.0788 - val_loss: 0.3846 - val_acc: 0.9749 - val_mean_iou: 0.7351 - val_adj_mean_iou: 0.0722
# Epoch 25/25
# 721/722 [============================>.] - ETA: 1s - loss: 0.3697 - acc: 0.9750 - mean_iou: 0.7447 - adj_mean_iou: 0.0790
# Epoch 00025: saving model to model9_320.h5
# 722/722 [==============================] - 1396s 2s/step - loss: 0.3698 - acc: 0.9751 - mean_iou: 0.7447 - adj_mean_iou: 0.0790 - val_loss: 0.3836 - val_acc: 0.9747 - val_mean_iou: 0.7370 - val_adj_mean_iou: 0.0717

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=30, shuffle=True, initial_epoch=25)
# Out:
# Epoch 26/30
# 721/722 [============================>.] - ETA: 1s - loss: 0.3702 - acc: 0.9748 - mean_iou: 0.7417 - adj_mean_iou: 0.0783
# Epoch 00026: saving model to model9_320.h5
# 722/722 [==============================] - 1432s 2s/step - loss: 0.3701 - acc: 0.9748 - mean_iou: 0.7418 - adj_mean_iou: 0.0783 - val_loss: 0.3826 - val_acc: 0.9743 - val_mean_iou: 0.7312 - val_adj_mean_iou: 0.0745
# Epoch 27/30
# 721/722 [============================>.] - ETA: 1s - loss: 0.3711 - acc: 0.9748 - mean_iou: 0.7417 - adj_mean_iou: 0.0791
# Epoch 00027: saving model to model9_320.h5
# 722/722 [==============================] - 1392s 2s/step - loss: 0.3709 - acc: 0.9748 - mean_iou: 0.7416 - adj_mean_iou: 0.0792 - val_loss: 0.3854 - val_acc: 0.9759 - val_mean_iou: 0.7452 - val_adj_mean_iou: 0.0693
# Epoch 28/30
# 721/722 [============================>.] - ETA: 1s - loss: 0.3702 - acc: 0.9749 - mean_iou: 0.7416 - adj_mean_iou: 0.0797
# Epoch 00028: saving model to model9_320.h5
# 722/722 [==============================] - 1395s 2s/step - loss: 0.3703 - acc: 0.9749 - mean_iou: 0.7416 - adj_mean_iou: 0.0797 - val_loss: 0.3858 - val_acc: 0.9758 - val_mean_iou: 0.7518 - val_adj_mean_iou: 0.0682
# Epoch 29/30
# 721/722 [============================>.] - ETA: 1s - loss: 0.3690 - acc: 0.9751 - mean_iou: 0.7423 - adj_mean_iou: 0.0800
# Epoch 00029: saving model to model9_320.h5
# 722/722 [==============================] - 1389s 2s/step - loss: 0.3689 - acc: 0.9751 - mean_iou: 0.7423 - adj_mean_iou: 0.0800 - val_loss: 0.3852 - val_acc: 0.9736 - val_mean_iou: 0.7267 - val_adj_mean_iou: 0.0758
# Epoch 30/30
# 721/722 [============================>.] - ETA: 1s - loss: 0.3665 - acc: 0.9752 - mean_iou: 0.7434 - adj_mean_iou: 0.0807
# Epoch 00030: saving model to model9_320.h5
# 722/722 [==============================] - 1398s 2s/step - loss: 0.3665 - acc: 0.9752 - mean_iou: 0.7434 - adj_mean_iou: 0.0807 - val_loss: 0.3834 - val_acc: 0.9737 - val_mean_iou: 0.7326 - val_adj_mean_iou: 0.0759

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %% [markdown]
# ## Sample Predictions

# %%
THRESHOLD = 0.5
# look at some sample predictions
samples = np.random.choice(valid_filenames, size=8, replace=False)

for filename in samples:
    # load the image
    img = pydicom.dcmread(os.path.join(train_dicom_dir, filename)).pixel_array
    
    msk = np.zeros(img.shape)
    
    filename = filename.split('.')[0]
    # if image contains pneumonia
    if filename in pneumonia_locations:
        # loop through pneumonia
        for location in pneumonia_locations[filename]:
            # add 1's at the location of the pneumonia
            x, y, w, h = location
            msk[y:y+h, x:x+w] = 1
        
    # resize both image and mask
    msk = resize(msk, (IMAGE_SIZE, IMAGE_SIZE), mode='reflect') > 0.5
    img = resize(img, (IMAGE_SIZE, IMAGE_SIZE), mode='reflect')
    
    # predict the image
    yhat = model.predict(img.reshape(1, IMAGE_SIZE, IMAGE_SIZE, 1))
    yhat = yhat > THRESHOLD
    # add trailing channel dimension
    msk = np.expand_dims(msk, -1)

    f, ax = plt.subplots(1, 3, figsize=(10, 4))
    ax[0].imshow(img.reshape(IMAGE_SIZE,IMAGE_SIZE))
    ax[0].set_title("Image")
    ax[1].imshow(msk.reshape(IMAGE_SIZE,IMAGE_SIZE))
    ax[1].set_title("Label")
    ax[2].imshow(yhat.reshape(IMAGE_SIZE,IMAGE_SIZE))
    ax[2].set_title("Prediction")
    plt.show()

# %% [markdown]
# # Predict test images

# %%
# load and shuffle filenames
folder = './stage_1_test_images'
test_filenames = os.listdir(folder)
print('n test samples:', len(test_filenames))

# create test generator with predict flag set to True
test_gen = generator(folder, test_filenames, None, batch_size=25, image_size=320, shuffle=False, predict=True)

# create submission dictionary
submission_dict = {}
# loop through testset
for imgs, filenames in test_gen:
    # predict batch of images
    preds = model.predict(imgs)
    # loop through batch
    for pred, filename in zip(preds, filenames):
        # resize predicted mask
        pred = resize(pred, (1024, 1024), mode='reflect')
        # threshold predicted mask
        comp = pred[:, :, 0] > 0.5
        # apply connected components
        comp = measure.label(comp)
        # apply bounding boxes
        predictionString = ''
        for region in measure.regionprops(comp):
            # retrieve x, y, height and width
            y, x, y2, x2 = region.bbox
            height = y2 - y
            width = x2 - x
            # proxy for confidence score
            conf = np.mean(pred[y:y+height, x:x+width])
            # add to predictionString
            predictionString += str(conf) + ' ' + str(x) + ' ' + str(y) + ' ' + str(width) + ' ' + str(height) + ' '
        # add filename and predictionString to dictionary
        filename = filename.split('.')[0]
        submission_dict[filename] = predictionString
    # stop if we've got them all
    if len(submission_dict) >= len(test_filenames):
        break

print("Done predicting!")        
        
# save dictionary as csv file
sub = pd.DataFrame.from_dict(submission_dict,orient='index')
sub.index.names = ['patientId']
sub.columns = ['PredictionString']
sub.to_csv('submission.csv')
# Out:
# n test samples: 1000
# Done predicting!

# %%
# !kaggle competitions submit -c rsna-pneumonia-detection-challenge -f submission.csv -m "Colab segmentation 5 320x320 30 epochs"
# Out:
# Successfully submitted to RSNA Pneumonia Detection Challenge

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# !gsutil cp ./{CHECKPOINT_PATH} gs://{bucket_name}/
# Out:
# Updated property [core/project].
# Copying file://./model9_320.h5 [Content-Type=application/octet-stream]...
# \
# Operation completed over 1 objects/48.7 MiB.
