# %% [markdown]
# ## Approach
#
# * This is a simplied version of YOLO. The input image is 512x512. YOLO was intended to train on images which all contained at least one object, most multiple objects. The architecture and loss functions have been adapted for this case, where not every image contains an object and there are at most 4 ROIs per image.
# * Since the maximum number of ROIs in each image is 4 we decided to use a 2x2 grid to simplify the network. In the case where multiple ROIs occur in the same cell we combine the ROIs into a single ROI by expanding the box to include both. Each cell outputs five values:
#     * The confidence that there is pneumonia present
#     * The x, y, w, and h of the bounding box
#     * We have removed the entire classification section, using the confidence to indicate whether there is an ROI in the cell instead.
# * A sigmoid is applied to the output of the network to result in values between 0 and 1
# * The x and y coordinates are offsets from the upper left corner of each cell, the w and h are percentage of the total width.
# * The loss function is based on YOLO with some differences:
#     * The weights of the components have been updated
#     * The classification loss has been removed.
#     * The "objectness" loss of YOLO tries to make the confidence match the actual IOU. Since our model only outputs one box per cell, this doesn't really make any sense and ends up driving the confidence down to the IOU. We replace this by an IOU loss which subtracts the IOU for that cell from 1.
#
# ## Network
#
# * The network consists of a number of residual blocks with convolutions and downsampling blocks with max pooling.
# * There are two dilated convolutions at the end of the network to provide context.
# * The dilated convolutions are followed by two strided convolutions which downsize to 2x2.
# * Finally there are a series of 1x1 convolutions which output a 2x2x5 tensor.
# * We are using an Adam optimizer with gradient clipping to avoid exploding gradients, which had been a problem.
#
# ## Predictions
# * To generate our predictions we loop through each cell of the output
# * We unnormalize the output to get the actual values
# * If the confidence is greater than 0.5 and the box has width and height we append it to the list of candidates.
# * We apply non-max suppression to remove duplicates.
# * The remaining boxes are concatenated onto the output string.
#
# **Change Log:**
# * v3 - changing output to 8x8 grid from 16x16; changed model to downsample one more time; adjusted network accordingly.
# * v4 - changed output to 4x4 grid, no image has more than 3 ROIs so this may work better?
#     * Using center point of ROI to predict instead of upper left corner.
# * v5 - We only calculate MSE loss for boxes with a confidence over 0.5 or actual truth since we don't care about predictions for boxes that are not ROIs. This will prevent the network from being constrained by outputting 0s for boxes that don't exist.
# * v6 - centering input data so maybe bboxes can be output more accurately? Also centering the image
# * v6.2 - labels have ROI centered in center of cell by default instead of mean location.
# * v8 - using custom loss function based on YOLO loss. Set default height and width to 1 px because 0 sent the gradients to -inf which screwed everything up.
# * v10 - using 2x2 grid as output
# * v12 - changing layout of model slightly - replaced final pools with convs with strides; reduced number of params; ensure that there is at least one positive image per batch.
# * v13 - tweaking architecture slightly.

# %%
# install dependencies not included by Colab
# use pip3 to ensure compatibility w/ Google Deep Learning Images 
# !pip3 install -q pydicom 
# !pip3 install -q imgaug 
# !pip3 install -q kaggle
# !pip3 install -q tqdm

# %%
import os
import csv
import random
import pydicom
import numpy as np
import pickle
import pandas as pd
from skimage import measure
from skimage.transform import resize
import datetime
import math

import tensorflow as tf
from tensorflow import keras

from matplotlib import pyplot as plt
import matplotlib.patches as patches

# %%
from google.colab import auth
from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build

auth.authenticate_user()

drive_service = build('drive', 'v3')

def save_file_to_drive(name, path):
    file_metadata = {
      'name': name,
      'mimeType': 'application/octet-stream'
     }

    media = MediaFileUpload(path, 
                    mimetype='application/octet-stream',
                    resumable=True)

    created = drive_service.files().create(body=file_metadata,
                                   media_body=media,
                                   fields='id').execute()

    print('File ID: {}'.format(created.get('id')))

    return created

# %%
# Malisiewicz et al.
def non_max_suppression_fast(boxes, overlapThresh=0.3):
    # if there are no boxes, return an empty list
    if len(boxes) == 0:
        return []
 
    # if the bounding boxes integers, convert them to floats --
    # this is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")
 
    # initialize the list of picked indexes	
    pick = []
 
    # grab the coordinates of the bounding boxes
    x1 = boxes[:,0]
    y1 = boxes[:,1]
    w = boxes[:,2]
    h = boxes[:,3]
 
    x2 = x1 + w
    y2 = y1 + h

    # compute the area of the bounding boxes and sort the bounding
    # boxes by the bottom-right y-coordinate of the bounding box
    area = (w + 1) * (h + 1)
    idxs = np.argsort(y2)
 
    # keep looping while some indexes still remain in the indexes
    # list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the
        # index value to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)
 
        # find the largest (x, y) coordinates for the start of
        # the bounding box and the smallest (x, y) coordinates
        # for the end of the bounding box
        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.minimum(x2[i], x2[idxs[:last]])
        yy2 = np.minimum(y2[i], y2[idxs[:last]])
 
        # compute the width and height of the bounding box
        w = np.maximum(0, xx2 - xx1 + 1)
        h = np.maximum(0, yy2 - yy1 + 1)
 
        # compute the ratio of overlap
        overlap = (w * h) / area[idxs[:last]]
 
        # delete all indexes from the index list that have
        idxs = np.delete(idxs, np.concatenate(([last],
            np.where(overlap > overlapThresh)[0])))
 
    # return only the bounding boxes that were picked using the
    # integer data type
    return boxes[pick].astype("int")

# get actual x and y values from sigmoid output and what cell they are in
def unnorm(val, idx, cell_size=256):
    x = (val * cell_size) + (cell_size * idx)
    return x

# sigmoid in numpy, with limit to avoid nans                             
def sigmoid(x):
    # to avoid NaNs set a lower floor on x values
    y = np.maximum(x, -700)
    return 1 / (1 + np.exp(-y))    

# adjust contrast of image
def change_contrast(img, contrast_factor):
    mean = np.mean(img)
    img = (img - mean) * contrast_factor + mean
    return img

# %%
# enter your Kaggle credentionals here
os.environ['KAGGLE_USERNAME']="skooch"
os.environ['KAGGLE_KEY']="42f8a02ee92cc773d1dbe66565673ad3"

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# If you are unable to download the competition dataset, check to see if you have 
# accepted the user agreement on the competition website. 
if not os.path.exists("./stage_1_detailed_class_info.csv.zip"):
    # !kaggle competitions download -c rsna-pneumonia-detection-challenge
# Out:
# Downloading GCP%20Credits%20Request%20Link%20-%20RSNA.txt to /content
#   0% 0.00/55.0 [00:00<?, ?B/s]
# 100% 55.0/55.0 [00:00<00:00, 42.5kB/s]
# Downloading stage_1_detailed_class_info.csv.zip to /content
#   0% 0.00/561k [00:00<?, ?B/s]
# 100% 561k/561k [00:00<00:00, 86.3MB/s]
# Downloading stage_1_sample_submission.csv to /content
#   0% 0.00/51.8k [00:00<?, ?B/s]
# 100% 51.8k/51.8k [00:00<00:00, 39.8MB/s]
# Downloading stage_1_train_labels.csv.zip to /content
#   0% 0.00/634k [00:00<?, ?B/s]
# 100% 634k/634k [00:00<00:00, 76.7MB/s]
# Downloading stage_1_test_images.zip to /content
#  96% 121M/126M [00:03<00:00, 40.5MB/s]
# 100% 126M/126M [00:03<00:00, 43.2MB/s]
# Downloading stage_1_train_images.zip to /content
# 100% 3.16G/3.17G [01:10<00:00, 44.8MB/s]
# 100% 3.17G/3.17G [01:10<00:00, 48.1MB/s]

# %%
# unzipping takes a few minutes
if not os.path.exists("./stage_1_train_labels.csv"):
    print("Unzipping...")
    # !unzip -q -o stage_1_test_images.zip -d stage_1_test_images
    # !unzip -q -o stage_1_train_images.zip -d stage_1_train_images
    # !unzip -q -o stage_1_train_labels.csv.zip
# Out:
# Unzipping...

# %% [markdown]
# # Load pneumonia locations
#
# Table contains [filename : pneumonia location] pairs per row.
# * If a filename contains multiple pneumonia, the table contains multiple rows with the same filename but different pneumonia locations.
# * If a filename contains no pneumonia it contains a single row with an empty pneumonia location.
#
# The code below loads the table and transforms it into a dictionary.
# * The dictionary uses the filename as key and a list of pneumonia locations in that filename as value.
# * If a filename is not present in the dictionary it means that it contains no pneumonia.

# %%
ROOT_DIR = "./"

train_dicom_dir = os.path.join(ROOT_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(ROOT_DIR, 'stage_1_test_images')
print("Train dir:", train_dicom_dir)
# Out:
# Train dir: ./stage_1_train_images

# %%
# !gsutil cp gs://{bucket_name}/yolo_labels_centered_2x2_7.p ./yolo_labels_centered_2x2_7.p
# Out:
# Copying gs://pneumonia/yolo_labels_centered_2x2_7.p...
# \ [1 files][  5.7 MiB/  5.7 MiB]
# Operation completed over 1 objects/5.7 MiB.

# %%
with open('yolo_labels_centered_2x2_7.p', 'rb') as handle:
    pneumonia_locations = pickle.load(handle)

# %% [markdown]
# # Load filenames

# %%
random.seed(72)

# load and shuffle filenames
folder = './stage_1_train_images'
filenames = os.listdir(folder)
random.shuffle(filenames)
# split into train and validation filenames
n_valid_samples = int(len(filenames) * 0.1)
train_filenames = filenames[n_valid_samples:]
valid_filenames = filenames[:n_valid_samples]
print('n train samples', len(train_filenames))
print('n valid samples', len(valid_filenames))
n_train_samples = len(filenames) - n_valid_samples
# Out:
# n train samples 23116
# n valid samples 2568

# %%
positive_images = []

for filename in pneumonia_locations:
    label = pneumonia_locations[filename][...,0]
    if np.max(label) > 1e-6:
        if filename + ".dcm" in train_filenames:
            positive_images.append(filename + ".dcm")

# %% [markdown]
#  # Data generator
#
# The dataset is too large to fit into memory, so we need to create a generator that loads data on the fly.
#
# * The generator takes in some filenames, batch_size and other parameters.
#
# * The generator outputs a random batch of numpy images and numpy masks.

# %%
BATCH_SIZE = 16
IMAGE_SIZE = 512
CHECKPOINT_PATH = "yolo13_2_512.h5"

# %%
# !gsutil cp gs://{bucket_name}/{CHECKPOINT_PATH} ./{CHECKPOINT_PATH}
# Out:
# Copying gs://pneumonia/yolo13_2_512.h5...
# | [1 files][ 58.7 MiB/ 58.7 MiB]
# Operation completed over 1 objects/58.7 MiB.

# %%
# means to center data
mu_x = 391.456158
mu_y = 363.1358768
mu_w = 220.8453815
mu_h = 334.1743641
mu_center_x = 501.8788487
mu_center_y = 530.2230589

# %%
class generator(keras.utils.Sequence):
    
    def __init__(self, folder, filenames, pneumonia_locations=None, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=False, predict=False):
        self.folder = folder
        self.filenames = filenames
        self.pneumonia_locations = pneumonia_locations
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.predict = predict
        self.on_epoch_end()
    
    def augment_imgs(self, img, confs, boxes):
        # flip the image half the time
        if random.random() > 0.5:
            img = np.fliplr(img)
            
            # update our x coords
            mask = confs != 0
            
            # flip
            boxes[mask, 0] = 1 - boxes[mask,0]
            
            # flip our boxes lr on axis 0
            boxes = np.flip(boxes, axis=0)         
            
            # flip the confidences lr as well
            confs = np.flip(confs, axis=0)
            
        ## small random shifts
        h_offset = np.random.randint(low=0, high=5)
        v_offset = np.random.randint(low=0, high=5)

        # crop the images
        img = img[v_offset:,h_offset:]
           
        ## adjust contrast half the time
        if random.random() > 0.5:  
            # generate a random contrast adjustment
            contrast_factor = np.random.normal(loc=1.0, scale=0.10)
            
            # put some limits on the contrast
            contrast_factor = np.minimum(contrast_factor, 1.25)
            contrast_factor = np.maximum(contrast_factor, 0.75)
            
            # adjust the image
            img = change_contrast(img, contrast_factor)
            
        return img, confs, boxes
            
            
    def __load__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # get filename without extension
        filename = filename.split('.')[0]
        label = pneumonia_locations[filename].copy()
        
        # remove the confidence and bboxes because they will be flipped separately
        confs = label[:,:,0]
        boxes = label[:,:,1:]
        
        ## augment the data with flips, small shifts and contrast adjustment
        if self.augment:
            img, confs, boxes = self.augment_imgs(img, confs, boxes)
            
        # resize both image and mask
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        
        # scale and center the image
        img = (img - np.mean(img)) / np.max(img)
        
        boxes = np.concatenate([confs.reshape((2,2,1)), boxes], axis=2)
        
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        return img, boxes
    
    def __loadpredict__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # resize image
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        return img
        
    def __getitem__(self, index):
        # select batch
        filenames = self.filenames[index*self.batch_size:(index+1)*self.batch_size]
        # predict mode: return images and filenames
        if self.predict:
            # load files
            imgs = [self.__loadpredict__(filename) for filename in filenames]
            # create numpy batch
            imgs = np.array(imgs)
            return imgs, filenames
        # train mode: return images and masks
        else:
            # load files
            items = [self.__load__(filename) for filename in filenames]
            
            # unzip images and masks
            imgs, bboxes = zip(*items)
            
            # create numpy batch
            imgs = np.array(imgs)
            bboxes = np.array(bboxes)
            
            # make sure there is at least one positive image in the batch
            pos = np.max(bboxes[:,:,:,0])
            if pos < 1:
                # pick a random positive image
                filename = np.random.choice(positive_images)
                img, label = self.__load__(filename)
                
                # add the positive image to our batch
                imgs[-1] = img
                bboxes[-1] = label
                
            labels = bboxes
            return imgs, labels
        
    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.filenames)
        
    def __len__(self):
        if self.predict:
            # return everything
            return int(np.ceil(len(self.filenames) / self.batch_size))
        else:
            # return full batches only
            return int(len(self.filenames) / self.batch_size)

# %%
# train_gen = generator(folder, train_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=True, predict=False)

# counter = 0
# for imgs, labels in train_gen:
#     for label in labels:
#         for i in range(4):
#             for j in range(4):
#                 if label[i,j,0] == 1:
#                     if label[i,j,4] ==  0.001:
#                         print("Error!")
#     counter += 1
#     if counter > 15:
#         break

# %% [markdown]
# # Network

# %%
def create_downsample(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.MaxPool2D(2)(x)
    return x

def create_resblock(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0.1)(x)
    x_1 = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x_1)
    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.add([x, x_1])
    return x

def create_network(input_size, channels, n_blocks=2, depth=4):
    # input - 512x512x3
    inputs = keras.Input(shape=(input_size, input_size, 1))
    
    # downsample to 256x256x24
    x = keras.layers.Conv2D(channels, 3, strides=(2,2), padding='same', use_bias=False)(inputs)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    # residual blocks
    for d in range(depth):
        
        channels = channels * 2
        for b in range(n_blocks):
            x = create_resblock(channels, x)
        
        x = create_downsample(channels, x)
    
    x_2 = x 
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    
    # dilated convolutions for context - 16x16x512
    x = keras.layers.Conv2D(channels, (3,3), padding='same', dilation_rate=(2,2), activation=None, name="dilated_conv_1")(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
        
    x = keras.layers.Conv2D(channels, (3,3), padding='same', dilation_rate=(2,2), activation=None, name="dilated_conv_2")(x)
    x = keras.layers.add([x, x_2])
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    # downsample to 8x8 with stride 2
    x = keras.layers.Conv2D(512, (3,3), padding='same', strides=(2,2), activation=None, name="downsample_1")(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    # condense each quadrant to one pixel
    x = keras.layers.Conv2D(512, (4,4), padding='same', strides=(4,4), activation=None, name="downsample_2")(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0.1)(x)
    
    # bounding box branch
    b = keras.layers.Conv2D(1024, (1,1), padding='same', activation=None, name="fc_1_b", kernel_regularizer=keras.regularizers.l2(l=0.01))(x)
    b = keras.layers.BatchNormalization(momentum=0.9)(b)
    b = keras.layers.LeakyReLU(0.01)(b)
    b = keras.layers.Dropout(0.20)(b)
    
    boxes = keras.layers.Conv2D(5, (1,1), padding='same', activation="linear")(b)
#     boxes = keras.layers.concatenate([confidence, boxes], name="bboxes_output")
    
    # return both outputs
    model = keras.Model(inputs=inputs, outputs=boxes)
    
    return model

# %% [markdown]
# # Train network

# %%
GRID_SIZE = 2
CELL_SIZE = 1024 // GRID_SIZE

def binary_accuracy(y_true, y_pred):
    y_pred = tf.sigmoid(y_pred)
    y_true = tf.round(tf.reshape(y_true, [-1, 5]))
    y_pred = tf.round(tf.reshape(y_pred, [-1, 5]))
    
    acc = tf.reduce_mean(tf.cast(tf.equal(y_true[:,0], y_pred[:,0]), dtype=tf.float32))
    return acc

def overlap_iou(y_true, y_pred):
    """
    Args:
        bboxes1: shape (batch_size, 16, 16, 4)
            with x1, y1, x2, y2 point order.
        bboxes2: shape (batch_size, 16, 16, 4)
            with x1, y1, x2, y2 point order.
        p1 *-----
           |     |
           |_____* p2
    Returns:
        Tensor with shape (total_bboxes1, total_bboxes2)
        with the IoU (intersection over union) of bboxes1[i] and bboxes2[j]
        in [i, j].
    """
    y_pred = tf.sigmoid(y_pred)
    
    # flatten the data because it's easier that way
    bboxes1 = tf.reshape(y_true, (-1, 5))
    bboxes2 = tf.reshape(y_pred, (-1, 5))
    
    # split the components out
    true_boxes, x11, y11, w1, h1 = tf.split(bboxes1, 5, axis=1)
    pred_conf, x21, y21, w2, h2 = tf.split(bboxes2, 5, axis=1)
    
    # uncenter the data - make sure the numbers are positive
    x11 = x11 * CELL_SIZE
    x21 = x21 * CELL_SIZE
    y11 = y11 * CELL_SIZE
    y21 = y21 * CELL_SIZE
    
    w1 = w1 * 1024
    w2 = w2 * 1024
    h1 = h1 * 1024
    h2 = h2 * 1024
    
    # is there either a box predicted here or a box actually here?
    mask = (pred_conf >= 0.5) | (true_boxes == 1)
    
    # get the far corners of the boxes
    x12 = x11 + (w1 / 2)
    y12 = y11 + (h1 / 2)
    x22 = x21 + (w2 / 2)
    y22 = y21 + (h2 / 2)
    
    x11 = x11 - (w1 / 2)
    y11 = y11 - (h1 / 2)
    x21 = x21 - (w2 / 2)
    y21 = y21 - (h2 / 2)

    # find the corners of the intersection area
    xI1 = tf.maximum(x11, x21)
    yI1 = tf.maximum(y11, y21)

    xI2 = tf.minimum(x12, x22)
    yI2 = tf.minimum(y12, y22)
    
    # get the intersection area, if the truth has no boxes it is 0
    inter_area = true_boxes * (xI2 - xI1 + 1) * (yI2 - yI1 + 1)

    # get the area of each box
    bboxes1_area = (w1 + 1) * (h1 + 1)
    bboxes2_area = (w2 + 1) * (h2 + 1)
    
    # union is area of both boxes - intersection
    union = (bboxes1_area + bboxes2_area) - inter_area + 1
    
    iou = tf.maximum(inter_area/(union + 1e-6), 0)
    
    # apply the mask
    iou = tf.boolean_mask(iou, mask)
    
    # reduce the mean so we have mean iou for our inputs
    return tf.reduce_mean(iou)

def overlap_iou2(y_true, y_pred):
    """
    Args:
        y_true and y_pred - arrays of boxes containing center points, h and w of boxes
        p1 *-----
           |     |
           |_____* p2
    Returns:
        Average IOU over boxes
    """
    # apply the sigmoid
    y_pred = tf.sigmoid(y_pred)
    
    ious = []
    
    # loop over both sets of boxes
    for truth, pred in zip(y_true, y_pred):
        # get true area
        true_area = 0
        true_boxes = []
        for i in range(GRID_SIZE):
            for j in range(GRID_SIZE):
                c, x, y, w, h = truth[i,j,:]
                # if we have an ROI
                if c == 1:
                    # unnormalize the data
                    w, h = w*1024, h*1024
                    true_area += w * h
                    
                    # unnormalize the x and y
                    x = unnorm(x, j, CELL_SIZE)
                    y = unnorm(y, i, CELL_SIZE)
                    
                    true_boxes.append([x, y, x+w, y+h])
                    
        pred_area = 0
        pred_boxes = []
        # get the predicted area
        for i in range(GRID_SIZE):
            for j in range(GRID_SIZE):
                c, x, y, w, h = pred[i,j,:]
                # if we have an ROI
                if c > 0.5:
                    # unnormalize the data
                    w, h = w*1024, h*1024
                    pred_area += w * h
                    
                    # unnormalize the x and y
                    x = unnorm(x, j, CELL_SIZE)
                    y = unnorm(y, i, CELL_SIZE)
                    
                    pred_boxes.append([x, y, x+w, y+h])
            
        intersect_area = 0
        # get the intersection
        for pred_box in pred_boxes:
            x1_p, y1_p, x2_p, y2_p = pred_box
            
            for true_box in true_boxes:
                x1_t, y1_t, x2_t, y2_t = true_box
                
                # if the boxes overlap at all
                if (x1_p >= x1_t and y1_p >= y1_t) or (x1_p <= x1_t and y1_p <= y1_t):
                    # get the intersection corners
                    x1_i = np.maximum(x1_p, x1_t)
                    y1_i = np.maximum(y1_p, y1_t)
                    x2_i = np.minimum(x2_p, x2_t)
                    y2_i = np.minimum(y2_p, y2_t)
                    
                    # get area of intersect
                    i_w, i_h = x2_i - x1_i, y2_i - y1_i

                    # trap for negative numbers
                    i_w = np.maximum(i_w, 0)
                    i_h = np.maximum(i_h, 0)

                    intersection = i_w * i_h
                    intersect_area += intersection

        union = true_area + pred_area - intersect_area
        
        iou = intersect_area / (union + 1e-16)
        ious.append(iou)
    
    iou_area = np.mean(ious)
    return iou_area
                    
def loss_fn(y_true, y_pred):
    # get the iou loss
    iou_loss = iou_loss_fn(y_true, y_pred)
    
    # get the xe loss
    xe_loss = binary_cross_entropy(y_true, y_pred)
    
    # get the box loss
    box_loss = adj_mse(y_true, y_pred)
    
    # add the losses and return them
    return ((1.5 * xe_loss) + (box_loss * 3.0) + (iou_loss * 2.0))

# only apply mse to layers with high confidence that there is an ROI or if there actually is an ROI
def adj_mse(y_true, y_pred):
    # coefficients
    lam_coord = 5
    lam_noobj = 0.5
    
    y_pred = tf.sigmoid(y_pred)
        
    # flatten the inputs
    y_true = tf.reshape(y_true, (-1, 5))
    y_pred = tf.reshape(y_pred, (-1, 5))

    # separate the confidence from the boxes
    conf_true, x_true, y_true, w_true, h_true = tf.split(y_true, 5, axis=1)
    conf_pred, x_pred, y_pred, w_pred, h_pred = tf.split(y_pred, 5, axis=1)

    # center squared error
    center_se = tf.square(x_true - y_pred) + tf.square(y_true - y_pred)
    size_se =  tf.square(tf.sqrt(w_true) - tf.sqrt(w_pred)) + tf.square(tf.sqrt(h_true) - tf.sqrt(h_pred))
    
    box_se = center_se + size_se
    
    # only get loss for boxes which are actually positive
    mask = tf.equal(conf_true, 1)
    box_se = tf.boolean_mask(box_se, mask)
    
    # weight the loss higher
    box_se = tf.multiply(box_se, 5.0)
    
    loss = tf.reduce_sum(box_se)
    
    return loss
    
# use weight of 0.5 for negative cells, 19 for positive ones
def binary_cross_entropy(y_true, y_pred):
    conf_true = y_true[...,0]
    conf_pred = tf.sigmoid(y_pred[...,0])
    
    weight = 2.5
    weights = tf.multiply(y_true[...,0], weight) + 0.5
    
    xe = tf.multiply(tf.square(conf_true - conf_pred), weights)
    
    return tf.reduce_sum(xe)

def objectness_loss_fn(y_true, y_pred):
    y_pred = tf.sigmoid(y_pred)
    
    # pred box conf
    pred_box_conf = y_pred[...,0]
    
    # separate the x, y from the w, h
    true_box_xy = y_true[...,1:3] * CELL_SIZE
    true_box_wh = y_true[...,3:] * 1024
    
    pred_box_xy = y_pred[...,1:3] * CELL_SIZE
    pred_box_wh = y_pred[...,3:] * 1024
    
    # get the corners of the boxes by subtracting or adding half of h, w
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half  
    
    # get the corners of the intersect area
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas + 1e-16)
    
    true_box_conf = iou_scores * y_true[..., 0]
    
    conf_mask  = tf.zeros_like(iou_scores)
    conf_mask = conf_mask + tf.cast((iou_scores < 0.6), dtype=tf.float32) * (1 - y_true[...,0])
    conf_mask = conf_mask + y_true[..., 0] * 5.0
    
    nb_conf_box  = tf.reduce_sum(tf.cast((conf_mask > 0.0), dtype=tf.float32)) 
    
    loss_conf  =  tf.reduce_sum(tf.square(true_box_conf-pred_box_conf) * conf_mask)  / (nb_conf_box + 1e-6) / 2.
    
    return tf.reduce_sum(loss_conf)

def iou_loss_fn(y_true, y_pred):
    # apply sigmoid to predictions
    y_pred = tf.sigmoid(y_pred)
    
    # separate the x, y from the w, h and unnormalize them
    true_box_xy = y_true[...,1:3] * CELL_SIZE
    true_box_wh = y_true[...,3:] * 1024
    
    pred_box_xy = y_pred[...,1:3] * CELL_SIZE
    pred_box_wh = y_pred[...,3:] * 1024
    
    # get the corners of the boxes by subtracting or adding half of h, w
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half  
    
    # get the corners of the intersect area
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    # get the area of the boxes
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    # calculate the IOU
    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas + 1e-6)
    
    # only use the IOU from boxes which actually have ROIs
    mask = tf.equal(y_true[...,0], 1)
    use_iou = tf.boolean_mask(1 - iou_scores, mask)
    
    return tf.reduce_sum(use_iou)
    
# create network and compiler
model = create_network(input_size=IMAGE_SIZE, channels=24, n_blocks=1, depth=4)

optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, decay=1e-7, clipnorm=1.5, clipvalue=0.75)

model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=[binary_accuracy, overlap_iou, adj_mse, binary_cross_entropy])

# cosine learning rate annealing
def exp_decay(x):
    lr0 = 0.002
    epochs_drop = 10
    drop = 0.75
    lrate = lr0 * math.pow(drop, math.floor((1+x)/epochs_drop))
    return lrate

learning_rate = tf.keras.callbacks.LearningRateScheduler(exp_decay)
checkpoint = keras.callbacks.ModelCheckpoint(CHECKPOINT_PATH, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=True, mode='auto', period=1)

# create train and validation generators
folder = './stage_1_train_images'
train_gen = generator(folder, train_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=True, predict=False)
valid_gen = generator(folder, valid_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=False, predict=False)

print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 24) 216         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 24) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 24) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 24) 96          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 24) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 48) 10368       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 48) 192         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 256, 256, 48) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 48) 20736       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 48) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 256, 256, 48) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 48) 20736       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256, 256, 48) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 256, 256, 48) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 48) 20736       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 48) 0           conv2d_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 256, 256, 48) 192         add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 256, 256, 48) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 48) 0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 48) 192         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 128, 128, 48) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 96) 41472       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 96) 384         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 128, 128, 96) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 96) 82944       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 96) 384         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 128, 128, 96) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 96) 82944       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 96) 384         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 128, 128, 96) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 96) 82944       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 96) 0           conv2d_8[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 96) 384         add_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 128, 128, 96) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 96)   0           leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 96)   384         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 64, 64, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 192)  165888      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 192)  768         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 64, 64, 192)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 192)  331776      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 192)  768         conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 64, 64, 192)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 192)  331776      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 192)  768         conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 64, 64, 192)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 192)  331776      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 192)  0           conv2d_12[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 192)  768         add_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 64, 64, 192)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 192)  0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 192)  768         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 32, 32, 192)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 384)  663552      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 384)  1536        conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 32, 32, 384)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 384)  1327104     leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 384)  1536        conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 32, 32, 384)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 384)  1327104     leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 384)  1536        conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 32, 32, 384)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 384)  1327104     leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 384)  0           conv2d_16[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 384)  1536        add_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 32, 32, 384)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 384)  0           leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 384)  1536        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 16, 16, 384)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dilated_conv_1 (Conv2D)         (None, 16, 16, 384)  1327488     leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 384)  1536        dilated_conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 16, 16, 384)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dilated_conv_2 (Conv2D)         (None, 16, 16, 384)  1327488     leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 384)  0           dilated_conv_2[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 384)  1536        add_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 16, 16, 384)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# downsample_1 (Conv2D)           (None, 8, 8, 512)    1769984     leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 512)    2048        downsample_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 8, 8, 512)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# downsample_2 (Conv2D)           (None, 2, 2, 512)    4194816     leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 2, 2, 512)    2048        downsample_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 2, 2, 512)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# fc_1_b (Conv2D)                 (None, 2, 2, 1024)   525312      leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 2, 2, 1024)   4096        fc_1_b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 2, 2, 1024)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2, 2, 1024)   0           leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 5)      5125        dropout[0][0]
# ==================================================================================================
# Total params: 15,345,245
# Trainable params: 15,332,317
# Non-trainable params: 12,928
# __________________________________________________________________________________________________
# None

# %%
  model.load_weights(CHECKPOINT_PATH)

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=10, shuffle=True, verbose=1, initial_epoch=0)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1443/1444 [============================>.] - ETA: 1s - loss: 41.1579 - binary_accuracy: 0.8357 - overlap_iou: nan - adj_mse: 5.8539 - binary_cross_entropy: 10.2378
# Epoch 00001: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2258s 2s/step - loss: 41.1429 - binary_accuracy: 0.8358 - overlap_iou: nan - adj_mse: 5.8514 - binary_cross_entropy: 10.2346 - val_loss: 34.9721 - val_binary_accuracy: 0.7860 - val_overlap_iou: nan - val_adj_mse: 4.7206 - val_binary_cross_entropy: 8.9456
# Epoch 2/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 36.2414 - binary_accuracy: 0.8033 - overlap_iou: nan - adj_mse: 5.0747 - binary_cross_entropy: 9.0152
# Epoch 00002: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2228s 2s/step - loss: 36.2234 - binary_accuracy: 0.8034 - overlap_iou: nan - adj_mse: 5.0717 - binary_cross_entropy: 9.0110 - val_loss: 33.1508 - val_binary_accuracy: 0.8357 - val_overlap_iou: nan - val_adj_mse: 4.4532 - val_binary_cross_entropy: 8.3961
# Epoch 3/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 34.1248 - binary_accuracy: 0.8000 - overlap_iou: nan - adj_mse: 4.6693 - binary_cross_entropy: 8.5621
# Epoch 00003: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2229s 2s/step - loss: 34.1484 - binary_accuracy: 0.7999 - overlap_iou: nan - adj_mse: 4.6733 - binary_cross_entropy: 8.5663 - val_loss: 30.6520 - val_binary_accuracy: 0.7513 - val_overlap_iou: 0.0913 - val_adj_mse: 3.7640 - val_binary_cross_entropy: 8.4043
# Epoch 4/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 33.0518 - binary_accuracy: 0.8005 - overlap_iou: 0.1016 - adj_mse: 4.3388 - binary_cross_entropy: 8.5596
# Epoch 00004: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2229s 2s/step - loss: 33.0592 - binary_accuracy: 0.8005 - overlap_iou: 0.1017 - adj_mse: 4.3393 - binary_cross_entropy: 8.5626 - val_loss: 34.4674 - val_binary_accuracy: 0.9029 - val_overlap_iou: nan - val_adj_mse: 4.2875 - val_binary_cross_entropy: 9.7470
# Epoch 5/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 30.6041 - binary_accuracy: 0.7991 - overlap_iou: 0.1145 - adj_mse: 3.8421 - binary_cross_entropy: 8.1863
# Epoch 00005: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2228s 2s/step - loss: 30.6139 - binary_accuracy: 0.7991 - overlap_iou: 0.1146 - adj_mse: 3.8441 - binary_cross_entropy: 8.1879 - val_loss: 32.7282 - val_binary_accuracy: 0.8861 - val_overlap_iou: nan - val_adj_mse: 3.9809 - val_binary_cross_entropy: 9.2833
# Epoch 6/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 29.5606 - binary_accuracy: 0.8065 - overlap_iou: 0.1242 - adj_mse: 3.6854 - binary_cross_entropy: 7.9592
# Epoch 00006: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2228s 2s/step - loss: 29.5576 - binary_accuracy: 0.8065 - overlap_iou: 0.1242 - adj_mse: 3.6847 - binary_cross_entropy: 7.9598 - val_loss: 28.4198 - val_binary_accuracy: 0.8267 - val_overlap_iou: 0.1323 - val_adj_mse: 3.4246 - val_binary_cross_entropy: 7.9029
# Epoch 7/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 28.7509 - binary_accuracy: 0.8134 - overlap_iou: 0.1337 - adj_mse: 3.5799 - binary_cross_entropy: 7.7427
# Epoch 00007: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2230s 2s/step - loss: 28.7623 - binary_accuracy: 0.8133 - overlap_iou: 0.1337 - adj_mse: 3.5807 - binary_cross_entropy: 7.7477 - val_loss: 27.3606 - val_binary_accuracy: 0.7834 - val_overlap_iou: 0.1211 - val_adj_mse: 3.3722 - val_binary_cross_entropy: 7.4744
# Epoch 8/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 27.8179 - binary_accuracy: 0.8181 - overlap_iou: 0.1392 - adj_mse: 3.4480 - binary_cross_entropy: 7.5216
# Epoch 00008: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2229s 2s/step - loss: 27.8216 - binary_accuracy: 0.8181 - overlap_iou: 0.1392 - adj_mse: 3.4483 - binary_cross_entropy: 7.5226 - val_loss: 26.2546 - val_binary_accuracy: 0.8084 - val_overlap_iou: 0.1366 - val_adj_mse: 3.0491 - val_binary_cross_entropy: 7.4645
# Epoch 9/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 27.4545 - binary_accuracy: 0.8274 - overlap_iou: 0.1463 - adj_mse: 3.3668 - binary_cross_entropy: 7.5114
# Epoch 00009: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2231s 2s/step - loss: 27.4527 - binary_accuracy: 0.8274 - overlap_iou: 0.1463 - adj_mse: 3.3666 - binary_cross_entropy: 7.5112 - val_loss: 27.8416 - val_binary_accuracy: 0.6963 - val_overlap_iou: 0.1008 - val_adj_mse: 3.4076 - val_binary_cross_entropy: 7.8297
# Epoch 10/10
# 1443/1444 [============================>.] - ETA: 1s - loss: 26.0421 - binary_accuracy: 0.8295 - overlap_iou: 0.1549 - adj_mse: 3.1765 - binary_cross_entropy: 7.1024
# Epoch 00010: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2228s 2s/step - loss: 26.0350 - binary_accuracy: 0.8294 - overlap_iou: 0.1548 - adj_mse: 3.1748 - binary_cross_entropy: 7.1025 - val_loss: 25.2023 - val_binary_accuracy: 0.8518 - val_overlap_iou: nan - val_adj_mse: 2.9664 - val_binary_cross_entropy: 7.1057

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=20, shuffle=True, verbose=1, initial_epoch=10)
# Out:
# Epoch 11/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 25.0430 - binary_accuracy: 0.8603 - overlap_iou: 0.1452 - adj_mse: 3.0392 - binary_cross_entropy: 5.8930
# Epoch 00011: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 25.0449 - binary_accuracy: 0.8603 - overlap_iou: 0.1452 - adj_mse: 3.0393 - binary_cross_entropy: 5.8937 - val_loss: 24.3366 - val_binary_accuracy: 0.8955 - val_overlap_iou: 0.1947 - val_adj_mse: 3.0809 - val_binary_cross_entropy: 5.3254
# Epoch 12/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 24.4571 - binary_accuracy: 0.8638 - overlap_iou: 0.1515 - adj_mse: 2.9772 - binary_cross_entropy: 5.7244
# Epoch 00012: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2126s 1s/step - loss: 24.4620 - binary_accuracy: 0.8637 - overlap_iou: 0.1514 - adj_mse: 2.9785 - binary_cross_entropy: 5.7245 - val_loss: 24.8583 - val_binary_accuracy: 0.8625 - val_overlap_iou: 0.1613 - val_adj_mse: 3.2946 - val_binary_cross_entropy: 5.3004
# Epoch 13/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 24.3118 - binary_accuracy: 0.8610 - overlap_iou: 0.1512 - adj_mse: 2.9554 - binary_cross_entropy: 5.7043
# Epoch 00013: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2126s 1s/step - loss: 24.3151 - binary_accuracy: 0.8611 - overlap_iou: 0.1513 - adj_mse: 2.9563 - binary_cross_entropy: 5.7037 - val_loss: 24.0320 - val_binary_accuracy: 0.8878 - val_overlap_iou: 0.1883 - val_adj_mse: 3.0401 - val_binary_cross_entropy: 5.3208
# Epoch 14/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 24.1260 - binary_accuracy: 0.8653 - overlap_iou: 0.1561 - adj_mse: 2.9445 - binary_cross_entropy: 5.6193
# Epoch 00014: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 24.1400 - binary_accuracy: 0.8653 - overlap_iou: 0.1560 - adj_mse: 2.9462 - binary_cross_entropy: 5.6219 - val_loss: 23.5929 - val_binary_accuracy: 0.8679 - val_overlap_iou: 0.1723 - val_adj_mse: 2.9451 - val_binary_cross_entropy: 5.2367
# Epoch 15/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 23.9291 - binary_accuracy: 0.8660 - overlap_iou: 0.1565 - adj_mse: 2.9215 - binary_cross_entropy: 5.5650
# Epoch 00015: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 23.9385 - binary_accuracy: 0.8660 - overlap_iou: 0.1565 - adj_mse: 2.9229 - binary_cross_entropy: 5.5672 - val_loss: 24.3037 - val_binary_accuracy: 0.8846 - val_overlap_iou: nan - val_adj_mse: 3.0161 - val_binary_cross_entropy: 5.4966
# Epoch 16/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 23.7257 - binary_accuracy: 0.8696 - overlap_iou: 0.1626 - adj_mse: 2.9003 - binary_cross_entropy: 5.4952
# Epoch 00016: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2126s 1s/step - loss: 23.7256 - binary_accuracy: 0.8696 - overlap_iou: 0.1626 - adj_mse: 2.8999 - binary_cross_entropy: 5.4967 - val_loss: 23.2150 - val_binary_accuracy: 0.8575 - val_overlap_iou: 0.1688 - val_adj_mse: 2.9395 - val_binary_cross_entropy: 5.2025
# Epoch 17/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 23.4444 - binary_accuracy: 0.8720 - overlap_iou: 0.1658 - adj_mse: 2.8759 - binary_cross_entropy: 5.3951
# Epoch 00017: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2126s 1s/step - loss: 23.4582 - binary_accuracy: 0.8719 - overlap_iou: 0.1658 - adj_mse: 2.8768 - binary_cross_entropy: 5.3993 - val_loss: 25.3437 - val_binary_accuracy: 0.8862 - val_overlap_iou: nan - val_adj_mse: 3.0880 - val_binary_cross_entropy: 6.0095
# Epoch 18/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 23.2794 - binary_accuracy: 0.8737 - overlap_iou: 0.1683 - adj_mse: 2.8718 - binary_cross_entropy: 5.2923
# Epoch 00018: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 23.2676 - binary_accuracy: 0.8737 - overlap_iou: 0.1683 - adj_mse: 2.8702 - binary_cross_entropy: 5.2898 - val_loss: 23.8206 - val_binary_accuracy: 0.8792 - val_overlap_iou: nan - val_adj_mse: 2.9827 - val_binary_cross_entropy: 5.4266
# Epoch 19/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 22.9976 - binary_accuracy: 0.8765 - overlap_iou: 0.1729 - adj_mse: 2.8625 - binary_cross_entropy: 5.1496
# Epoch 00019: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 22.9939 - binary_accuracy: 0.8765 - overlap_iou: 0.1728 - adj_mse: 2.8619 - binary_cross_entropy: 5.1499 - val_loss: 24.7578 - val_binary_accuracy: 0.8725 - val_overlap_iou: 0.1592 - val_adj_mse: 3.0746 - val_binary_cross_entropy: 5.6393
# Epoch 20/20
# 1443/1444 [============================>.] - ETA: 1s - loss: 22.4588 - binary_accuracy: 0.8825 - overlap_iou: 0.1823 - adj_mse: 2.8335 - binary_cross_entropy: 4.9199
# Epoch 00020: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2124s 1s/step - loss: 22.4506 - binary_accuracy: 0.8825 - overlap_iou: 0.1822 - adj_mse: 2.8323 - binary_cross_entropy: 4.9187 - val_loss: 23.6161 - val_binary_accuracy: 0.8844 - val_overlap_iou: nan - val_adj_mse: 2.9204 - val_binary_cross_entropy: 5.3865

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=30, shuffle=True, verbose=1, initial_epoch=20)
# Out:
# Epoch 21/30
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1443/1444 [============================>.] - ETA: 1s - loss: 21.3684 - binary_accuracy: 0.8950 - overlap_iou: 0.1987 - adj_mse: 2.7979 - binary_cross_entropy: 4.2927
# Epoch 00021: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2151s 1s/step - loss: 21.3692 - binary_accuracy: 0.8950 - overlap_iou: 0.1987 - adj_mse: 2.7980 - binary_cross_entropy: 4.2928 - val_loss: 22.1629 - val_binary_accuracy: 0.9109 - val_overlap_iou: nan - val_adj_mse: 2.8270 - val_binary_cross_entropy: 4.5883
# Epoch 22/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 21.1978 - binary_accuracy: 0.8984 - overlap_iou: 0.2040 - adj_mse: 2.7962 - binary_cross_entropy: 4.1996
# Epoch 00022: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2124s 1s/step - loss: 21.1902 - binary_accuracy: 0.8984 - overlap_iou: 0.2041 - adj_mse: 2.7953 - binary_cross_entropy: 4.1978 - val_loss: 21.6271 - val_binary_accuracy: 0.8846 - val_overlap_iou: 0.2031 - val_adj_mse: 2.8847 - val_binary_cross_entropy: 4.1884
# Epoch 23/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 20.9383 - binary_accuracy: 0.9019 - overlap_iou: 0.2112 - adj_mse: 2.7659 - binary_cross_entropy: 4.1112
# Epoch 00023: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 20.9403 - binary_accuracy: 0.9018 - overlap_iou: 0.2111 - adj_mse: 2.7660 - binary_cross_entropy: 4.1127 - val_loss: 22.0890 - val_binary_accuracy: 0.9021 - val_overlap_iou: 0.2336 - val_adj_mse: 2.9532 - val_binary_cross_entropy: 4.3912
# Epoch 24/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 20.7553 - binary_accuracy: 0.9045 - overlap_iou: 0.2157 - adj_mse: 2.7874 - binary_cross_entropy: 3.9599
# Epoch 00024: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2124s 1s/step - loss: 20.7512 - binary_accuracy: 0.9045 - overlap_iou: 0.2156 - adj_mse: 2.7863 - binary_cross_entropy: 3.9611 - val_loss: 22.0553 - val_binary_accuracy: 0.8923 - val_overlap_iou: 0.2163 - val_adj_mse: 2.8907 - val_binary_cross_entropy: 4.5034
# Epoch 25/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 20.4195 - binary_accuracy: 0.9094 - overlap_iou: 0.2225 - adj_mse: 2.7531 - binary_cross_entropy: 3.8320
# Epoch 00025: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2120s 1s/step - loss: 20.4317 - binary_accuracy: 0.9094 - overlap_iou: 0.2226 - adj_mse: 2.7551 - binary_cross_entropy: 3.8336 - val_loss: 21.8031 - val_binary_accuracy: 0.8858 - val_overlap_iou: 0.2042 - val_adj_mse: 2.8515 - val_binary_cross_entropy: 4.4720
# Epoch 26/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 20.0954 - binary_accuracy: 0.9124 - overlap_iou: 0.2280 - adj_mse: 2.7333 - binary_cross_entropy: 3.6880
# Epoch 00026: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2122s 1s/step - loss: 20.1005 - binary_accuracy: 0.9124 - overlap_iou: 0.2280 - adj_mse: 2.7339 - binary_cross_entropy: 3.6888 - val_loss: 22.1336 - val_binary_accuracy: 0.8884 - val_overlap_iou: 0.2138 - val_adj_mse: 2.9095 - val_binary_cross_entropy: 4.6352
# Epoch 27/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 20.0290 - binary_accuracy: 0.9151 - overlap_iou: 0.2309 - adj_mse: 2.7568 - binary_cross_entropy: 3.5794
# Epoch 00027: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 20.0199 - binary_accuracy: 0.9151 - overlap_iou: 0.2309 - adj_mse: 2.7553 - binary_cross_entropy: 3.5778 - val_loss: 22.0088 - val_binary_accuracy: 0.8878 - val_overlap_iou: 0.2083 - val_adj_mse: 2.8632 - val_binary_cross_entropy: 4.6039
# Epoch 28/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 19.5374 - binary_accuracy: 0.9200 - overlap_iou: nan - adj_mse: 2.6833 - binary_cross_entropy: 3.4325
# Epoch 00028: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 19.5504 - binary_accuracy: 0.9199 - overlap_iou: nan - adj_mse: 2.6845 - binary_cross_entropy: 3.4366 - val_loss: 22.5822 - val_binary_accuracy: 0.8930 - val_overlap_iou: 0.2123 - val_adj_mse: 2.8643 - val_binary_cross_entropy: 4.9155
# Epoch 29/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 19.6168 - binary_accuracy: 0.9221 - overlap_iou: 0.2456 - adj_mse: 2.7353 - binary_cross_entropy: 3.3762
# Epoch 00029: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2123s 1s/step - loss: 19.6191 - binary_accuracy: 0.9221 - overlap_iou: 0.2455 - adj_mse: 2.7350 - binary_cross_entropy: 3.3778 - val_loss: 22.5107 - val_binary_accuracy: 0.8850 - val_overlap_iou: 0.2038 - val_adj_mse: 2.8929 - val_binary_cross_entropy: 4.8523
# Epoch 30/30
# 1443/1444 [============================>.] - ETA: 1s - loss: 19.0090 - binary_accuracy: 0.9286 - overlap_iou: 0.2638 - adj_mse: 2.6766 - binary_cross_entropy: 3.1594
# Epoch 00030: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2124s 1s/step - loss: 19.0130 - binary_accuracy: 0.9286 - overlap_iou: 0.2639 - adj_mse: 2.6774 - binary_cross_entropy: 3.1592 - val_loss: 22.4132 - val_binary_accuracy: 0.8768 - val_overlap_iou: 0.1927 - val_adj_mse: 2.8993 - val_binary_cross_entropy: 4.7540

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=35, shuffle=True, verbose=1, initial_epoch=30)
# Out:
# Epoch 31/35
# 1443/1444 [============================>.] - ETA: 1s - loss: 18.7712 - binary_accuracy: 0.9322 - overlap_iou: 0.2667 - adj_mse: 2.6796 - binary_cross_entropy: 2.9937
# Epoch 00031: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 18.7648 - binary_accuracy: 0.9323 - overlap_iou: 0.2668 - adj_mse: 2.6789 - binary_cross_entropy: 2.9921 - val_loss: 23.0063 - val_binary_accuracy: 0.8864 - val_overlap_iou: 0.1997 - val_adj_mse: 2.9043 - val_binary_cross_entropy: 5.0790
# Epoch 32/35
# 1443/1444 [============================>.] - ETA: 1s - loss: 18.6378 - binary_accuracy: 0.9339 - overlap_iou: 0.2737 - adj_mse: 2.6807 - binary_cross_entropy: 2.9281
# Epoch 00032: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2123s 1s/step - loss: 18.6289 - binary_accuracy: 0.9340 - overlap_iou: 0.2737 - adj_mse: 2.6794 - binary_cross_entropy: 2.9265 - val_loss: 23.2197 - val_binary_accuracy: 0.8837 - val_overlap_iou: 0.1978 - val_adj_mse: 2.9626 - val_binary_cross_entropy: 5.2099
# Epoch 33/35
# 1443/1444 [============================>.] - ETA: 1s - loss: 18.3879 - binary_accuracy: 0.9375 - overlap_iou: nan - adj_mse: 2.6445 - binary_cross_entropy: 2.8604
# Epoch 00033: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2120s 1s/step - loss: 18.3866 - binary_accuracy: 0.9375 - overlap_iou: nan - adj_mse: 2.6447 - binary_cross_entropy: 2.8589 - val_loss: 23.7338 - val_binary_accuracy: 0.8919 - val_overlap_iou: 0.2118 - val_adj_mse: 2.9525 - val_binary_cross_entropy: 5.4650
# Epoch 34/35
# 1443/1444 [============================>.] - ETA: 1s - loss: 18.2360 - binary_accuracy: 0.9392 - overlap_iou: 0.2884 - adj_mse: 2.6486 - binary_cross_entropy: 2.7576
# Epoch 00034: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2121s 1s/step - loss: 18.2323 - binary_accuracy: 0.9392 - overlap_iou: 0.2883 - adj_mse: 2.6484 - binary_cross_entropy: 2.7568 - val_loss: 23.4927 - val_binary_accuracy: 0.8741 - val_overlap_iou: 0.1874 - val_adj_mse: 2.9064 - val_binary_cross_entropy: 5.4287
# Epoch 35/35
# 1443/1444 [============================>.] - ETA: 1s - loss: 18.1830 - binary_accuracy: 0.9428 - overlap_iou: nan - adj_mse: 2.6716 - binary_cross_entropy: 2.6434
# Epoch 00035: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2122s 1s/step - loss: 18.1901 - binary_accuracy: 0.9427 - overlap_iou: nan - adj_mse: 2.6736 - binary_cross_entropy: 2.6432 - val_loss: 24.2119 - val_binary_accuracy: 0.8921 - val_overlap_iou: nan - val_adj_mse: 2.9214 - val_binary_cross_entropy: 5.8155

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=40, shuffle=True, verbose=1, initial_epoch=35)
# Out:
# Epoch 36/40
# 1443/1444 [============================>.] - ETA: 1s - loss: 18.1557 - binary_accuracy: 0.9414 - overlap_iou: nan - adj_mse: 2.6669 - binary_cross_entropy: 2.6587
# Epoch 00036: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2121s 1s/step - loss: 18.1547 - binary_accuracy: 0.9414 - overlap_iou: nan - adj_mse: 2.6666 - binary_cross_entropy: 2.6588 - val_loss: 24.3554 - val_binary_accuracy: 0.9003 - val_overlap_iou: 0.2146 - val_adj_mse: 2.9811 - val_binary_cross_entropy: 5.8679
# Epoch 37/40
# 1443/1444 [============================>.] - ETA: 1s - loss: 17.9408 - binary_accuracy: 0.9445 - overlap_iou: 0.2978 - adj_mse: 2.6567 - binary_cross_entropy: 2.5451
# Epoch 00037: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2123s 1s/step - loss: 17.9438 - binary_accuracy: 0.9445 - overlap_iou: 0.2978 - adj_mse: 2.6566 - binary_cross_entropy: 2.5465 - val_loss: 24.3802 - val_binary_accuracy: 0.8905 - val_overlap_iou: 0.1982 - val_adj_mse: 2.9246 - val_binary_cross_entropy: 5.9544
# Epoch 38/40
# 1443/1444 [============================>.] - ETA: 1s - loss: 17.8612 - binary_accuracy: 0.9467 - overlap_iou: 0.3049 - adj_mse: 2.6665 - binary_cross_entropy: 2.4743
# Epoch 00038: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2125s 1s/step - loss: 17.8652 - binary_accuracy: 0.9467 - overlap_iou: 0.3048 - adj_mse: 2.6673 - binary_cross_entropy: 2.4754 - val_loss: 25.8414 - val_binary_accuracy: 0.9059 - val_overlap_iou: nan - val_adj_mse: 2.9957 - val_binary_cross_entropy: 6.5971
# Epoch 39/40
# 1443/1444 [============================>.] - ETA: 1s - loss: 17.5810 - binary_accuracy: 0.9476 - overlap_iou: nan - adj_mse: 2.6101 - binary_cross_entropy: 2.4344
# Epoch 00039: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2126s 1s/step - loss: 17.5944 - binary_accuracy: 0.9476 - overlap_iou: nan - adj_mse: 2.6126 - binary_cross_entropy: 2.4368 - val_loss: 24.0522 - val_binary_accuracy: 0.8911 - val_overlap_iou: nan - val_adj_mse: 2.9275 - val_binary_cross_entropy: 5.7759
# Epoch 40/40
# 1443/1444 [============================>.] - ETA: 1s - loss: 17.1793 - binary_accuracy: 0.9551 - overlap_iou: 0.3317 - adj_mse: 2.6295 - binary_cross_entropy: 2.1497
# Epoch 00040: saving model to yolo13_2_512.h5
# 1444/1444 [==============================] - 2130s 1s/step - loss: 17.1772 - binary_accuracy: 0.9551 - overlap_iou: 0.3318 - adj_mse: 2.6294 - binary_cross_entropy: 2.1486 - val_loss: 25.3622 - val_binary_accuracy: 0.8901 - val_overlap_iou: 0.1936 - val_adj_mse: 2.9641 - val_binary_cross_entropy: 6.4799

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(142)
plt.plot(history.epoch, history.history["adj_mse"], label="Train MSE loss")
plt.plot(history.epoch, history.history["val_adj_mse"], label="Valid MSE loss")
plt.legend()
plt.subplot(143)
plt.plot(history.epoch, history.history["binary_accuracy"], label="Train Confidence accuracy")
plt.plot(history.epoch, history.history["val_binary_accuracy"], label="Valid Confidence accuracy")
plt.legend()
plt.subplot(144)
plt.plot(history.epoch, history.history["overlap_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_overlap_iou"], label="Valid iou")
plt.legend()
plt.show()

# %% [markdown]
# ## Sample Predictions

# %%
THRESHOLD = 0.75
OVERLAP = 0.3
# look at some sample predictions
samples = np.random.choice(valid_filenames, size=15, replace=False)

coords = np.arange(0, 1024, 512)
overall_ious = []

for filename in samples:
    # load the image
    img = pydicom.dcmread(os.path.join(train_dicom_dir, filename)).pixel_array
    
    filename = filename.split('.')[0]
    
    f, ax = plt.subplots(figsize=(6, 6))
    plt.imshow(img)
    
    # initialize our lists
    ious = []
    truths = []
    boxes = []
    
    # draw the truth boxes
    if filename in pneumonia_locations:
        locs = pneumonia_locations[filename].copy()
        for i in range(GRID_SIZE):
            for j in range(GRID_SIZE):
                pixel_data = locs[i,j,:]
                if pixel_data[0] > 0.5:
                    x, y, w, h = pixel_data[1:]
                    
                    # unnormalize the data
                    w = w * 1024
                    h = h * 1024
                    
                    x = unnorm(x, j, CELL_SIZE)
                    y = unnorm(y, i, CELL_SIZE)
                    
                    # get the corners
                    x = x - (w // 2)
                    y = y - (h // 2)
                    
                    x = int(x)
                    y = int(y)
                    w = int(w)
                    h = int(h)
                    locs[i,j,:] = [1, x, y, w, h]
                    print("Truth:", i, j, x, y, w, h)
                    truths.append([x, y, w, h])
                    
                    rect = patches.Rectangle((x,y),w,h,linewidth=1,edgecolor='b',facecolor='none')
                    ax.add_patch(rect)
                    
    # predict the image
    img = resize(img, (IMAGE_SIZE, IMAGE_SIZE), mode='reflect')
    yhat = model.predict(img.reshape(1, IMAGE_SIZE, IMAGE_SIZE, 1))
    yhat = sigmoid(yhat)
    conf = np.squeeze(yhat)[:,:,0]
    bboxes = np.squeeze(yhat)[:,:,1:]    
    pred_boxes = np.zeros_like(bboxes)
#     print(conf)

    # loop through our predictions
    for i in range(GRID_SIZE):
        for j in range(GRID_SIZE):
            conf_ = conf[i,j]
            # if we have a prediction
            if conf_ > THRESHOLD:
                x,y,w,h = bboxes[i,j,:]
                
                # unnormalize the data
                w = w * 1024
                h = h * 1024

                x = unnorm(x, j, CELL_SIZE)
                y = unnorm(y, i, CELL_SIZE)
                
                # convert to upper left corner from center
                x = np.maximum(x - (w // 2), 0)
                y = np.maximum(y - (h // 2), 0)
                
                x = int(x)
                y = int(y)
                w = int(w)
                h = int(h)
                
                pred_boxes[i,j,:] = [x, y, w, h]
                
                print("Pred:", i, j, "conf:", conf_, x, y, w, h)
                
                # if the boxes have width and height add them to our list
                if w > 30 and h > 30:
                    boxes.append([x,y,w,h])
                
    # do non-max suppression of our boxes
    nms_boxes = non_max_suppression_fast(np.array(boxes), OVERLAP)
    
    # plot our boxes
    for box in nms_boxes:
        x,y,w,h = box
        print(x, y, w, h)
        rect = patches.Rectangle((x,y), w, h, linewidth=1, edgecolor='r', facecolor='none')
        ax.add_patch(rect)
    
    ## calculate the IOU
    true_area = 0
    # get the area of the true boxes
    for true_box in truths:
        x, y, w, h = true_box
        area = w * h
        true_area += area
        
    pred_area = 0
    # get the area of the predictions
    for pred_box in nms_boxes:
        x, y, w, h = pred_box
        area = w * h
        pred_area += area
        
    overall_intersect_area = 0
    # get the IOU by checking all combinations of boxes
    for true_box in truths:
        x1_t, y1_t, w_t, h_t = true_box
        for pred_box in nms_boxes:
            x1_p, y1_p, w_p, h_p = pred_box
            
            # check if the boxes overlap at all
            
            # get the far corners
            x2_p, y2_p = x1_p + w_p, y1_p + h_p
            x2_t, y2_t = x1_t + w_t, y1_t + h_t
        
            # get corners of intersection
            x1_i = np.maximum(x1_p, x1_t)
            y1_i = np.maximum(y1_p, y1_t)
            x2_i = np.minimum(x2_p, x2_t)
            y2_i = np.minimum(y2_p, y2_t)

            # get area of intersect
            i_w, i_h = x2_i - x1_i, y2_i - y1_i
            
            # trap for negative numbers
            i_w = np.maximum(i_w, 0)
            i_h = np.maximum(i_h, 0)
            
            intersect_area = i_w * i_h
            overall_intersect_area += intersect_area
            
            
    for item in coords:
        plt.axvline(item, linewidth=0.5)
        plt.axhline(item, linewidth=0.5)
    
    print("True:", true_area, "Pred:", pred_area, "Intersect:", overall_intersect_area)
    union_area = true_area + pred_area - overall_intersect_area
    
    iou = overall_intersect_area / (union_area + 1e-6)
    print("IOU:", iou)
    
    # only count the IOU if there is a truth or a prediction
    if len(truths) or len(nms_boxes):
      overall_ious.append(iou)
    plt.show()
    
print("Overall Mean IOU:", np.mean(overall_ious))
# Out:
# Truth: 0 0 224 274 202 447
# Truth: 0 1 483 257 210 426
# True: 179754 Pred: 0 Intersect: 0
# IOU: 0.0
# Pred: 0 0 conf: 0.8423235 238 230 205 269
# Pred: 0 1 conf: 0.786234 598 135 209 332
# 238 230 205 269
# 598 135 209 332
# True: 0 Pred: 124533 Intersect: 0
# IOU: 0.0
# Truth: 0 0 240 267 214 413
# Truth: 0 1 605 273 246 451
# Pred: 1 1 conf: 0.52776 707 680 204 291
# 707 680 204 291
# True: 199328 Pred: 59364 Intersect: 6336
# IOU: 0.025107387975617353
# Pred: 1 0 conf: 0.520558 162 571 226 305
# 162 571 226 305
# True: 0 Pred: 68930 Intersect: 0
# IOU: 0.0
# Truth: 0 0 161 208 304 402
# Pred: 0 1 conf: 0.94571614 564 68 241 385
# 564 68 241 385
# True: 122208 Pred: 92785 Intersect: 0
# IOU: 0.0
# Pred: 0 0 conf: 0.8709633 213 138 243 441
# Pred: 0 1 conf: 0.93071026 613 78 251 465
# 213 138 243 441
# 613 78 251 465
# True: 0 Pred: 223878 Intersect: 0
# IOU: 0.0
# Truth: 0 0 228 383 164 248
# Truth: 0 1 528 358 200 297
# True: 100072 Pred: 0 Intersect: 0
# IOU: 0.0
# True: 0 Pred: 0 Intersect: 0
# IOU: 0.0
# Pred: 0 0 conf: 0.8240042 219 152 244 437
# Pred: 0 1 conf: 0.65802366 560 65 217 428
# 219 152 244 437
# 560 65 217 428
# True: 0 Pred: 199504 Intersect: 0
# IOU: 0.0
# Pred: 0 1 conf: 0.88140607 549 114 214 366
# 549 114 214 366
# True: 0 Pred: 78324 Intersect: 0
# IOU: 0.0
# True: 0 Pred: 0 Intersect: 0
# IOU: 0.0
# Pred: 1 1 conf: 0.54614174 748 719 200 274
# 748 719 200 274
# True: 0 Pred: 54800 Intersect: 0
# IOU: 0.0
# Pred: 0 0 conf: 0.94428843 221 182 227 331
# Pred: 0 1 conf: 0.9512287 575 70 240 410
# 221 182 227 331
# 575 70 240 410
# True: 0 Pred: 173537 Intersect: 0
# IOU: 0.0
# True: 0 Pred: 0 Intersect: 0
# IOU: 0.0
# True: 0 Pred: 0 Intersect: 0
# IOU: 0.0
# Overall Mean IOU: 0.0022824898159652138

# %% [markdown]
# # Predict test images

# %%
THRESHOLD = 0.75

# load and shuffle filenames
folder = './stage_1_test_images'
test_filenames = os.listdir(folder)
print('n test samples:', len(test_filenames))

# create test generator with predict flag set to True
test_gen = generator(folder, test_filenames, None, batch_size=24, image_size=IMAGE_SIZE, shuffle=False, predict=True)

# create submission dictionary
submission_dict = {}
# loop through testset
for imgs, filenames in test_gen:
    
    # predict batch of images
    yhats = model.predict(imgs)
    
    # apply sigmoid
    yhats = sigmoid(yhats)
    
    # loop through batch
    for yhat, filename in zip(yhats, filenames):
        predictionString = ""
        boxes = []
        for i in range(4):
            for j in range(4):
                conf = yhat[i, j, 0]
                if conf > THRESHOLD:
                    x, y, w, h = yhat[i,j, 1:]
                    
                    # possible thresholds to keep our boxes within reasonable sizes?
                    if True: #w < 600 and h < 1000:
                        w = w * 1024
                        h = h * 1024

                        x = unnorm(x, j, 256)
                        y = unnorm(y, i, 256)

                        # convert to upper left corner from center
                        x = x - (w // 2)
                        y = y - (h // 2)
                        
                        if w > 20 and h > 20:
                            # make sure our boxes don't run off the edges of the images
                            w = np.minimum(w, 1024 - x)
                            h = np.minimum(h, 1024 - y)
                            boxes.append([x,y,w,h])

        # do our non-max suppression here
        boxes = non_max_suppression_fast(np.array(boxes), 0.3)
        
        # loop through our suppressed boxes and creat the prediction string
        for box in boxes:
            x,y,w,h = box
            
            x = int(x)
            y = int(y)
            w = int(w)
            h = int(h)
        
            # create the prediction string
            predictionString += str(0.9) + ' ' + str(x) + ' ' + str(y) + ' ' + str(w) + ' ' + str(h) + ' '
            
        # add filename and predictionString to dictionary
        filename = filename.split('.')[0]
        submission_dict[filename] = predictionString

    # stop if we've got them all
    if len(submission_dict) >= len(test_filenames):
        break
    
# save dictionary as csv file
sub = pd.DataFrame.from_dict(submission_dict,orient='index')
sub.index.names = ['patientId']
sub.columns = ['PredictionString']

now = datetime.datetime.now()
today = str(now)[:10]
submission_file = today + "_yolo_submission.csv" 
sub.to_csv(submission_file)
# Out:
# n test samples: 1000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-19fd8a7040de> in <module>()
#      26         for i in range(4):
#      27             for j in range(4):
# ---> 28                 conf = yhat[i, j, 0]
#      29                 if conf > THRESHOLD:
#      30                     x, y, w, h = yhat[i,j, 1:]
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
# !kaggle competitions submit -c rsna-pneumonia-detection-challenge -f {submission_file} -m "YOLOv13 512x512 40 epochs"

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# !gsutil cp ./{CHECKPOINT_PATH} gs://{bucket_name}/
# Out:
# Updated property [core/project].
# Copying file://./yolo13_2_512.h5 [Content-Type=application/octet-stream]...
# \
# Operation completed over 1 objects/58.7 MiB.
