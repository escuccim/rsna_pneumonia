# %% [markdown]
# # Approach
#
# * Firstly a convolutional neural network is used to segment the image, using the bounding boxes directly as a mask.
# * Secondly connected components is used to separate multiple areas of predicted pneumonia.
# * Finally a bounding box is simply drawn around every connected component.
#
# # Network
#
# * The network consists of a number of residual blocks with convolutions and downsampling blocks with max pooling.
# * At the end of the network a single upsampling layer converts the output to the same shape as the input.
#
# As the input to the network is 256 by 256 (instead of the original 1024 by 1024) and the network downsamples a number of times without any meaningful upsampling (the final upsampling is just to match in 256 by 256 mask) the final prediction is very crude. If the network downsamples 4 times the final bounding boxes can only change with at least 16 pixels.
#
# **Edit by EAS** - Change input image size to 320x320.

# %%
# install dependencies not included by Colab
# use pip3 to ensure compatibility w/ Google Deep Learning Images 
# !pip install -q pydicom 
# !pip install -q imgaug 
# !pip install -q kaggle
# !pip install -q tqdm 
# !pip install -q PyDrive

# %%
import os
import csv
import random
import pydicom
import numpy as np
import pandas as pd
from skimage import measure
from skimage.transform import resize

import tensorflow as tf
from tensorflow import keras

from matplotlib import pyplot as plt

# %%
from google.colab import auth
from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build

auth.authenticate_user()

drive_service = build('drive', 'v3')

def save_file_to_drive(name, path):
    file_metadata = {
      'name': name,
      'mimeType': 'application/octet-stream'
     }

    media = MediaFileUpload(path, 
                    mimetype='application/octet-stream',
                    resumable=True)

    created = drive_service.files().create(body=file_metadata,
                                   media_body=media,
                                   fields='id').execute()

    print('File ID: {}'.format(created.get('id')))

    return created

# %%
# enter your Kaggle credentionals here
os.environ['KAGGLE_USERNAME']="skooch"
os.environ['KAGGLE_KEY']="42f8a02ee92cc773d1dbe66565673ad3"

# %%
# If you are unable to download the competition dataset, check to see if you have 
# accepted the user agreement on the competition website. 
if not os.path.exists("./stage_1_detailed_class_info.csv.zip"):
    # !kaggle competitions download -c rsna-pneumonia-detection-challenge
# Out:
# Downloading GCP%20Credits%20Request%20Link%20-%20RSNA.txt to /content
#   0% 0.00/55.0 [00:00<?, ?B/s]
# 100% 55.0/55.0 [00:00<00:00, 40.5kB/s]
# Downloading stage_1_detailed_class_info.csv.zip to /content
#   0% 0.00/561k [00:00<?, ?B/s]
# 100% 561k/561k [00:00<00:00, 86.0MB/s]
# Downloading stage_1_sample_submission.csv to /content
#   0% 0.00/51.8k [00:00<?, ?B/s]
# 100% 51.8k/51.8k [00:00<00:00, 38.2MB/s]
# Downloading stage_1_train_labels.csv.zip to /content
#   0% 0.00/634k [00:00<?, ?B/s]
# 100% 634k/634k [00:00<00:00, 93.5MB/s]
# Downloading stage_1_test_images.zip to /content
#  96% 121M/126M [00:02<00:00, 42.7MB/s]
# 100% 126M/126M [00:02<00:00, 50.7MB/s]
# Downloading stage_1_train_images.zip to /content
# 100% 3.16G/3.17G [01:00<00:00, 69.9MB/s]
# 100% 3.17G/3.17G [01:00<00:00, 56.2MB/s]

# %%
# unzipping takes a few minutes
if not os.path.exists("./stage_1_train_labels.csv"):
    print("Unzipping...")
    # !unzip -q -o stage_1_test_images.zip -d stage_1_test_images
    # !unzip -q -o stage_1_train_images.zip -d stage_1_train_images
    # !unzip -q -o stage_1_train_labels.csv.zip
# Out:
# Unzipping...

# %% [markdown]
# # Load pneumonia locations
#
# Table contains [filename : pneumonia location] pairs per row.
# * If a filename contains multiple pneumonia, the table contains multiple rows with the same filename but different pneumonia locations.
# * If a filename contains no pneumonia it contains a single row with an empty pneumonia location.
#
# The code below loads the table and transforms it into a dictionary.
# * The dictionary uses the filename as key and a list of pneumonia locations in that filename as value.
# * If a filename is not present in the dictionary it means that it contains no pneumonia.

# %%
ROOT_DIR = "./"

train_dicom_dir = os.path.join(ROOT_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(ROOT_DIR, 'stage_1_test_images')
print("Train dir:", train_dicom_dir)
# Out:
# Train dir: ./stage_1_train_images

# %%
# empty dictionary
pneumonia_locations = {}
# load table
with open(os.path.join('./stage_1_train_labels.csv'), mode='r') as infile:
    # open reader
    reader = csv.reader(infile)
    # skip header
    next(reader, None)
    # loop through rows
    for rows in reader:
        # retrieve information
        filename = rows[0]
        location = rows[1:5]
        pneumonia = rows[5]
        # if row contains pneumonia add label to dictionary
        # which contains a list of pneumonia locations per filename
        if pneumonia == '1':
            # convert string to float to int
            location = [int(float(i)) for i in location]
            # save pneumonia location in dictionary
            if filename in pneumonia_locations:
                pneumonia_locations[filename].append(location)
            else:
                pneumonia_locations[filename] = [location]

# %% [markdown]
# # Load filenames

# %%
# load and shuffle filenames
random.seed(1977)
folder = './stage_1_train_images'
filenames = os.listdir(folder)
random.shuffle(filenames)
# split into train and validation filenames
n_valid_samples = 2560
train_filenames = filenames[n_valid_samples:]
valid_filenames = filenames[:n_valid_samples]
print('n train samples', len(train_filenames))
print('n valid samples', len(valid_filenames))
n_train_samples = len(filenames) - n_valid_samples
# Out:
# n train samples 23124
# n valid samples 2560

# %% [markdown]
#  # Data generator
#
# The dataset is too large to fit into memory, so we need to create a generator that loads data on the fly.
#
# * The generator takes in some filenames, batch_size and other parameters.
#
# * The generator outputs a random batch of numpy images and numpy masks.

# %%
BATCH_SIZE = 16
IMAGE_SIZE = 448
CHECKPOINT_PATH = "model11_448.h5"

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# !gsutil cp gs://{bucket_name}/{CHECKPOINT_PATH} ./{CHECKPOINT_PATH}
# Out:
# Updated property [core/project].
# Copying gs://pneumonia/model10_448.h5...
# / [1 files][ 66.9 MiB/ 66.9 MiB]
# Operation completed over 1 objects/66.9 MiB.

# %%
class generator(keras.utils.Sequence):
    
    def __init__(self, folder, filenames, pneumonia_locations=None, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=False, predict=False):
        self.folder = folder
        self.filenames = filenames
        self.pneumonia_locations = pneumonia_locations
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.predict = predict
        self.on_epoch_end()
        
    def __load__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # create empty mask
        msk = np.zeros(img.shape)
        # get filename without extension
        filename = filename.split('.')[0]
        # if image contains pneumonia
        if filename in pneumonia_locations:
            # loop through pneumonia
            for location in pneumonia_locations[filename]:
                # add 1's at the location of the pneumonia
                x, y, w, h = location
                msk[y:y+h, x:x+w] = 1
        # if augment then horizontal flip half the time
        if self.augment and random.random() > 0.5:
            img = np.fliplr(img)
            msk = np.fliplr(msk)
            
        # small shifts to images
        if self.augment:
            h_offset = np.random.randint(low=0, high=15)
            v_offset = np.random.randint(low=0, high=15)
            # crop the images
            img = img[v_offset:,h_offset:]
            msk = msk[v_offset:,h_offset:]
            
        # resize both image and mask
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        msk = resize(msk, (self.image_size, self.image_size), mode='reflect') > 0.5
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        msk = np.expand_dims(msk, -1)
        return img, msk
    
    def __loadpredict__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # resize image
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        return img
        
    def __getitem__(self, index):
        # select batch
        filenames = self.filenames[index*self.batch_size:(index+1)*self.batch_size]
        # predict mode: return images and filenames
        if self.predict:
            # load files
            imgs = [self.__loadpredict__(filename) for filename in filenames]
            # create numpy batch
            imgs = np.array(imgs)
            return imgs, filenames
        # train mode: return images and masks
        else:
            # load files
            items = [self.__load__(filename) for filename in filenames]
            # unzip images and masks
            imgs, msks = zip(*items)
            # create numpy batch
            imgs = np.array(imgs)
            msks = np.array(msks)
            return imgs, msks
        
    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.filenames)
        
    def __len__(self):
        if self.predict:
            # return everything
            return int(np.ceil(len(self.filenames) / self.batch_size))
        else:
            # return full batches only
            return int(len(self.filenames) / self.batch_size)

# %% [markdown]
# # Network

# %%
def create_downsample(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 1, padding='same', use_bias=False)(x)
    x = keras.layers.MaxPool2D(2)(x)
    return x

def create_resblock(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    return keras.layers.add([x, inputs])

def create_network(input_size, channels, n_blocks=2, depth=4):
    # input
    inputs = keras.Input(shape=(input_size, input_size, 1))
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(inputs)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    
    x = keras.layers.Conv2D(channels * 2, 3, strides=(2,2), padding='same', use_bias=False)(x)
    
    # residual blocks
    for d in range(depth):
        channels = channels * 2
        if d > 0:
          x = create_downsample(channels, x)
          
        for b in range(n_blocks):
            x = create_resblock(channels, x)
    # output
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    
    # dilated convolutions
    x = keras.layers.Conv2D(channels, 3, dilation_rate=(2,2), padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    
    x = keras.layers.Conv2D(channels, 3, dilation_rate=(2,2), padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    
    x = keras.layers.Dropout(0.15)(x)
    
    x = keras.layers.Conv2D(1, 1, activation='sigmoid')(x)
    outputs = keras.layers.UpSampling2D(2**depth)(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # Train network

# %%
# define iou or jaccard loss function
def iou_loss(y_true, y_pred):
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true * y_pred)
    score = (intersection + 1.) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection + 1.)
    return 1 - score

# combine bce loss and iou loss
def iou_bce_loss(y_true, y_pred):
    return 0.5 * keras.losses.binary_crossentropy(y_true, y_pred) + 0.5 * iou_loss(y_true, y_pred)

# mean iou as a metric
def mean_iou(y_true, y_pred):
    y_pred = tf.round(y_pred)
    intersect = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    smooth = tf.ones(tf.shape(intersect))
    return tf.reduce_mean((intersect + smooth) / (union - intersect + smooth))

# mean iou with any image with no truth counted as 0
def adj_mean_iou(y_true, y_pred):
    y_pred = tf.round(y_pred)
    y_true_pos = tf.reduce_max(y_true, axis=[1, 2, 3])
    
    intersect = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    smooth = tf.ones(tf.shape(intersect))
    
    return tf.reduce_mean((y_true_pos * (intersect + smooth)) / (union - intersect + smooth))      
  
# create network and compiler
model = create_network(input_size=IMAGE_SIZE, channels=32, n_blocks=2, depth=4)
model.compile(optimizer='adam',
              loss=iou_bce_loss,
              metrics=['accuracy', mean_iou, adj_mean_iou])

# cosine learning rate annealing
def cosine_annealing(x):
    lr = 0.002
    epochs = 40
    return lr*(np.cos(np.pi*x/epochs)+1.)/2
  
learning_rate = tf.keras.callbacks.LearningRateScheduler(cosine_annealing)
checkpoint = keras.callbacks.ModelCheckpoint(CHECKPOINT_PATH, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=True, mode='auto', period=1)

# create train and validation generators
folder = './stage_1_train_images'
train_gen = generator(folder, train_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=True, augment=True, predict=False)
valid_gen = generator(folder, valid_filenames, pneumonia_locations, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, shuffle=False, predict=False)

print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 448, 448, 1)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 448, 448, 32) 288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 448, 448, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 448, 448, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 448, 448, 32) 9216        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 448, 448, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 448, 448, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 64) 18432       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 224, 224, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 64) 36864       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 224, 224, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 224, 224, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 224, 224, 64) 36864       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 224, 224, 64) 0           conv2d_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 224, 224, 64) 256         add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 224, 224, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 224, 224, 64) 36864       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 224, 224, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 224, 224, 64) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 224, 224, 64) 36864       leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 224, 224, 64) 0           conv2d_6[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 224, 224, 64) 256         add_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 224, 224, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 224, 224, 128 8192        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 128 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 112, 112, 128 512         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 112, 112, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 112, 112, 128 147456      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 112, 112, 128 512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 112, 112, 128 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 112, 112, 128 147456      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 112, 112, 128 0           conv2d_9[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 112, 112, 128 512         add_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 112, 112, 128 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 112, 112, 128 147456      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 112, 112, 128 512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 112, 112, 128 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 112, 112, 128 147456      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 112, 112, 128 0           conv2d_11[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 112, 112, 128 512         add_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 112, 112, 128 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 112, 112, 256 32768       leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 256)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 256)  1024        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 56, 56, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 256)  589824      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 56, 56, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 256)  589824      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 56, 56, 256)  0           conv2d_14[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 56, 56, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 56, 56, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 256)  589824      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 56, 56, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 56, 56, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 256)  589824      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 56, 56, 256)  0           conv2d_16[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 56, 56, 256)  1024        add_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 56, 56, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 512)  131072      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 512)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 512)  2048        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 28, 28, 512)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 512)  2359296     leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 512)  2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 28, 28, 512)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 512)  2359296     leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           conv2d_19[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 512)  2048        add_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 28, 28, 512)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 512)  2359296     leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 512)  2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 28, 28, 512)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 512)  2359296     leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           conv2d_21[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 512)  2048        add_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 28, 28, 512)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 512)  2359296     leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 512)  2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 28, 28, 512)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 512)  2359296     leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 512)  2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 28, 28, 512)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 28, 28, 512)  0           leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 1)    513         dropout[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 448, 448, 1)  0           conv2d_24[0][0]
# ==================================================================================================
# Total params: 17,476,385
# Trainable params: 17,464,609
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# None

# %%
model.load_weights(CHECKPOINT_PATH)

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=10, shuffle=True)
# Out:
# Epoch 1/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.5072 - acc: 0.9598 - mean_iou: 0.6083 - adj_mean_iou: 0.0290
# Epoch 00001: saving model to model10_448.h5
# 1445/1445 [==============================] - 2828s 2s/step - loss: 0.5071 - acc: 0.9598 - mean_iou: 0.6084 - adj_mean_iou: 0.0290 - val_loss: 0.4766 - val_acc: 0.9635 - val_mean_iou: 0.6087 - val_adj_mean_iou: 0.0457
# Epoch 2/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4678 - acc: 0.9640 - mean_iou: 0.6126 - adj_mean_iou: 0.0496
# Epoch 00002: saving model to model10_448.h5
# 1445/1445 [==============================] - 2803s 2s/step - loss: 0.4677 - acc: 0.9640 - mean_iou: 0.6126 - adj_mean_iou: 0.0496 - val_loss: 0.4585 - val_acc: 0.9661 - val_mean_iou: 0.6711 - val_adj_mean_iou: 0.0492
# Epoch 3/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4523 - acc: 0.9662 - mean_iou: 0.6448 - adj_mean_iou: 0.0550
# Epoch 00003: saving model to model10_448.h5
# 1445/1445 [==============================] - 2807s 2s/step - loss: 0.4523 - acc: 0.9662 - mean_iou: 0.6448 - adj_mean_iou: 0.0551 - val_loss: 0.4408 - val_acc: 0.9702 - val_mean_iou: 0.6660 - val_adj_mean_iou: 0.0569
# Epoch 4/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4409 - acc: 0.9677 - mean_iou: 0.6647 - adj_mean_iou: 0.0599
# Epoch 00004: saving model to model10_448.h5
# 1445/1445 [==============================] - 2804s 2s/step - loss: 0.4409 - acc: 0.9677 - mean_iou: 0.6647 - adj_mean_iou: 0.0599 - val_loss: 0.4342 - val_acc: 0.9707 - val_mean_iou: 0.6645 - val_adj_mean_iou: 0.0617
# Epoch 5/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4332 - acc: 0.9684 - mean_iou: 0.6728 - adj_mean_iou: 0.0617
# Epoch 00005: saving model to model10_448.h5
# 1445/1445 [==============================] - 2808s 2s/step - loss: 0.4333 - acc: 0.9684 - mean_iou: 0.6728 - adj_mean_iou: 0.0617 - val_loss: 0.4572 - val_acc: 0.9603 - val_mean_iou: 0.6461 - val_adj_mean_iou: 0.0582
# Epoch 6/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4287 - acc: 0.9690 - mean_iou: 0.6754 - adj_mean_iou: 0.0638
# Epoch 00006: saving model to model10_448.h5
# 1445/1445 [==============================] - 2807s 2s/step - loss: 0.4287 - acc: 0.9690 - mean_iou: 0.6753 - adj_mean_iou: 0.0638 - val_loss: 0.4242 - val_acc: 0.9717 - val_mean_iou: 0.6775 - val_adj_mean_iou: 0.0645
# Epoch 7/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4237 - acc: 0.9696 - mean_iou: 0.6813 - adj_mean_iou: 0.0659
# Epoch 00007: saving model to model10_448.h5
# 1445/1445 [==============================] - 2804s 2s/step - loss: 0.4237 - acc: 0.9696 - mean_iou: 0.6813 - adj_mean_iou: 0.0659 - val_loss: 0.4245 - val_acc: 0.9705 - val_mean_iou: 0.6943 - val_adj_mean_iou: 0.0634
# Epoch 8/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4203 - acc: 0.9698 - mean_iou: 0.6819 - adj_mean_iou: 0.0678
# Epoch 00008: saving model to model10_448.h5
# 1445/1445 [==============================] - 2796s 2s/step - loss: 0.4203 - acc: 0.9698 - mean_iou: 0.6820 - adj_mean_iou: 0.0679 - val_loss: 0.4500 - val_acc: 0.9635 - val_mean_iou: 0.6401 - val_adj_mean_iou: 0.0619
# Epoch 9/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4172 - acc: 0.9703 - mean_iou: 0.6849 - adj_mean_iou: 0.0680
# Epoch 00009: saving model to model10_448.h5
# 1445/1445 [==============================] - 2798s 2s/step - loss: 0.4171 - acc: 0.9703 - mean_iou: 0.6850 - adj_mean_iou: 0.0680 - val_loss: 0.4241 - val_acc: 0.9683 - val_mean_iou: 0.6460 - val_adj_mean_iou: 0.0741
# Epoch 10/10
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4134 - acc: 0.9706 - mean_iou: 0.6856 - adj_mean_iou: 0.0704
# Epoch 00010: saving model to model10_448.h5
# 1445/1445 [==============================] - 2795s 2s/step - loss: 0.4134 - acc: 0.9706 - mean_iou: 0.6857 - adj_mean_iou: 0.0704 - val_loss: 0.4384 - val_acc: 0.9670 - val_mean_iou: 0.6368 - val_adj_mean_iou: 0.0648

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=15, shuffle=True, initial_epoch=10)
# Out:
# Epoch 11/15
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4105 - acc: 0.9709 - mean_iou: 0.6887 - adj_mean_iou: 0.0723
# Epoch 00011: saving model to model10_448.h5
# 1445/1445 [==============================] - 2819s 2s/step - loss: 0.4106 - acc: 0.9709 - mean_iou: 0.6886 - adj_mean_iou: 0.0722 - val_loss: 0.4118 - val_acc: 0.9707 - val_mean_iou: 0.6629 - val_adj_mean_iou: 0.0773
# Epoch 12/15
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4068 - acc: 0.9712 - mean_iou: 0.6921 - adj_mean_iou: 0.0731
# Epoch 00012: saving model to model10_448.h5
# 1445/1445 [==============================] - 2790s 2s/step - loss: 0.4068 - acc: 0.9712 - mean_iou: 0.6921 - adj_mean_iou: 0.0731 - val_loss: 0.4201 - val_acc: 0.9744 - val_mean_iou: 0.7156 - val_adj_mean_iou: 0.0609
# Epoch 13/15
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4041 - acc: 0.9716 - mean_iou: 0.6973 - adj_mean_iou: 0.0727
# Epoch 00013: saving model to model10_448.h5
# 1445/1445 [==============================] - 2791s 2s/step - loss: 0.4040 - acc: 0.9716 - mean_iou: 0.6974 - adj_mean_iou: 0.0727 - val_loss: 0.4032 - val_acc: 0.9726 - val_mean_iou: 0.7110 - val_adj_mean_iou: 0.0734
# Epoch 14/15
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.4027 - acc: 0.9717 - mean_iou: 0.6991 - adj_mean_iou: 0.0752
# Epoch 00014: saving model to model10_448.h5
# 1445/1445 [==============================] - 2790s 2s/step - loss: 0.4026 - acc: 0.9717 - mean_iou: 0.6992 - adj_mean_iou: 0.0751 - val_loss: 0.4059 - val_acc: 0.9749 - val_mean_iou: 0.7264 - val_adj_mean_iou: 0.0658
# Epoch 15/15
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3981 - acc: 0.9720 - mean_iou: 0.7015 - adj_mean_iou: 0.0763
# Epoch 00015: saving model to model10_448.h5
# 1445/1445 [==============================] - 2785s 2s/step - loss: 0.3981 - acc: 0.9721 - mean_iou: 0.7015 - adj_mean_iou: 0.0762 - val_loss: 0.4266 - val_acc: 0.9773 - val_mean_iou: 0.7507 - val_adj_mean_iou: 0.0522

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=25, shuffle=True, initial_epoch=15)
# Out:
# Epoch 16/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3958 - acc: 0.9723 - mean_iou: 0.7036 - adj_mean_iou: 0.0778
# Epoch 00016: saving model to model10_448.h5
# 1445/1445 [==============================] - 2660s 2s/step - loss: 0.3958 - acc: 0.9723 - mean_iou: 0.7036 - adj_mean_iou: 0.0779 - val_loss: 0.4002 - val_acc: 0.9746 - val_mean_iou: 0.7171 - val_adj_mean_iou: 0.0721
# Epoch 17/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3950 - acc: 0.9722 - mean_iou: 0.7029 - adj_mean_iou: 0.0786
# Epoch 00017: saving model to model10_448.h5
# 1445/1445 [==============================] - 2628s 2s/step - loss: 0.3950 - acc: 0.9722 - mean_iou: 0.7030 - adj_mean_iou: 0.0786 - val_loss: 0.4047 - val_acc: 0.9773 - val_mean_iou: 0.7393 - val_adj_mean_iou: 0.0638
# Epoch 18/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3914 - acc: 0.9727 - mean_iou: 0.7086 - adj_mean_iou: 0.0787
# Epoch 00018: saving model to model10_448.h5
# 1445/1445 [==============================] - 2631s 2s/step - loss: 0.3915 - acc: 0.9727 - mean_iou: 0.7086 - adj_mean_iou: 0.0787 - val_loss: 0.4035 - val_acc: 0.9742 - val_mean_iou: 0.7081 - val_adj_mean_iou: 0.0694
# Epoch 19/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3893 - acc: 0.9731 - mean_iou: 0.7121 - adj_mean_iou: 0.0799
# Epoch 00019: saving model to model10_448.h5
# 1445/1445 [==============================] - 2631s 2s/step - loss: 0.3893 - acc: 0.9731 - mean_iou: 0.7121 - adj_mean_iou: 0.0799 - val_loss: 0.3988 - val_acc: 0.9759 - val_mean_iou: 0.7239 - val_adj_mean_iou: 0.0703
# Epoch 20/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3875 - acc: 0.9732 - mean_iou: 0.7133 - adj_mean_iou: 0.0810
# Epoch 00020: saving model to model10_448.h5
# 1445/1445 [==============================] - 2632s 2s/step - loss: 0.3875 - acc: 0.9732 - mean_iou: 0.7132 - adj_mean_iou: 0.0810 - val_loss: 0.4061 - val_acc: 0.9709 - val_mean_iou: 0.6887 - val_adj_mean_iou: 0.0762
# Epoch 21/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3842 - acc: 0.9734 - mean_iou: 0.7155 - adj_mean_iou: 0.0818
# Epoch 00021: saving model to model10_448.h5
# 1445/1445 [==============================] - 2633s 2s/step - loss: 0.3843 - acc: 0.9734 - mean_iou: 0.7154 - adj_mean_iou: 0.0818 - val_loss: 0.3971 - val_acc: 0.9756 - val_mean_iou: 0.7326 - val_adj_mean_iou: 0.0697
# Epoch 22/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3818 - acc: 0.9737 - mean_iou: 0.7178 - adj_mean_iou: 0.0822
# Epoch 00022: saving model to model10_448.h5
# 1445/1445 [==============================] - 2632s 2s/step - loss: 0.3819 - acc: 0.9737 - mean_iou: 0.7178 - adj_mean_iou: 0.0822 - val_loss: 0.3974 - val_acc: 0.9763 - val_mean_iou: 0.7372 - val_adj_mean_iou: 0.0684
# Epoch 23/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3829 - acc: 0.9739 - mean_iou: 0.7132 - adj_mean_iou: 0.0838
# Epoch 00023: saving model to model10_448.h5
# 1445/1445 [==============================] - 2634s 2s/step - loss: 0.3829 - acc: 0.9739 - mean_iou: 0.7132 - adj_mean_iou: 0.0838 - val_loss: 0.3988 - val_acc: 0.9782 - val_mean_iou: 0.7525 - val_adj_mean_iou: 0.0642
# Epoch 24/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3801 - acc: 0.9743 - mean_iou: 0.7195 - adj_mean_iou: 0.0834
# Epoch 00024: saving model to model10_448.h5
# 1445/1445 [==============================] - 2630s 2s/step - loss: 0.3802 - acc: 0.9743 - mean_iou: 0.7195 - adj_mean_iou: 0.0834 - val_loss: 0.3985 - val_acc: 0.9769 - val_mean_iou: 0.7339 - val_adj_mean_iou: 0.0659
# Epoch 25/25
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3773 - acc: 0.9747 - mean_iou: 0.7218 - adj_mean_iou: 0.0839
# Epoch 00025: saving model to model10_448.h5
# 1445/1445 [==============================] - 2629s 2s/step - loss: 0.3773 - acc: 0.9747 - mean_iou: 0.7218 - adj_mean_iou: 0.0839 - val_loss: 0.3976 - val_acc: 0.9760 - val_mean_iou: 0.7221 - val_adj_mean_iou: 0.0689

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=30, shuffle=True, initial_epoch=25)
# Out:
# Epoch 26/30
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3740 - acc: 0.9749 - mean_iou: 0.7240 - adj_mean_iou: 0.0850
# Epoch 00026: saving model to model10_448.h5
# 1445/1445 [==============================] - 2631s 2s/step - loss: 0.3740 - acc: 0.9749 - mean_iou: 0.7240 - adj_mean_iou: 0.0849 - val_loss: 0.3962 - val_acc: 0.9757 - val_mean_iou: 0.7195 - val_adj_mean_iou: 0.0706
# Epoch 27/30
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3755 - acc: 0.9748 - mean_iou: 0.7223 - adj_mean_iou: 0.0849
# Epoch 00027: saving model to model10_448.h5
# 1445/1445 [==============================] - 2634s 2s/step - loss: 0.3756 - acc: 0.9748 - mean_iou: 0.7223 - adj_mean_iou: 0.0849 - val_loss: 0.3964 - val_acc: 0.9760 - val_mean_iou: 0.7203 - val_adj_mean_iou: 0.0698
# Epoch 28/30
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3727 - acc: 0.9752 - mean_iou: 0.7274 - adj_mean_iou: 0.0849
# Epoch 00028: saving model to model10_448.h5
# 1445/1445 [==============================] - 2634s 2s/step - loss: 0.3727 - acc: 0.9752 - mean_iou: 0.7274 - adj_mean_iou: 0.0849 - val_loss: 0.3967 - val_acc: 0.9766 - val_mean_iou: 0.7286 - val_adj_mean_iou: 0.0679
# Epoch 29/30
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3720 - acc: 0.9753 - mean_iou: 0.7298 - adj_mean_iou: 0.0853
# Epoch 00029: saving model to model10_448.h5
# 1445/1445 [==============================] - 2634s 2s/step - loss: 0.3719 - acc: 0.9753 - mean_iou: 0.7298 - adj_mean_iou: 0.0853 - val_loss: 0.3958 - val_acc: 0.9764 - val_mean_iou: 0.7225 - val_adj_mean_iou: 0.0693
# Epoch 30/30
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3723 - acc: 0.9752 - mean_iou: 0.7258 - adj_mean_iou: 0.0859
# Epoch 00030: saving model to model10_448.h5
# 1445/1445 [==============================] - 2635s 2s/step - loss: 0.3723 - acc: 0.9752 - mean_iou: 0.7258 - adj_mean_iou: 0.0859 - val_loss: 0.3966 - val_acc: 0.9754 - val_mean_iou: 0.7123 - val_adj_mean_iou: 0.0712

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=35, shuffle=True, initial_epoch=30)
# Out:
# Epoch 31/35
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3760 - acc: 0.9748 - mean_iou: 0.7246 - adj_mean_iou: 0.0840
# Epoch 00031: saving model to model10_448.h5
# 1445/1445 [==============================] - 2668s 2s/step - loss: 0.3761 - acc: 0.9748 - mean_iou: 0.7246 - adj_mean_iou: 0.0840 - val_loss: 0.4007 - val_acc: 0.9731 - val_mean_iou: 0.6778 - val_adj_mean_iou: 0.0769
# Epoch 32/35
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3757 - acc: 0.9748 - mean_iou: 0.7209 - adj_mean_iou: 0.0857
# Epoch 00032: saving model to model10_448.h5
# 1445/1445 [==============================] - 2634s 2s/step - loss: 0.3757 - acc: 0.9748 - mean_iou: 0.7207 - adj_mean_iou: 0.0856 - val_loss: 0.3976 - val_acc: 0.9753 - val_mean_iou: 0.7167 - val_adj_mean_iou: 0.0713
# Epoch 33/35
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3732 - acc: 0.9750 - mean_iou: 0.7244 - adj_mean_iou: 0.0859
# Epoch 00033: saving model to model10_448.h5
# 1445/1445 [==============================] - 2637s 2s/step - loss: 0.3733 - acc: 0.9750 - mean_iou: 0.7243 - adj_mean_iou: 0.0859 - val_loss: 0.3945 - val_acc: 0.9768 - val_mean_iou: 0.7369 - val_adj_mean_iou: 0.0689
# Epoch 34/35
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3732 - acc: 0.9752 - mean_iou: 0.7239 - adj_mean_iou: 0.0862
# Epoch 00034: saving model to model10_448.h5
# 1445/1445 [==============================] - 2640s 2s/step - loss: 0.3732 - acc: 0.9752 - mean_iou: 0.7239 - adj_mean_iou: 0.0862 - val_loss: 0.3968 - val_acc: 0.9752 - val_mean_iou: 0.7112 - val_adj_mean_iou: 0.0720
# Epoch 35/35
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3697 - acc: 0.9756 - mean_iou: 0.7273 - adj_mean_iou: 0.0864
# Epoch 00035: saving model to model10_448.h5
# 1445/1445 [==============================] - 2638s 2s/step - loss: 0.3696 - acc: 0.9756 - mean_iou: 0.7274 - adj_mean_iou: 0.0865 - val_loss: 0.3957 - val_acc: 0.9771 - val_mean_iou: 0.7286 - val_adj_mean_iou: 0.0680

# %%
history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate, checkpoint], epochs=40, shuffle=True, initial_epoch=36)
# Out:
# Epoch 37/40
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3698 - acc: 0.9760 - mean_iou: 0.7208 - adj_mean_iou: 0.0870
# Epoch 00037: saving model to model10_448.h5
# 1445/1445 [==============================] - 2677s 2s/step - loss: 0.3697 - acc: 0.9760 - mean_iou: 0.7208 - adj_mean_iou: 0.0871 - val_loss: 0.3969 - val_acc: 0.9769 - val_mean_iou: 0.7269 - val_adj_mean_iou: 0.0678
# Epoch 38/40
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3716 - acc: 0.9758 - mean_iou: 0.7197 - adj_mean_iou: 0.0877
# Epoch 00038: saving model to model10_448.h5
# 1445/1445 [==============================] - 2648s 2s/step - loss: 0.3716 - acc: 0.9758 - mean_iou: 0.7197 - adj_mean_iou: 0.0876 - val_loss: 0.3971 - val_acc: 0.9768 - val_mean_iou: 0.7265 - val_adj_mean_iou: 0.0682
# Epoch 39/40
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3682 - acc: 0.9760 - mean_iou: 0.7235 - adj_mean_iou: 0.0880
# Epoch 00039: saving model to model10_448.h5
# 1445/1445 [==============================] - 2648s 2s/step - loss: 0.3682 - acc: 0.9760 - mean_iou: 0.7236 - adj_mean_iou: 0.0880 - val_loss: 0.3972 - val_acc: 0.9759 - val_mean_iou: 0.7154 - val_adj_mean_iou: 0.0704
# Epoch 40/40
# 1444/1445 [============================>.] - ETA: 1s - loss: 0.3691 - acc: 0.9760 - mean_iou: 0.7214 - adj_mean_iou: 0.0877
# Epoch 00040: saving model to model10_448.h5
# 1445/1445 [==============================] - 2649s 2s/step - loss: 0.3691 - acc: 0.9760 - mean_iou: 0.7213 - adj_mean_iou: 0.0877 - val_loss: 0.3968 - val_acc: 0.9760 - val_mean_iou: 0.7159 - val_adj_mean_iou: 0.0705

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %% [markdown]
# ## Sample Predictions

# %%
THRESHOLD = 0.5
# look at some sample predictions
samples = np.random.choice(valid_filenames, size=8, replace=False)

for filename in samples:
    # load the image
    img = pydicom.dcmread(os.path.join(train_dicom_dir, filename)).pixel_array
    
    msk = np.zeros(img.shape)
    
    filename = filename.split('.')[0]
    # if image contains pneumonia
    if filename in pneumonia_locations:
        # loop through pneumonia
        for location in pneumonia_locations[filename]:
            # add 1's at the location of the pneumonia
            x, y, w, h = location
            msk[y:y+h, x:x+w] = 1
        
    # resize both image and mask
    msk = resize(msk, (IMAGE_SIZE, IMAGE_SIZE), mode='reflect') > 0.5
    img = resize(img, (IMAGE_SIZE, IMAGE_SIZE), mode='reflect')
    
    # predict the image
    yhat = model.predict(img.reshape(1, IMAGE_SIZE, IMAGE_SIZE, 1))
    yhat = yhat > THRESHOLD
    # add trailing channel dimension
    msk = np.expand_dims(msk, -1)

    f, ax = plt.subplots(1, 3, figsize=(10, 4))
    ax[0].imshow(img.reshape(IMAGE_SIZE,IMAGE_SIZE))
    ax[0].set_title("Image")
    ax[1].imshow(msk.reshape(IMAGE_SIZE,IMAGE_SIZE))
    ax[1].set_title("Label")
    ax[2].imshow(yhat.reshape(IMAGE_SIZE,IMAGE_SIZE))
    ax[2].set_title("Prediction")
    plt.show()

# %% [markdown]
# # Predict test images

# %%
# load and shuffle filenames
folder = './stage_1_test_images'
test_filenames = os.listdir(folder)
print('n test samples:', len(test_filenames))

# create test generator with predict flag set to True
test_gen = generator(folder, test_filenames, None, batch_size=25, image_size=IMAGE_SIZE, shuffle=False, predict=True)

# create submission dictionary
submission_dict = {}
# loop through testset
for imgs, filenames in test_gen:
    # predict batch of images
    preds = model.predict(imgs)
    # loop through batch
    for pred, filename in zip(preds, filenames):
        # resize predicted mask
        pred = resize(pred, (1024, 1024), mode='reflect')
        # threshold predicted mask
        comp = pred[:, :, 0] > 0.5
        # apply connected components
        comp = measure.label(comp)
        # apply bounding boxes
        predictionString = ''
        for region in measure.regionprops(comp):
            # retrieve x, y, height and width
            y, x, y2, x2 = region.bbox
            height = y2 - y
            width = x2 - x
            # proxy for confidence score
            conf = np.mean(pred[y:y+height, x:x+width])
            # add to predictionString
            predictionString += str(conf) + ' ' + str(x) + ' ' + str(y) + ' ' + str(width) + ' ' + str(height) + ' '
        # add filename and predictionString to dictionary
        filename = filename.split('.')[0]
        submission_dict[filename] = predictionString
    # stop if we've got them all
    if len(submission_dict) >= len(test_filenames):
        break

print("Done predicting!")        
        
# save dictionary as csv file
sub = pd.DataFrame.from_dict(submission_dict,orient='index')
sub.index.names = ['patientId']
sub.columns = ['PredictionString']
sub.to_csv('submission.csv')
# Out:
# n test samples: 1000
# Done predicting!

# %%
# !kaggle competitions submit -c rsna-pneumonia-detection-challenge -f submission.csv -m "Colab segmentation 10 448x448 40 epochs"
# Out:
# Successfully submitted to RSNA Pneumonia Detection Challenge

# %%
# upload checkpoint to GCS
project_id = 'mammography-198911'
bucket_name = 'pneumonia'

# !gcloud config set project {project_id}
# !gsutil cp ./{CHECKPOINT_PATH} gs://{bucket_name}/
# Out:
# Updated property [core/project].
# Copying file://./model10_448.h5 [Content-Type=application/octet-stream]...
# |
# Operation completed over 1 objects/66.9 MiB.
